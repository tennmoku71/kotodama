# %%
# # 動詞を抽出
# output = open("result.txt", mode='w')

# counter = 0
# with open("voc_list_kiso_kansei.csv",encoding='cp932', mode='r') as f:
#     for s_line in f:
#         linedata = s_line.split(",")
#         if "動詞" in linedata[4]:
#             verb = linedata[2].replace("\"", "")
#             if "名詞" in  linedata[4]:
#                 verb += "する"
#             output.write(verb+"\n")
# output.close()

# %%
# 手動で添削して、ダブリがないかどうか見てみる
with open("result.txt",encoding='utf-8', mode='r') as f:
    lines = f.readlines()
    for i in range(len(lines)):
        for j in range(i):
            if j < i and lines[i] == lines[j]:
                print(str(i)+" "+str(j))
                break

# %%
# jumanにかけて、活用形を抽出する
import pyknp
juman = pyknp.Juman()

output = open("kotodama_dic.csv",encoding="utf-8",mode="w")
with open("result.txt",encoding='utf-8', mode='r') as f:
    for original_verb in f:
        original_verb = original_verb.strip()
        output_line = ""
        mrphs = juman.analysis(original_verb).mrph_list()
        mrph = mrphs[-1]
        output_line_list = [original_verb,mrph.genkei,mrph.hinsi,mrph.katuyou1]
        output.write(",".join(output_line_list)+"\n")
    
output.close()

# %%
# # プログラム変更前の段階でテスト
# from kotodama import kotodama
# from pyknp import Juman
# juman = Juman()
# kotodama.transformVerb(juman.analysis("する"),["過去"])

# %%
# # KNPに依存しない形に変更
# from kotodama import kotodama_no_juman
# kotodama_no_juman.transformVerb("する",["過去"])
# Out:
# 'した'

# %%
# 一個ずつでテスト

from kotodama import kotodama_no_juman
format_all_list = ["可能","受け身","使役","過去","否定","推定","様態","伝聞","例示","勧誘","自分の希望","他人の希望","て","です・ます"]

f = open("result.txt",encoding="utf-8",mode="r")
target_verb_hist = []
for verb in f:
    verb = verb.strip()
    target_verb = kotodama_no_juman.kotodama_dic[verb][0]
    
    if not target_verb in target_verb_hist:    
        katuyou1 = kotodama_no_juman.kotodama_dic[verb][2]
        print(katuyou1)
        for format_element in format_all_list:
            print(target_verb+"\t"+format_element+"\t"+kotodama_no_juman.transformVerb(verb,{format_element}))
        target_verb_hist.append(target_verb)
# Out:
# サ変動詞
# する	可能	できる
# する	受け身	される
# する	使役	させる
# する	過去	した
# する	否定	しない
# する	推定	するらしい
# する	様態	するそう
# する	伝聞	するそうだ
# する	例示	するようだ
# する	勧誘	しよう
# する	自分の希望	したい
# する	他人の希望	したがる
# する	て	して
# する	です・ます	します
# 母音動詞
# いる	可能	いれる
# いる	受け身	いられる
# いる	使役	いさせる
# いる	過去	いた
# いる	否定	いない
# いる	推定	いるらしい
# いる	様態	いるそう
# いる	伝聞	いるそうだ
# いる	例示	いるようだ
# いる	勧誘	いよう
# いる	自分の希望	いたい
# いる	他人の希望	いたがる
# いる	て	いて
# いる	です・ます	います
# 子音動詞ワ行
# 合う	可能	愛し合える
# 合う	受け身	愛し合われる
# 合う	使役	愛し合わせる
# 合う	過去	愛し合った
# 合う	否定	愛し合わない
# 合う	推定	愛し合うらしい
# 合う	様態	愛し合うそう
# 合う	伝聞	愛し合うそうだ
# 合う	例示	愛し合うようだ
# 合う	勧誘	愛し合おう
# 合う	自分の希望	愛し合いたい
# 合う	他人の希望	愛し合いたがる
# 合う	て	愛し合って
# 合う	です・ます	愛し合います
# 子音動詞ガ行
# 扇ぐ	可能	扇げる
# 扇ぐ	受け身	扇がれる
# 扇ぐ	使役	扇がせる
# 扇ぐ	過去	扇いだ
# 扇ぐ	否定	扇がない
# 扇ぐ	推定	扇ぐらしい
# 扇ぐ	様態	扇ぐそう
# 扇ぐ	伝聞	扇ぐそうだ
# 扇ぐ	例示	扇ぐようだ
# 扇ぐ	勧誘	扇ごう
# 扇ぐ	自分の希望	扇ぎたい
# 扇ぐ	他人の希望	扇ぎたがる
# 扇ぐ	て	扇いて
# 扇ぐ	です・ます	扇ぎます
# 子音動詞ラ行
# 挙がる	可能	挙がれる
# 挙がる	受け身	挙がられる
# 挙がる	使役	挙がらせる
# 挙がる	過去	挙がった
# 挙がる	否定	挙がらない
# 挙がる	推定	挙がるらしい
# 挙がる	様態	挙がるそう
# 挙がる	伝聞	挙がるそうだ
# 挙がる	例示	挙がるようだ
# 挙がる	勧誘	挙がろう
# 挙がる	自分の希望	挙がりたい
# 挙がる	他人の希望	挙がりたがる
# 挙がる	て	挙がって
# 挙がる	です・ます	挙がります
# 母音動詞
# 飽きる	可能	飽きれる
# 飽きる	受け身	飽きられる
# 飽きる	使役	飽きさせる
# 飽きる	過去	飽きた
# 飽きる	否定	飽きない
# 飽きる	推定	飽きるらしい
# 飽きる	様態	飽きるそう
# 飽きる	伝聞	飽きるそうだ
# 飽きる	例示	飽きるようだ
# 飽きる	勧誘	飽きよう
# 飽きる	自分の希望	飽きたい
# 飽きる	他人の希望	飽きたがる
# 飽きる	て	飽きて
# 飽きる	です・ます	飽きます
# 子音動詞カ行
# 空く	可能	空ける
# 空く	受け身	空かれる
# 空く	使役	空かせる
# 空く	過去	空いた
# 空く	否定	空かない
# 空く	推定	空くらしい
# 空く	様態	空くそう
# 空く	伝聞	空くそうだ
# 空く	例示	空くようだ
# 空く	勧誘	空こう
# 空く	自分の希望	空きたい
# 空く	他人の希望	空きたがる
# 空く	て	空いて
# 空く	です・ます	空きます
# 母音動詞
# 明ける	可能	明けれる
# 明ける	受け身	明けられる
# 明ける	使役	明けさせる
# 明ける	過去	明けた
# 明ける	否定	明けない
# 明ける	推定	明けるらしい
# 明ける	様態	明けるそう
# 明ける	伝聞	明けるそうだ
# 明ける	例示	明けるようだ
# 明ける	勧誘	明けよう
# 明ける	自分の希望	明けたい
# 明ける	他人の希望	明けたがる
# 明ける	て	明けて
# 明ける	です・ます	明けます
# 母音動詞
# 挙げる	可能	挙げれる
# 挙げる	受け身	挙げられる
# 挙げる	使役	挙げさせる
# 挙げる	過去	挙げた
# 挙げる	否定	挙げない
# 挙げる	推定	挙げるらしい
# 挙げる	様態	挙げるそう
# 挙げる	伝聞	挙げるそうだ
# 挙げる	例示	挙げるようだ
# 挙げる	勧誘	挙げよう
# 挙げる	自分の希望	挙げたい
# 挙げる	他人の希望	挙げたがる
# 挙げる	て	挙げて
# 挙げる	です・ます	挙げます
# 母音動詞
# 上げる	可能	上げれる
# 上げる	受け身	上げられる
# 上げる	使役	上げさせる
# 上げる	過去	上げた
# 上げる	否定	上げない
# 上げる	推定	上げるらしい
# 上げる	様態	上げるそう
# 上げる	伝聞	上げるそうだ
# 上げる	例示	上げるようだ
# 上げる	勧誘	上げよう
# 上げる	自分の希望	上げたい
# 上げる	他人の希望	上げたがる
# 上げる	て	上げて
# 上げる	です・ます	上げます
# 母音動詞
# 憧れる	可能	憧れれる
# 憧れる	受け身	憧れられる
# 憧れる	使役	憧れさせる
# 憧れる	過去	憧れた
# 憧れる	否定	憧れない
# 憧れる	推定	憧れるらしい
# 憧れる	様態	憧れるそう
# 憧れる	伝聞	憧れるそうだ
# 憧れる	例示	憧れるようだ
# 憧れる	勧誘	憧れよう
# 憧れる	自分の希望	憧れたい
# 憧れる	他人の希望	憧れたがる
# 憧れる	て	憧れて
# 憧れる	です・ます	憧れます
# 子音動詞ワ行
# 味わう	可能	味わえる
# 味わう	受け身	味わわれる
# 味わう	使役	味わわせる
# 味わう	過去	味わった
# 味わう	否定	味わわない
# 味わう	推定	味わうらしい
# 味わう	様態	味わうそう
# 味わう	伝聞	味わうそうだ
# 味わう	例示	味わうようだ
# 味わう	勧誘	味わおう
# 味わう	自分の希望	味わいたい
# 味わう	他人の希望	味わいたがる
# 味わう	て	味わって
# 味わう	です・ます	味わいます
# 母音動詞
# 預ける	可能	預けれる
# 預ける	受け身	預けられる
# 預ける	使役	預けさせる
# 預ける	過去	預けた
# 預ける	否定	預けない
# 預ける	推定	預けるらしい
# 預ける	様態	預けるそう
# 預ける	伝聞	預けるそうだ
# 預ける	例示	預けるようだ
# 預ける	勧誘	預けよう
# 預ける	自分の希望	預けたい
# 預ける	他人の希望	預けたがる
# 預ける	て	預けて
# 預ける	です・ます	預けます
# 母音動詞
# 与える	可能	与えれる
# 与える	受け身	与えられる
# 与える	使役	与えさせる
# 与える	過去	与えた
# 与える	否定	与えない
# 与える	推定	与えるらしい
# 与える	様態	与えるそう
# 与える	伝聞	与えるそうだ
# 与える	例示	与えるようだ
# 与える	勧誘	与えよう
# 与える	自分の希望	与えたい
# 与える	他人の希望	与えたがる
# 与える	て	与えて
# 与える	です・ます	与えます
# 子音動詞ラ行
# 当たる	可能	当たれる
# 当たる	受け身	当たられる
# 当たる	使役	当たらせる
# 当たる	過去	当たった
# 当たる	否定	当たらない
# 当たる	推定	当たるらしい
# 当たる	様態	当たるそう
# 当たる	伝聞	当たるそうだ
# 当たる	例示	当たるようだ
# 当たる	勧誘	当たろう
# 当たる	自分の希望	当たりたい
# 当たる	他人の希望	当たりたがる
# 当たる	て	当たって
# 当たる	です・ます	当たります
# 子音動詞ワ行
# 扱う	可能	扱える
# 扱う	受け身	扱われる
# 扱う	使役	扱わせる
# 扱う	過去	扱った
# 扱う	否定	扱わない
# 扱う	推定	扱うらしい
# 扱う	様態	扱うそう
# 扱う	伝聞	扱うそうだ
# 扱う	例示	扱うようだ
# 扱う	勧誘	扱おう
# 扱う	自分の希望	扱いたい
# 扱う	他人の希望	扱いたがる
# 扱う	て	扱って
# 扱う	です・ます	扱います
# 母音動詞
# あてはめる	可能	あてはめれる
# あてはめる	受け身	あてはめられる
# あてはめる	使役	あてはめさせる
# あてはめる	過去	あてはめた
# あてはめる	否定	あてはめない
# あてはめる	推定	あてはめるらしい
# あてはめる	様態	あてはめるそう
# あてはめる	伝聞	あてはめるそうだ
# あてはめる	例示	あてはめるようだ
# あてはめる	勧誘	あてはめよう
# あてはめる	自分の希望	あてはめたい
# あてはめる	他人の希望	あてはめたがる
# あてはめる	て	あてはめて
# あてはめる	です・ます	あてはめます
# 母音動詞
# 当てる	可能	当てれる
# 当てる	受け身	当てられる
# 当てる	使役	当てさせる
# 当てる	過去	当てた
# 当てる	否定	当てない
# 当てる	推定	当てるらしい
# 当てる	様態	当てるそう
# 当てる	伝聞	当てるそうだ
# 当てる	例示	当てるようだ
# 当てる	勧誘	当てよう
# 当てる	自分の希望	当てたい
# 当てる	他人の希望	当てたがる
# 当てる	て	当てて
# 当てる	です・ます	当てます
# 母音動詞
# あてる	可能	あてれる
# あてる	受け身	あてられる
# あてる	使役	あてさせる
# あてる	過去	あてた
# あてる	否定	あてない
# あてる	推定	あてるらしい
# あてる	様態	あてるそう
# あてる	伝聞	あてるそうだ
# あてる	例示	あてるようだ
# あてる	勧誘	あてよう
# あてる	自分の希望	あてたい
# あてる	他人の希望	あてたがる
# あてる	て	あてて
# あてる	です・ます	あてます
# 母音動詞
# あふれる	可能	あふれれる
# あふれる	受け身	あふれられる
# あふれる	使役	あふれさせる
# あふれる	過去	あふれた
# あふれる	否定	あふれない
# あふれる	推定	あふれるらしい
# あふれる	様態	あふれるそう
# あふれる	伝聞	あふれるそうだ
# あふれる	例示	あふれるようだ
# あふれる	勧誘	あふれよう
# あふれる	自分の希望	あふれたい
# あふれる	他人の希望	あふれたがる
# あふれる	て	あふれて
# あふれる	です・ます	あふれます
# 子音動詞サ行
# 甘やかす	可能	甘やかせる
# 甘やかす	受け身	甘やかされる
# 甘やかす	使役	甘やかさせる
# 甘やかす	過去	甘やかした
# 甘やかす	否定	甘やかさない
# 甘やかす	推定	甘やかすらしい
# 甘やかす	様態	甘やかすそう
# 甘やかす	伝聞	甘やかすそうだ
# 甘やかす	例示	甘やかすようだ
# 甘やかす	勧誘	甘やかそう
# 甘やかす	自分の希望	甘やかしたい
# 甘やかす	他人の希望	甘やかしたがる
# 甘やかす	て	甘やかして
# 甘やかす	です・ます	甘やかします
# 子音動詞ラ行
# 誤る	可能	誤れる
# 誤る	受け身	誤られる
# 誤る	使役	誤らせる
# 誤る	過去	誤った
# 誤る	否定	誤らない
# 誤る	推定	誤るらしい
# 誤る	様態	誤るそう
# 誤る	伝聞	誤るそうだ
# 誤る	例示	誤るようだ
# 誤る	勧誘	誤ろう
# 誤る	自分の希望	誤りたい
# 誤る	他人の希望	誤りたがる
# 誤る	て	誤って
# 誤る	です・ます	誤ります
# 子音動詞マ行
# 歩む	可能	歩める
# 歩む	受け身	歩まれる
# 歩む	使役	歩ませる
# 歩む	過去	歩んだ
# 歩む	否定	歩まない
# 歩む	推定	歩むらしい
# 歩む	様態	歩むそう
# 歩む	伝聞	歩むそうだ
# 歩む	例示	歩むようだ
# 歩む	勧誘	歩もう
# 歩む	自分の希望	歩みたい
# 歩む	他人の希望	歩みたがる
# 歩む	て	歩んて
# 歩む	です・ます	歩みます
# 子音動詞ワ行
# 争う	可能	争える
# 争う	受け身	争われる
# 争う	使役	争わせる
# 争う	過去	争った
# 争う	否定	争わない
# 争う	推定	争うらしい
# 争う	様態	争うそう
# 争う	伝聞	争うそうだ
# 争う	例示	争うようだ
# 争う	勧誘	争おう
# 争う	自分の希望	争いたい
# 争う	他人の希望	争いたがる
# 争う	て	争って
# 争う	です・ます	争います
# 子音動詞ラ行
# 改まる	可能	改まれる
# 改まる	受け身	改まられる
# 改まる	使役	改まらせる
# 改まる	過去	改まった
# 改まる	否定	改まらない
# 改まる	推定	改まるらしい
# 改まる	様態	改まるそう
# 改まる	伝聞	改まるそうだ
# 改まる	例示	改まるようだ
# 改まる	勧誘	改まろう
# 改まる	自分の希望	改まりたい
# 改まる	他人の希望	改まりたがる
# 改まる	て	改まって
# 改まる	です・ます	改まります
# 子音動詞サ行
# 表す	可能	表せる
# 表す	受け身	表される
# 表す	使役	表させる
# 表す	過去	表した
# 表す	否定	表さない
# 表す	推定	表すらしい
# 表す	様態	表すそう
# 表す	伝聞	表すそうだ
# 表す	例示	表すようだ
# 表す	勧誘	表そう
# 表す	自分の希望	表したい
# 表す	他人の希望	表したがる
# 表す	て	表して
# 表す	です・ます	表します
# 子音動詞サ行
# 表わす	可能	表わせる
# 表わす	受け身	表わされる
# 表わす	使役	表わさせる
# 表わす	過去	表わした
# 表わす	否定	表わさない
# 表わす	推定	表わすらしい
# 表わす	様態	表わすそう
# 表わす	伝聞	表わすそうだ
# 表わす	例示	表わすようだ
# 表わす	勧誘	表わそう
# 表わす	自分の希望	表わしたい
# 表わす	他人の希望	表わしたがる
# 表わす	て	表わして
# 表わす	です・ます	表わします
# 母音動詞
# 現れる	可能	現れれる
# 現れる	受け身	現れられる
# 現れる	使役	現れさせる
# 現れる	過去	現れた
# 現れる	否定	現れない
# 現れる	推定	現れるらしい
# 現れる	様態	現れるそう
# 現れる	伝聞	現れるそうだ
# 現れる	例示	現れるようだ
# 現れる	勧誘	現れよう
# 現れる	自分の希望	現れたい
# 現れる	他人の希望	現れたがる
# 現れる	て	現れて
# 現れる	です・ます	現れます
# 母音動詞
# 現われる	可能	現われれる
# 現われる	受け身	現われられる
# 現われる	使役	現われさせる
# 現われる	過去	現われた
# 現われる	否定	現われない
# 現われる	推定	現われるらしい
# 現われる	様態	現われるそう
# 現われる	伝聞	現われるそうだ
# 現われる	例示	現われるようだ
# 現われる	勧誘	現われよう
# 現われる	自分の希望	現われたい
# 現われる	他人の希望	現われたがる
# 現われる	て	現われて
# 現われる	です・ます	現われます
# 子音動詞ラ行
# 回る	可能	歩き回れる
# 回る	受け身	歩き回られる
# 回る	使役	歩き回らせる
# 回る	過去	歩き回った
# 回る	否定	歩き回らない
# 回る	推定	歩き回るらしい
# 回る	様態	歩き回るそう
# 回る	伝聞	歩き回るそうだ
# 回る	例示	歩き回るようだ
# 回る	勧誘	歩き回ろう
# 回る	自分の希望	歩き回りたい
# 回る	他人の希望	歩き回りたがる
# 回る	て	歩き回って
# 回る	です・ます	歩き回ります
# 母音動詞
# 合わせる	可能	合わせれる
# 合わせる	受け身	合わせられる
# 合わせる	使役	合わせさせる
# 合わせる	過去	合わせた
# 合わせる	否定	合わせない
# 合わせる	推定	合わせるらしい
# 合わせる	様態	合わせるそう
# 合わせる	伝聞	合わせるそうだ
# 合わせる	例示	合わせるようだ
# 合わせる	勧誘	合わせよう
# 合わせる	自分の希望	合わせたい
# 合わせる	他人の希望	合わせたがる
# 合わせる	て	合わせて
# 合わせる	です・ます	合わせます
# 母音動詞
# 慌てる	可能	慌てれる
# 慌てる	受け身	慌てられる
# 慌てる	使役	慌てさせる
# 慌てる	過去	慌てた
# 慌てる	否定	慌てない
# 慌てる	推定	慌てるらしい
# 慌てる	様態	慌てるそう
# 慌てる	伝聞	慌てるそうだ
# 慌てる	例示	慌てるようだ
# 慌てる	勧誘	慌てよう
# 慌てる	自分の希望	慌てたい
# 慌てる	他人の希望	慌てたがる
# 慌てる	て	慌てて
# 慌てる	です・ます	慌てます
# 子音動詞サ行
# 言い表す	可能	言い表せる
# 言い表す	受け身	言い表される
# 言い表す	使役	言い表させる
# 言い表す	過去	言い表した
# 言い表す	否定	言い表さない
# 言い表す	推定	言い表すらしい
# 言い表す	様態	言い表すそう
# 言い表す	伝聞	言い表すそうだ
# 言い表す	例示	言い表すようだ
# 言い表す	勧誘	言い表そう
# 言い表す	自分の希望	言い表したい
# 言い表す	他人の希望	言い表したがる
# 言い表す	て	言い表して
# 言い表す	です・ます	言い表します
# 子音動詞サ行
# 返す	可能	言い返せる
# 返す	受け身	言い返される
# 返す	使役	言い返させる
# 返す	過去	言い返した
# 返す	否定	言い返さない
# 返す	推定	言い返すらしい
# 返す	様態	言い返すそう
# 返す	伝聞	言い返すそうだ
# 返す	例示	言い返すようだ
# 返す	勧誘	言い返そう
# 返す	自分の希望	言い返したい
# 返す	他人の希望	言い返したがる
# 返す	て	言い返して
# 返す	です・ます	言い返します
# 母音動詞
# 換える	可能	言い換えれる
# 換える	受け身	言い換えられる
# 換える	使役	言い換えさせる
# 換える	過去	言い換えた
# 換える	否定	言い換えない
# 換える	推定	言い換えるらしい
# 換える	様態	言い換えるそう
# 換える	伝聞	言い換えるそうだ
# 換える	例示	言い換えるようだ
# 換える	勧誘	言い換えよう
# 換える	自分の希望	言い換えたい
# 換える	他人の希望	言い換えたがる
# 換える	て	言い換えて
# 換える	です・ます	言い換えます
# 子音動詞サ行
# 生かす	可能	生かせる
# 生かす	受け身	生かされる
# 生かす	使役	生かさせる
# 生かす	過去	生かした
# 生かす	否定	生かさない
# 生かす	推定	生かすらしい
# 生かす	様態	生かすそう
# 生かす	伝聞	生かすそうだ
# 生かす	例示	生かすようだ
# 生かす	勧誘	生かそう
# 生かす	自分の希望	生かしたい
# 生かす	他人の希望	生かしたがる
# 生かす	て	生かして
# 生かす	です・ます	生かします
# 母音動詞
# 生きる	可能	生きれる
# 生きる	受け身	生きられる
# 生きる	使役	生きさせる
# 生きる	過去	生きた
# 生きる	否定	生きない
# 生きる	推定	生きるらしい
# 生きる	様態	生きるそう
# 生きる	伝聞	生きるそうだ
# 生きる	例示	生きるようだ
# 生きる	勧誘	生きよう
# 生きる	自分の希望	生きたい
# 生きる	他人の希望	生きたがる
# 生きる	て	生きて
# 生きる	です・ます	生きます
# 子音動詞カ行促音便形
# 行く	可能	行ける
# 行く	受け身	行かれる
# 行く	使役	行かせる
# 行く	過去	行った
# 行く	否定	行かない
# 行く	推定	行くらしい
# 行く	様態	行くそう
# 行く	伝聞	行くそうだ
# 行く	例示	行くようだ
# 行く	勧誘	行こう
# 行く	自分の希望	行きたい
# 行く	他人の希望	行きたがる
# 行く	て	行って
# 行く	です・ます	行きます
# 母音動詞
# いじめる	可能	いじめれる
# いじめる	受け身	いじめられる
# いじめる	使役	いじめさせる
# いじめる	過去	いじめた
# いじめる	否定	いじめない
# いじめる	推定	いじめるらしい
# いじめる	様態	いじめるそう
# いじめる	伝聞	いじめるそうだ
# いじめる	例示	いじめるようだ
# いじめる	勧誘	いじめよう
# いじめる	自分の希望	いじめたい
# いじめる	他人の希望	いじめたがる
# いじめる	て	いじめて
# いじめる	です・ます	いじめます
# 子音動詞カ行
# 抱く	可能	抱ける
# 抱く	受け身	抱かれる
# 抱く	使役	抱かせる
# 抱く	過去	抱いた
# 抱く	否定	抱かない
# 抱く	推定	抱くらしい
# 抱く	様態	抱くそう
# 抱く	伝聞	抱くそうだ
# 抱く	例示	抱くようだ
# 抱く	勧誘	抱こう
# 抱く	自分の希望	抱きたい
# 抱く	他人の希望	抱きたがる
# 抱く	て	抱いて
# 抱く	です・ます	抱きます
# 子音動詞マ行
# 痛む	可能	痛める
# 痛む	受け身	痛まれる
# 痛む	使役	痛ませる
# 痛む	過去	痛んだ
# 痛む	否定	痛まない
# 痛む	推定	痛むらしい
# 痛む	様態	痛むそう
# 痛む	伝聞	痛むそうだ
# 痛む	例示	痛むようだ
# 痛む	勧誘	痛もう
# 痛む	自分の希望	痛みたい
# 痛む	他人の希望	痛みたがる
# 痛む	て	痛んて
# 痛む	です・ます	痛みます
# 母音動詞
# いためる	可能	いためれる
# いためる	受け身	いためられる
# いためる	使役	いためさせる
# いためる	過去	いためた
# いためる	否定	いためない
# いためる	推定	いためるらしい
# いためる	様態	いためるそう
# いためる	伝聞	いためるそうだ
# いためる	例示	いためるようだ
# いためる	勧誘	いためよう
# いためる	自分の希望	いためたい
# いためる	他人の希望	いためたがる
# いためる	て	いためて
# いためる	です・ます	いためます
# 母音動詞
# 痛める	可能	痛めれる
# 痛める	受け身	痛められる
# 痛める	使役	痛めさせる
# 痛める	過去	痛めた
# 痛める	否定	痛めない
# 痛める	推定	痛めるらしい
# 痛める	様態	痛めるそう
# 痛める	伝聞	痛めるそうだ
# 痛める	例示	痛めるようだ
# 痛める	勧誘	痛めよう
# 痛める	自分の希望	痛めたい
# 痛める	他人の希望	痛めたがる
# 痛める	て	痛めて
# 痛める	です・ます	痛めます
# 子音動詞ラ行
# 至る	可能	至れる
# 至る	受け身	至られる
# 至る	使役	至らせる
# 至る	過去	至った
# 至る	否定	至らない
# 至る	推定	至るらしい
# 至る	様態	至るそう
# 至る	伝聞	至るそうだ
# 至る	例示	至るようだ
# 至る	勧誘	至ろう
# 至る	自分の希望	至りたい
# 至る	他人の希望	至りたがる
# 至る	て	至って
# 至る	です・ます	至ります
# 子音動詞マ行
# 営む	可能	営める
# 営む	受け身	営まれる
# 営む	使役	営ませる
# 営む	過去	営んだ
# 営む	否定	営まない
# 営む	推定	営むらしい
# 営む	様態	営むそう
# 営む	伝聞	営むそうだ
# 営む	例示	営むようだ
# 営む	勧誘	営もう
# 営む	自分の希望	営みたい
# 営む	他人の希望	営みたがる
# 営む	て	営んて
# 営む	です・ます	営みます
# 子音動詞ラ行
# 威張る	可能	威張れる
# 威張る	受け身	威張られる
# 威張る	使役	威張らせる
# 威張る	過去	威張った
# 威張る	否定	威張らない
# 威張る	推定	威張るらしい
# 威張る	様態	威張るそう
# 威張る	伝聞	威張るそうだ
# 威張る	例示	威張るようだ
# 威張る	勧誘	威張ろう
# 威張る	自分の希望	威張りたい
# 威張る	他人の希望	威張りたがる
# 威張る	て	威張って
# 威張る	です・ます	威張ります
# 子音動詞サ行
# 癒す	可能	癒せる
# 癒す	受け身	癒される
# 癒す	使役	癒させる
# 癒す	過去	癒した
# 癒す	否定	癒さない
# 癒す	推定	癒すらしい
# 癒す	様態	癒すそう
# 癒す	伝聞	癒すそうだ
# 癒す	例示	癒すようだ
# 癒す	勧誘	癒そう
# 癒す	自分の希望	癒したい
# 癒す	他人の希望	癒したがる
# 癒す	て	癒して
# 癒す	です・ます	癒します
# 子音動詞ワ行
# うかがう	可能	うかがえる
# うかがう	受け身	うかがわれる
# うかがう	使役	うかがわせる
# うかがう	過去	うかがった
# うかがう	否定	うかがわない
# うかがう	推定	うかがうらしい
# うかがう	様態	うかがうそう
# うかがう	伝聞	うかがうそうだ
# うかがう	例示	うかがうようだ
# うかがう	勧誘	うかがおう
# うかがう	自分の希望	うかがいたい
# うかがう	他人の希望	うかがいたがる
# うかがう	て	うかがって
# うかがう	です・ます	うかがいます
# 子音動詞バ行
# 浮かぶ	可能	浮かべる
# 浮かぶ	受け身	浮かばれる
# 浮かぶ	使役	浮かばせる
# 浮かぶ	過去	浮かんだ
# 浮かぶ	否定	浮かばない
# 浮かぶ	推定	浮かぶらしい
# 浮かぶ	様態	浮かぶそう
# 浮かぶ	伝聞	浮かぶそうだ
# 浮かぶ	例示	浮かぶようだ
# 浮かぶ	勧誘	浮かぼう
# 浮かぶ	自分の希望	浮かびたい
# 浮かぶ	他人の希望	浮かびたがる
# 浮かぶ	て	浮かんて
# 浮かぶ	です・ます	浮かびます
# 子音動詞ラ行
# 上がる	可能	浮き上がれる
# 上がる	受け身	浮き上がられる
# 上がる	使役	浮き上がらせる
# 上がる	過去	浮き上がった
# 上がる	否定	浮き上がらない
# 上がる	推定	浮き上がるらしい
# 上がる	様態	浮き上がるそう
# 上がる	伝聞	浮き上がるそうだ
# 上がる	例示	浮き上がるようだ
# 上がる	勧誘	浮き上がろう
# 上がる	自分の希望	浮き上がりたい
# 上がる	他人の希望	浮き上がりたがる
# 上がる	て	浮き上がって
# 上がる	です・ます	浮き上がります
# 子音動詞カ行
# 浮く	可能	浮ける
# 浮く	受け身	浮かれる
# 浮く	使役	浮かせる
# 浮く	過去	浮いた
# 浮く	否定	浮かない
# 浮く	推定	浮くらしい
# 浮く	様態	浮くそう
# 浮く	伝聞	浮くそうだ
# 浮く	例示	浮くようだ
# 浮く	勧誘	浮こう
# 浮く	自分の希望	浮きたい
# 浮く	他人の希望	浮きたがる
# 浮く	て	浮いて
# 浮く	です・ます	浮きます
# 子音動詞ラ行
# 承る	可能	承れる
# 承る	受け身	承られる
# 承る	使役	承らせる
# 承る	過去	承った
# 承る	否定	承らない
# 承る	推定	承るらしい
# 承る	様態	承るそう
# 承る	伝聞	承るそうだ
# 承る	例示	承るようだ
# 承る	勧誘	承ろう
# 承る	自分の希望	承りたい
# 承る	他人の希望	承りたがる
# 承る	て	承って
# 承る	です・ます	承ります
# 母音動詞
# 受け付ける	可能	受け付けれる
# 受け付ける	受け身	受け付けられる
# 受け付ける	使役	受け付けさせる
# 受け付ける	過去	受け付けた
# 受け付ける	否定	受け付けない
# 受け付ける	推定	受け付けるらしい
# 受け付ける	様態	受け付けるそう
# 受け付ける	伝聞	受け付けるそうだ
# 受け付ける	例示	受け付けるようだ
# 受け付ける	勧誘	受け付けよう
# 受け付ける	自分の希望	受け付けたい
# 受け付ける	他人の希望	受け付けたがる
# 受け付ける	て	受け付けて
# 受け付ける	です・ます	受け付けます
# 子音動詞ラ行
# 受け取る	可能	受け取れる
# 受け取る	受け身	受け取られる
# 受け取る	使役	受け取らせる
# 受け取る	過去	受け取った
# 受け取る	否定	受け取らない
# 受け取る	推定	受け取るらしい
# 受け取る	様態	受け取るそう
# 受け取る	伝聞	受け取るそうだ
# 受け取る	例示	受け取るようだ
# 受け取る	勧誘	受け取ろう
# 受け取る	自分の希望	受け取りたい
# 受け取る	他人の希望	受け取りたがる
# 受け取る	て	受け取って
# 受け取る	です・ます	受け取ります
# 子音動詞ワ行
# 失う	可能	失える
# 失う	受け身	失われる
# 失う	使役	失わせる
# 失う	過去	失った
# 失う	否定	失わない
# 失う	推定	失うらしい
# 失う	様態	失うそう
# 失う	伝聞	失うそうだ
# 失う	例示	失うようだ
# 失う	勧誘	失おう
# 失う	自分の希望	失いたい
# 失う	他人の希望	失いたがる
# 失う	て	失って
# 失う	です・ます	失います
# 子音動詞ワ行
# 疑う	可能	疑える
# 疑う	受け身	疑われる
# 疑う	使役	疑わせる
# 疑う	過去	疑った
# 疑う	否定	疑わない
# 疑う	推定	疑うらしい
# 疑う	様態	疑うそう
# 疑う	伝聞	疑うそうだ
# 疑う	例示	疑うようだ
# 疑う	勧誘	疑おう
# 疑う	自分の希望	疑いたい
# 疑う	他人の希望	疑いたがる
# 疑う	て	疑って
# 疑う	です・ます	疑います
# 母音動詞
# 打ち上げる	可能	打ち上げれる
# 打ち上げる	受け身	打ち上げられる
# 打ち上げる	使役	打ち上げさせる
# 打ち上げる	過去	打ち上げた
# 打ち上げる	否定	打ち上げない
# 打ち上げる	推定	打ち上げるらしい
# 打ち上げる	様態	打ち上げるそう
# 打ち上げる	伝聞	打ち上げるそうだ
# 打ち上げる	例示	打ち上げるようだ
# 打ち上げる	勧誘	打ち上げよう
# 打ち上げる	自分の希望	打ち上げたい
# 打ち上げる	他人の希望	打ち上げたがる
# 打ち上げる	て	打ち上げて
# 打ち上げる	です・ます	打ち上げます
# 母音動詞
# 打ち合わせる	可能	打ち合わせれる
# 打ち合わせる	受け身	打ち合わせられる
# 打ち合わせる	使役	打ち合わせさせる
# 打ち合わせる	過去	打ち合わせた
# 打ち合わせる	否定	打ち合わせない
# 打ち合わせる	推定	打ち合わせるらしい
# 打ち合わせる	様態	打ち合わせるそう
# 打ち合わせる	伝聞	打ち合わせるそうだ
# 打ち合わせる	例示	打ち合わせるようだ
# 打ち合わせる	勧誘	打ち合わせよう
# 打ち合わせる	自分の希望	打ち合わせたい
# 打ち合わせる	他人の希望	打ち合わせたがる
# 打ち合わせる	て	打ち合わせて
# 打ち合わせる	です・ます	打ち合わせます
# 子音動詞サ行
# 映す	可能	映せる
# 映す	受け身	映される
# 映す	使役	映させる
# 映す	過去	映した
# 映す	否定	映さない
# 映す	推定	映すらしい
# 映す	様態	映すそう
# 映す	伝聞	映すそうだ
# 映す	例示	映すようだ
# 映す	勧誘	映そう
# 映す	自分の希望	映したい
# 映す	他人の希望	映したがる
# 映す	て	映して
# 映す	です・ます	映します
# 母音動詞
# 訴える	可能	訴えれる
# 訴える	受け身	訴えられる
# 訴える	使役	訴えさせる
# 訴える	過去	訴えた
# 訴える	否定	訴えない
# 訴える	推定	訴えるらしい
# 訴える	様態	訴えるそう
# 訴える	伝聞	訴えるそうだ
# 訴える	例示	訴えるようだ
# 訴える	勧誘	訴えよう
# 訴える	自分の希望	訴えたい
# 訴える	他人の希望	訴えたがる
# 訴える	て	訴えて
# 訴える	です・ます	訴えます
# 子音動詞ラ行
# 映る	可能	映れる
# 映る	受け身	映られる
# 映る	使役	映らせる
# 映る	過去	映った
# 映る	否定	映らない
# 映る	推定	映るらしい
# 映る	様態	映るそう
# 映る	伝聞	映るそうだ
# 映る	例示	映るようだ
# 映る	勧誘	映ろう
# 映る	自分の希望	映りたい
# 映る	他人の希望	映りたがる
# 映る	て	映って
# 映る	です・ます	映ります
# 子音動詞ラ行
# 写る	可能	写れる
# 写る	受け身	写られる
# 写る	使役	写らせる
# 写る	過去	写った
# 写る	否定	写らない
# 写る	推定	写るらしい
# 写る	様態	写るそう
# 写る	伝聞	写るそうだ
# 写る	例示	写るようだ
# 写る	勧誘	写ろう
# 写る	自分の希望	写りたい
# 写る	他人の希望	写りたがる
# 写る	て	写って
# 写る	です・ます	写ります
# 子音動詞ラ行
# 移る	可能	移れる
# 移る	受け身	移られる
# 移る	使役	移らせる
# 移る	過去	移った
# 移る	否定	移らない
# 移る	推定	移るらしい
# 移る	様態	移るそう
# 移る	伝聞	移るそうだ
# 移る	例示	移るようだ
# 移る	勧誘	移ろう
# 移る	自分の希望	移りたい
# 移る	他人の希望	移りたがる
# 移る	て	移って
# 移る	です・ます	移ります
# 子音動詞カ行
# うなずく	可能	うなずける
# うなずく	受け身	うなずかれる
# うなずく	使役	うなずかせる
# うなずく	過去	うなずいた
# うなずく	否定	うなずかない
# うなずく	推定	うなずくらしい
# うなずく	様態	うなずくそう
# うなずく	伝聞	うなずくそうだ
# うなずく	例示	うなずくようだ
# うなずく	勧誘	うなずこう
# うなずく	自分の希望	うなずきたい
# うなずく	他人の希望	うなずきたがる
# うなずく	て	うなずいて
# うなずく	です・ます	うなずきます
# 子音動詞ラ行
# 奪い取る	可能	奪い取れる
# 奪い取る	受け身	奪い取られる
# 奪い取る	使役	奪い取らせる
# 奪い取る	過去	奪い取った
# 奪い取る	否定	奪い取らない
# 奪い取る	推定	奪い取るらしい
# 奪い取る	様態	奪い取るそう
# 奪い取る	伝聞	奪い取るそうだ
# 奪い取る	例示	奪い取るようだ
# 奪い取る	勧誘	奪い取ろう
# 奪い取る	自分の希望	奪い取りたい
# 奪い取る	他人の希望	奪い取りたがる
# 奪い取る	て	奪い取って
# 奪い取る	です・ます	奪い取ります
# 子音動詞ワ行
# 奪う	可能	奪える
# 奪う	受け身	奪われる
# 奪う	使役	奪わせる
# 奪う	過去	奪った
# 奪う	否定	奪わない
# 奪う	推定	奪うらしい
# 奪う	様態	奪うそう
# 奪う	伝聞	奪うそうだ
# 奪う	例示	奪うようだ
# 奪う	勧誘	奪おう
# 奪う	自分の希望	奪いたい
# 奪う	他人の希望	奪いたがる
# 奪う	て	奪って
# 奪う	です・ます	奪います
# 母音動詞
# 立てる	可能	埋め立てれる
# 立てる	受け身	埋め立てられる
# 立てる	使役	埋め立てさせる
# 立てる	過去	埋め立てた
# 立てる	否定	埋め立てない
# 立てる	推定	埋め立てるらしい
# 立てる	様態	埋め立てるそう
# 立てる	伝聞	埋め立てるそうだ
# 立てる	例示	埋め立てるようだ
# 立てる	勧誘	埋め立てよう
# 立てる	自分の希望	埋め立てたい
# 立てる	他人の希望	埋め立てたがる
# 立てる	て	埋め立てて
# 立てる	です・ます	埋め立てます
# 母音動詞
# 埋める	可能	埋めれる
# 埋める	受け身	埋められる
# 埋める	使役	埋めさせる
# 埋める	過去	埋めた
# 埋める	否定	埋めない
# 埋める	推定	埋めるらしい
# 埋める	様態	埋めるそう
# 埋める	伝聞	埋めるそうだ
# 埋める	例示	埋めるようだ
# 埋める	勧誘	埋めよう
# 埋める	自分の希望	埋めたい
# 埋める	他人の希望	埋めたがる
# 埋める	て	埋めて
# 埋める	です・ます	埋めます
# 子音動詞ラ行
# 裏切る	可能	裏切れる
# 裏切る	受け身	裏切られる
# 裏切る	使役	裏切らせる
# 裏切る	過去	裏切った
# 裏切る	否定	裏切らない
# 裏切る	推定	裏切るらしい
# 裏切る	様態	裏切るそう
# 裏切る	伝聞	裏切るそうだ
# 裏切る	例示	裏切るようだ
# 裏切る	勧誘	裏切ろう
# 裏切る	自分の希望	裏切りたい
# 裏切る	他人の希望	裏切りたがる
# 裏切る	て	裏切って
# 裏切る	です・ます	裏切ります
# 子音動詞ワ行
# 占う	可能	占える
# 占う	受け身	占われる
# 占う	使役	占わせる
# 占う	過去	占った
# 占う	否定	占わない
# 占う	推定	占うらしい
# 占う	様態	占うそう
# 占う	伝聞	占うそうだ
# 占う	例示	占うようだ
# 占う	勧誘	占おう
# 占う	自分の希望	占いたい
# 占う	他人の希望	占いたがる
# 占う	て	占って
# 占う	です・ます	占います
# 子音動詞マ行
# うらやむ	可能	うらやめる
# うらやむ	受け身	うらやまれる
# うらやむ	使役	うらやませる
# うらやむ	過去	うらやんだ
# うらやむ	否定	うらやまない
# うらやむ	推定	うらやむらしい
# うらやむ	様態	うらやむそう
# うらやむ	伝聞	うらやむそうだ
# うらやむ	例示	うらやむようだ
# うらやむ	勧誘	うらやもう
# うらやむ	自分の希望	うらやみたい
# うらやむ	他人の希望	うらやみたがる
# うらやむ	て	うらやんて
# うらやむ	です・ます	うらやみます
# 子音動詞ラ行
# 上回る	可能	上回れる
# 上回る	受け身	上回られる
# 上回る	使役	上回らせる
# 上回る	過去	上回った
# 上回る	否定	上回らない
# 上回る	推定	上回るらしい
# 上回る	様態	上回るそう
# 上回る	伝聞	上回るそうだ
# 上回る	例示	上回るようだ
# 上回る	勧誘	上回ろう
# 上回る	自分の希望	上回りたい
# 上回る	他人の希望	上回りたがる
# 上回る	て	上回って
# 上回る	です・ます	上回ります
# 子音動詞カ行
# 描く	可能	描ける
# 描く	受け身	描かれる
# 描く	使役	描かせる
# 描く	過去	描いた
# 描く	否定	描かない
# 描く	推定	描くらしい
# 描く	様態	描くそう
# 描く	伝聞	描くそうだ
# 描く	例示	描くようだ
# 描く	勧誘	描こう
# 描く	自分の希望	描きたい
# 描く	他人の希望	描きたがる
# 描く	て	描いて
# 描く	です・ます	描きます
# 母音動詞
# 得る	可能	得れる
# 得る	受け身	得られる
# 得る	使役	得させる
# 得る	過去	得た
# 得る	否定	得ない
# 得る	推定	得るらしい
# 得る	様態	得るそう
# 得る	伝聞	得るそうだ
# 得る	例示	得るようだ
# 得る	勧誘	得よう
# 得る	自分の希望	得たい
# 得る	他人の希望	得たがる
# 得る	て	得て
# 得る	です・ます	得ます
# 母音動詞
# かける	可能	追いかけれる
# かける	受け身	追いかけられる
# かける	使役	追いかけさせる
# かける	過去	追いかけた
# かける	否定	追いかけない
# かける	推定	追いかけるらしい
# かける	様態	追いかけるそう
# かける	伝聞	追いかけるそうだ
# かける	例示	追いかけるようだ
# かける	勧誘	追いかけよう
# かける	自分の希望	追いかけたい
# かける	他人の希望	追いかけたがる
# かける	て	追いかけて
# かける	です・ます	追いかけます
# 子音動詞カ行
# 追いつく	可能	追いつける
# 追いつく	受け身	追いつかれる
# 追いつく	使役	追いつかせる
# 追いつく	過去	追いついた
# 追いつく	否定	追いつかない
# 追いつく	推定	追いつくらしい
# 追いつく	様態	追いつくそう
# 追いつく	伝聞	追いつくそうだ
# 追いつく	例示	追いつくようだ
# 追いつく	勧誘	追いつこう
# 追いつく	自分の希望	追いつきたい
# 追いつく	他人の希望	追いつきたがる
# 追いつく	て	追いついて
# 追いつく	です・ます	追いつきます
# 子音動詞カ行
# 追い抜く	可能	追い抜ける
# 追い抜く	受け身	追い抜かれる
# 追い抜く	使役	追い抜かせる
# 追い抜く	過去	追い抜いた
# 追い抜く	否定	追い抜かない
# 追い抜く	推定	追い抜くらしい
# 追い抜く	様態	追い抜くそう
# 追い抜く	伝聞	追い抜くそうだ
# 追い抜く	例示	追い抜くようだ
# 追い抜く	勧誘	追い抜こう
# 追い抜く	自分の希望	追い抜きたい
# 追い抜く	他人の希望	追い抜きたがる
# 追い抜く	て	追い抜いて
# 追い抜く	です・ます	追い抜きます
# 子音動詞ラ行
# 追いやる	可能	追いやれる
# 追いやる	受け身	追いやられる
# 追いやる	使役	追いやらせる
# 追いやる	過去	追いやった
# 追いやる	否定	追いやらない
# 追いやる	推定	追いやるらしい
# 追いやる	様態	追いやるそう
# 追いやる	伝聞	追いやるそうだ
# 追いやる	例示	追いやるようだ
# 追いやる	勧誘	追いやろう
# 追いやる	自分の希望	追いやりたい
# 追いやる	他人の希望	追いやりたがる
# 追いやる	て	追いやって
# 追いやる	です・ます	追いやります
# 子音動詞ワ行
# 追う	可能	追える
# 追う	受け身	追われる
# 追う	使役	追わせる
# 追う	過去	追った
# 追う	否定	追わない
# 追う	推定	追うらしい
# 追う	様態	追うそう
# 追う	伝聞	追うそうだ
# 追う	例示	追うようだ
# 追う	勧誘	追おう
# 追う	自分の希望	追いたい
# 追う	他人の希望	追いたがる
# 追う	て	追って
# 追う	です・ます	追います
# 子音動詞ワ行
# 負う	可能	負える
# 負う	受け身	負われる
# 負う	使役	負わせる
# 負う	過去	負った
# 負う	否定	負わない
# 負う	推定	負うらしい
# 負う	様態	負うそう
# 負う	伝聞	負うそうだ
# 負う	例示	負うようだ
# 負う	勧誘	負おう
# 負う	自分の希望	負いたい
# 負う	他人の希望	負いたがる
# 負う	て	負って
# 負う	です・ます	負います
# 母音動詞
# 応じる	可能	応じれる
# 応じる	受け身	応じられる
# 応じる	使役	応じさせる
# 応じる	過去	応じた
# 応じる	否定	応じない
# 応じる	推定	応じるらしい
# 応じる	様態	応じるそう
# 応じる	伝聞	応じるそうだ
# 応じる	例示	応じるようだ
# 応じる	勧誘	応じよう
# 応じる	自分の希望	応じたい
# 応じる	他人の希望	応じたがる
# 応じる	て	応じて
# 応じる	です・ます	応じます
# 子音動詞ワ行
# 覆う	可能	覆える
# 覆う	受け身	覆われる
# 覆う	使役	覆わせる
# 覆う	過去	覆った
# 覆う	否定	覆わない
# 覆う	推定	覆うらしい
# 覆う	様態	覆うそう
# 覆う	伝聞	覆うそうだ
# 覆う	例示	覆うようだ
# 覆う	勧誘	覆おう
# 覆う	自分の希望	覆いたい
# 覆う	他人の希望	覆いたがる
# 覆う	て	覆って
# 覆う	です・ます	覆います
# 子音動詞サ行
# 犯す	可能	犯せる
# 犯す	受け身	犯される
# 犯す	使役	犯させる
# 犯す	過去	犯した
# 犯す	否定	犯さない
# 犯す	推定	犯すらしい
# 犯す	様態	犯すそう
# 犯す	伝聞	犯すそうだ
# 犯す	例示	犯すようだ
# 犯す	勧誘	犯そう
# 犯す	自分の希望	犯したい
# 犯す	他人の希望	犯したがる
# 犯す	て	犯して
# 犯す	です・ます	犯します
# 母音動詞
# 置き換える	可能	置き換えれる
# 置き換える	受け身	置き換えられる
# 置き換える	使役	置き換えさせる
# 置き換える	過去	置き換えた
# 置き換える	否定	置き換えない
# 置き換える	推定	置き換えるらしい
# 置き換える	様態	置き換えるそう
# 置き換える	伝聞	置き換えるそうだ
# 置き換える	例示	置き換えるようだ
# 置き換える	勧誘	置き換えよう
# 置き換える	自分の希望	置き換えたい
# 置き換える	他人の希望	置き換えたがる
# 置き換える	て	置き換えて
# 置き換える	です・ます	置き換えます
# 子音動詞ワ行
# 補う	可能	補える
# 補う	受け身	補われる
# 補う	使役	補わせる
# 補う	過去	補った
# 補う	否定	補わない
# 補う	推定	補うらしい
# 補う	様態	補うそう
# 補う	伝聞	補うそうだ
# 補う	例示	補うようだ
# 補う	勧誘	補おう
# 補う	自分の希望	補いたい
# 補う	他人の希望	補いたがる
# 補う	て	補って
# 補う	です・ます	補います
# 子音動詞ラ行
# 起こる	可能	起これる
# 起こる	受け身	起こられる
# 起こる	使役	起こらせる
# 起こる	過去	起こった
# 起こる	否定	起こらない
# 起こる	推定	起こるらしい
# 起こる	様態	起こるそう
# 起こる	伝聞	起こるそうだ
# 起こる	例示	起こるようだ
# 起こる	勧誘	起ころう
# 起こる	自分の希望	起こりたい
# 起こる	他人の希望	起こりたがる
# 起こる	て	起こって
# 起こる	です・ます	起こります
# 子音動詞ラ行
# 怒る	可能	怒れる
# 怒る	受け身	怒られる
# 怒る	使役	怒らせる
# 怒る	過去	怒った
# 怒る	否定	怒らない
# 怒る	推定	怒るらしい
# 怒る	様態	怒るそう
# 怒る	伝聞	怒るそうだ
# 怒る	例示	怒るようだ
# 怒る	勧誘	怒ろう
# 怒る	自分の希望	怒りたい
# 怒る	他人の希望	怒りたがる
# 怒る	て	怒って
# 怒る	です・ます	怒ります
# 子音動詞ラ行
# おごる	可能	おごれる
# おごる	受け身	おごられる
# おごる	使役	おごらせる
# おごる	過去	おごった
# おごる	否定	おごらない
# おごる	推定	おごるらしい
# おごる	様態	おごるそう
# おごる	伝聞	おごるそうだ
# おごる	例示	おごるようだ
# おごる	勧誘	おごろう
# おごる	自分の希望	おごりたい
# おごる	他人の希望	おごりたがる
# おごる	て	おごって
# おごる	です・ます	おごります
# 母音動詞
# 抑える	可能	抑えれる
# 抑える	受け身	抑えられる
# 抑える	使役	抑えさせる
# 抑える	過去	抑えた
# 抑える	否定	抑えない
# 抑える	推定	抑えるらしい
# 抑える	様態	抑えるそう
# 抑える	伝聞	抑えるそうだ
# 抑える	例示	抑えるようだ
# 抑える	勧誘	抑えよう
# 抑える	自分の希望	抑えたい
# 抑える	他人の希望	抑えたがる
# 抑える	て	抑えて
# 抑える	です・ます	抑えます
# 子音動詞ラ行
# 治まる	可能	治まれる
# 治まる	受け身	治まられる
# 治まる	使役	治まらせる
# 治まる	過去	治まった
# 治まる	否定	治まらない
# 治まる	推定	治まるらしい
# 治まる	様態	治まるそう
# 治まる	伝聞	治まるそうだ
# 治まる	例示	治まるようだ
# 治まる	勧誘	治まろう
# 治まる	自分の希望	治まりたい
# 治まる	他人の希望	治まりたがる
# 治まる	て	治まって
# 治まる	です・ます	治まります
# 母音動詞
# 納める	可能	納めれる
# 納める	受け身	納められる
# 納める	使役	納めさせる
# 納める	過去	納めた
# 納める	否定	納めない
# 納める	推定	納めるらしい
# 納める	様態	納めるそう
# 納める	伝聞	納めるそうだ
# 納める	例示	納めるようだ
# 納める	勧誘	納めよう
# 納める	自分の希望	納めたい
# 納める	他人の希望	納めたがる
# 納める	て	納めて
# 納める	です・ます	納めます
# 母音動詞
# 治める	可能	治めれる
# 治める	受け身	治められる
# 治める	使役	治めさせる
# 治める	過去	治めた
# 治める	否定	治めない
# 治める	推定	治めるらしい
# 治める	様態	治めるそう
# 治める	伝聞	治めるそうだ
# 治める	例示	治めるようだ
# 治める	勧誘	治めよう
# 治める	自分の希望	治めたい
# 治める	他人の希望	治めたがる
# 治める	て	治めて
# 治める	です・ます	治めます
# 子音動詞サ行
# 押し倒す	可能	押し倒せる
# 押し倒す	受け身	押し倒される
# 押し倒す	使役	押し倒させる
# 押し倒す	過去	押し倒した
# 押し倒す	否定	押し倒さない
# 押し倒す	推定	押し倒すらしい
# 押し倒す	様態	押し倒すそう
# 押し倒す	伝聞	押し倒すそうだ
# 押し倒す	例示	押し倒すようだ
# 押し倒す	勧誘	押し倒そう
# 押し倒す	自分の希望	押し倒したい
# 押し倒す	他人の希望	押し倒したがる
# 押し倒す	て	押し倒して
# 押し倒す	です・ます	押し倒します
# 子音動詞マ行
# 惜しむ	可能	惜しめる
# 惜しむ	受け身	惜しまれる
# 惜しむ	使役	惜しませる
# 惜しむ	過去	惜しんだ
# 惜しむ	否定	惜しまない
# 惜しむ	推定	惜しむらしい
# 惜しむ	様態	惜しむそう
# 惜しむ	伝聞	惜しむそうだ
# 惜しむ	例示	惜しむようだ
# 惜しむ	勧誘	惜しもう
# 惜しむ	自分の希望	惜しみたい
# 惜しむ	他人の希望	惜しみたがる
# 惜しむ	て	惜しんて
# 惜しむ	です・ます	惜しみます
# 母音動詞
# 押し寄せる	可能	押し寄せれる
# 押し寄せる	受け身	押し寄せられる
# 押し寄せる	使役	押し寄せさせる
# 押し寄せる	過去	押し寄せた
# 押し寄せる	否定	押し寄せない
# 押し寄せる	推定	押し寄せるらしい
# 押し寄せる	様態	押し寄せるそう
# 押し寄せる	伝聞	押し寄せるそうだ
# 押し寄せる	例示	押し寄せるようだ
# 押し寄せる	勧誘	押し寄せよう
# 押し寄せる	自分の希望	押し寄せたい
# 押し寄せる	他人の希望	押し寄せたがる
# 押し寄せる	て	押し寄せて
# 押し寄せる	です・ます	押し寄せます
# 子音動詞ラ行
# 恐れ入る	可能	恐れ入れる
# 恐れ入る	受け身	恐れ入られる
# 恐れ入る	使役	恐れ入らせる
# 恐れ入る	過去	恐れ入った
# 恐れ入る	否定	恐れ入らない
# 恐れ入る	推定	恐れ入るらしい
# 恐れ入る	様態	恐れ入るそう
# 恐れ入る	伝聞	恐れ入るそうだ
# 恐れ入る	例示	恐れ入るようだ
# 恐れ入る	勧誘	恐れ入ろう
# 恐れ入る	自分の希望	恐れ入りたい
# 恐れ入る	他人の希望	恐れ入りたがる
# 恐れ入る	て	恐れ入って
# 恐れ入る	です・ます	恐れ入ります
# 母音動詞
# 恐れる	可能	恐れれる
# 恐れる	受け身	恐れられる
# 恐れる	使役	恐れさせる
# 恐れる	過去	恐れた
# 恐れる	否定	恐れない
# 恐れる	推定	恐れるらしい
# 恐れる	様態	恐れるそう
# 恐れる	伝聞	恐れるそうだ
# 恐れる	例示	恐れるようだ
# 恐れる	勧誘	恐れよう
# 恐れる	自分の希望	恐れたい
# 恐れる	他人の希望	恐れたがる
# 恐れる	て	恐れて
# 恐れる	です・ます	恐れます
# 子音動詞ラ行
# 教わる	可能	教われる
# 教わる	受け身	教わられる
# 教わる	使役	教わらせる
# 教わる	過去	教わった
# 教わる	否定	教わらない
# 教わる	推定	教わるらしい
# 教わる	様態	教わるそう
# 教わる	伝聞	教わるそうだ
# 教わる	例示	教わるようだ
# 教わる	勧誘	教わろう
# 教わる	自分の希望	教わりたい
# 教わる	他人の希望	教わりたがる
# 教わる	て	教わって
# 教わる	です・ます	教わります
# 子音動詞マ行
# 込む	可能	落ち込める
# 込む	受け身	落ち込まれる
# 込む	使役	落ち込ませる
# 込む	過去	落ち込んだ
# 込む	否定	落ち込まない
# 込む	推定	落ち込むらしい
# 込む	様態	落ち込むそう
# 込む	伝聞	落ち込むそうだ
# 込む	例示	落ち込むようだ
# 込む	勧誘	落ち込もう
# 込む	自分の希望	落ち込みたい
# 込む	他人の希望	落ち込みたがる
# 込む	て	落ち込んて
# 込む	です・ます	落ち込みます
# 子音動詞カ行
# 落ち着く	可能	落ち着ける
# 落ち着く	受け身	落ち着かれる
# 落ち着く	使役	落ち着かせる
# 落ち着く	過去	落ち着いた
# 落ち着く	否定	落ち着かない
# 落ち着く	推定	落ち着くらしい
# 落ち着く	様態	落ち着くそう
# 落ち着く	伝聞	落ち着くそうだ
# 落ち着く	例示	落ち着くようだ
# 落ち着く	勧誘	落ち着こう
# 落ち着く	自分の希望	落ち着きたい
# 落ち着く	他人の希望	落ち着きたがる
# 落ち着く	て	落ち着いて
# 落ち着く	です・ます	落ち着きます
# 母音動詞
# 訪れる	可能	訪れれる
# 訪れる	受け身	訪れられる
# 訪れる	使役	訪れさせる
# 訪れる	過去	訪れた
# 訪れる	否定	訪れない
# 訪れる	推定	訪れるらしい
# 訪れる	様態	訪れるそう
# 訪れる	伝聞	訪れるそうだ
# 訪れる	例示	訪れるようだ
# 訪れる	勧誘	訪れよう
# 訪れる	自分の希望	訪れたい
# 訪れる	他人の希望	訪れたがる
# 訪れる	て	訪れて
# 訪れる	です・ます	訪れます
# 母音動詞
# 衰える	可能	衰えれる
# 衰える	受け身	衰えられる
# 衰える	使役	衰えさせる
# 衰える	過去	衰えた
# 衰える	否定	衰えない
# 衰える	推定	衰えるらしい
# 衰える	様態	衰えるそう
# 衰える	伝聞	衰えるそうだ
# 衰える	例示	衰えるようだ
# 衰える	勧誘	衰えよう
# 衰える	自分の希望	衰えたい
# 衰える	他人の希望	衰えたがる
# 衰える	て	衰えて
# 衰える	です・ます	衰えます
# 子音動詞カ行
# 驚く	可能	驚ける
# 驚く	受け身	驚かれる
# 驚く	使役	驚かせる
# 驚く	過去	驚いた
# 驚く	否定	驚かない
# 驚く	推定	驚くらしい
# 驚く	様態	驚くそう
# 驚く	伝聞	驚くそうだ
# 驚く	例示	驚くようだ
# 驚く	勧誘	驚こう
# 驚く	自分の希望	驚きたい
# 驚く	他人の希望	驚きたがる
# 驚く	て	驚いて
# 驚く	です・ます	驚きます
# 子音動詞サ行
# 脅かす	可能	脅かせる
# 脅かす	受け身	脅かされる
# 脅かす	使役	脅かさせる
# 脅かす	過去	脅かした
# 脅かす	否定	脅かさない
# 脅かす	推定	脅かすらしい
# 脅かす	様態	脅かすそう
# 脅かす	伝聞	脅かすそうだ
# 脅かす	例示	脅かすようだ
# 脅かす	勧誘	脅かそう
# 脅かす	自分の希望	脅かしたい
# 脅かす	他人の希望	脅かしたがる
# 脅かす	て	脅かして
# 脅かす	です・ます	脅かします
# 母音動詞
# 帯びる	可能	帯びれる
# 帯びる	受け身	帯びられる
# 帯びる	使役	帯びさせる
# 帯びる	過去	帯びた
# 帯びる	否定	帯びない
# 帯びる	推定	帯びるらしい
# 帯びる	様態	帯びるそう
# 帯びる	伝聞	帯びるそうだ
# 帯びる	例示	帯びるようだ
# 帯びる	勧誘	帯びよう
# 帯びる	自分の希望	帯びたい
# 帯びる	他人の希望	帯びたがる
# 帯びる	て	帯びて
# 帯びる	です・ます	帯びます
# 母音動詞
# 覚える	可能	覚えれる
# 覚える	受け身	覚えられる
# 覚える	使役	覚えさせる
# 覚える	過去	覚えた
# 覚える	否定	覚えない
# 覚える	推定	覚えるらしい
# 覚える	様態	覚えるそう
# 覚える	伝聞	覚えるそうだ
# 覚える	例示	覚えるようだ
# 覚える	勧誘	覚えよう
# 覚える	自分の希望	覚えたい
# 覚える	他人の希望	覚えたがる
# 覚える	て	覚えて
# 覚える	です・ます	覚えます
# 母音動詞
# おぼれる	可能	おぼれれる
# おぼれる	受け身	おぼれられる
# おぼれる	使役	おぼれさせる
# おぼれる	過去	おぼれた
# おぼれる	否定	おぼれない
# おぼれる	推定	おぼれるらしい
# おぼれる	様態	おぼれるそう
# おぼれる	伝聞	おぼれるそうだ
# おぼれる	例示	おぼれるようだ
# おぼれる	勧誘	おぼれよう
# おぼれる	自分の希望	おぼれたい
# おぼれる	他人の希望	おぼれたがる
# おぼれる	て	おぼれて
# おぼれる	です・ます	おぼれます
# 子音動詞バ行
# 思い浮かぶ	可能	思い浮かべる
# 思い浮かぶ	受け身	思い浮かばれる
# 思い浮かぶ	使役	思い浮かばせる
# 思い浮かぶ	過去	思い浮かんだ
# 思い浮かぶ	否定	思い浮かばない
# 思い浮かぶ	推定	思い浮かぶらしい
# 思い浮かぶ	様態	思い浮かぶそう
# 思い浮かぶ	伝聞	思い浮かぶそうだ
# 思い浮かぶ	例示	思い浮かぶようだ
# 思い浮かぶ	勧誘	思い浮かぼう
# 思い浮かぶ	自分の希望	思い浮かびたい
# 思い浮かぶ	他人の希望	思い浮かびたがる
# 思い浮かぶ	て	思い浮かんて
# 思い浮かぶ	です・ます	思い浮かびます
# 子音動詞カ行
# つく	可能	思いつける
# つく	受け身	思いつかれる
# つく	使役	思いつかせる
# つく	過去	思いついた
# つく	否定	思いつかない
# つく	推定	思いつくらしい
# つく	様態	思いつくそう
# つく	伝聞	思いつくそうだ
# つく	例示	思いつくようだ
# つく	勧誘	思いつこう
# つく	自分の希望	思いつきたい
# つく	他人の希望	思いつきたがる
# つく	て	思いついて
# つく	です・ます	思いつきます
# 子音動詞バ行
# 及ぶ	可能	及べる
# 及ぶ	受け身	及ばれる
# 及ぶ	使役	及ばせる
# 及ぶ	過去	及んだ
# 及ぶ	否定	及ばない
# 及ぶ	推定	及ぶらしい
# 及ぶ	様態	及ぶそう
# 及ぶ	伝聞	及ぶそうだ
# 及ぶ	例示	及ぶようだ
# 及ぶ	勧誘	及ぼう
# 及ぶ	自分の希望	及びたい
# 及ぶ	他人の希望	及びたがる
# 及ぶ	て	及んて
# 及ぶ	です・ます	及びます
# 子音動詞サ行
# 及ぼす	可能	及ぼせる
# 及ぼす	受け身	及ぼされる
# 及ぼす	使役	及ぼさせる
# 及ぼす	過去	及ぼした
# 及ぼす	否定	及ぼさない
# 及ぼす	推定	及ぼすらしい
# 及ぼす	様態	及ぼすそう
# 及ぼす	伝聞	及ぼすそうだ
# 及ぼす	例示	及ぼすようだ
# 及ぼす	勧誘	及ぼそう
# 及ぼす	自分の希望	及ぼしたい
# 及ぼす	他人の希望	及ぼしたがる
# 及ぼす	て	及ぼして
# 及ぼす	です・ます	及ぼします
# 子音動詞ラ行
# 終わる	可能	終われる
# 終わる	受け身	終わられる
# 終わる	使役	終わらせる
# 終わる	過去	終わった
# 終わる	否定	終わらない
# 終わる	推定	終わるらしい
# 終わる	様態	終わるそう
# 終わる	伝聞	終わるそうだ
# 終わる	例示	終わるようだ
# 終わる	勧誘	終わろう
# 終わる	自分の希望	終わりたい
# 終わる	他人の希望	終わりたがる
# 終わる	て	終わって
# 終わる	です・ます	終わります
# 母音動詞
# 代える	可能	代えれる
# 代える	受け身	代えられる
# 代える	使役	代えさせる
# 代える	過去	代えた
# 代える	否定	代えない
# 代える	推定	代えるらしい
# 代える	様態	代えるそう
# 代える	伝聞	代えるそうだ
# 代える	例示	代えるようだ
# 代える	勧誘	代えよう
# 代える	自分の希望	代えたい
# 代える	他人の希望	代えたがる
# 代える	て	代えて
# 代える	です・ます	代えます
# 母音動詞
# 抱える	可能	抱えれる
# 抱える	受け身	抱えられる
# 抱える	使役	抱えさせる
# 抱える	過去	抱えた
# 抱える	否定	抱えない
# 抱える	推定	抱えるらしい
# 抱える	様態	抱えるそう
# 抱える	伝聞	抱えるそうだ
# 抱える	例示	抱えるようだ
# 抱える	勧誘	抱えよう
# 抱える	自分の希望	抱えたい
# 抱える	他人の希望	抱えたがる
# 抱える	て	抱えて
# 抱える	です・ます	抱えます
# 子音動詞カ行
# 輝く	可能	輝ける
# 輝く	受け身	輝かれる
# 輝く	使役	輝かせる
# 輝く	過去	輝いた
# 輝く	否定	輝かない
# 輝く	推定	輝くらしい
# 輝く	様態	輝くそう
# 輝く	伝聞	輝くそうだ
# 輝く	例示	輝くようだ
# 輝く	勧誘	輝こう
# 輝く	自分の希望	輝きたい
# 輝く	他人の希望	輝きたがる
# 輝く	て	輝いて
# 輝く	です・ます	輝きます
# 子音動詞ラ行
# かかわる	可能	かかわれる
# かかわる	受け身	かかわられる
# かかわる	使役	かかわらせる
# かかわる	過去	かかわった
# かかわる	否定	かかわらない
# かかわる	推定	かかわるらしい
# かかわる	様態	かかわるそう
# かかわる	伝聞	かかわるそうだ
# かかわる	例示	かかわるようだ
# かかわる	勧誘	かかわろう
# かかわる	自分の希望	かかわりたい
# かかわる	他人の希望	かかわりたがる
# かかわる	て	かかわって
# かかわる	です・ます	かかわります
# 子音動詞ラ行
# 限る	可能	限れる
# 限る	受け身	限られる
# 限る	使役	限らせる
# 限る	過去	限った
# 限る	否定	限らない
# 限る	推定	限るらしい
# 限る	様態	限るそう
# 限る	伝聞	限るそうだ
# 限る	例示	限るようだ
# 限る	勧誘	限ろう
# 限る	自分の希望	限りたい
# 限る	他人の希望	限りたがる
# 限る	て	限って
# 限る	です・ます	限ります
# 子音動詞サ行
# 隠す	可能	隠せる
# 隠す	受け身	隠される
# 隠す	使役	隠させる
# 隠す	過去	隠した
# 隠す	否定	隠さない
# 隠す	推定	隠すらしい
# 隠す	様態	隠すそう
# 隠す	伝聞	隠すそうだ
# 隠す	例示	隠すようだ
# 隠す	勧誘	隠そう
# 隠す	自分の希望	隠したい
# 隠す	他人の希望	隠したがる
# 隠す	て	隠して
# 隠す	です・ます	隠します
# 母音動詞
# 隠れる	可能	隠れれる
# 隠れる	受け身	隠れられる
# 隠れる	使役	隠れさせる
# 隠れる	過去	隠れた
# 隠れる	否定	隠れない
# 隠れる	推定	隠れるらしい
# 隠れる	様態	隠れるそう
# 隠れる	伝聞	隠れるそうだ
# 隠れる	例示	隠れるようだ
# 隠れる	勧誘	隠れよう
# 隠れる	自分の希望	隠れたい
# 隠れる	他人の希望	隠れたがる
# 隠れる	て	隠れて
# 隠れる	です・ます	隠れます
# 母音動詞
# かけ離れる	可能	かけ離れれる
# かけ離れる	受け身	かけ離れられる
# かけ離れる	使役	かけ離れさせる
# かけ離れる	過去	かけ離れた
# かけ離れる	否定	かけ離れない
# かけ離れる	推定	かけ離れるらしい
# かけ離れる	様態	かけ離れるそう
# かけ離れる	伝聞	かけ離れるそうだ
# かけ離れる	例示	かけ離れるようだ
# かけ離れる	勧誘	かけ離れよう
# かけ離れる	自分の希望	かけ離れたい
# かけ離れる	他人の希望	かけ離れたがる
# かけ離れる	て	かけ離れて
# かけ離れる	です・ます	かけ離れます
# 母音動詞
# 掛ける	可能	掛けれる
# 掛ける	受け身	掛けられる
# 掛ける	使役	掛けさせる
# 掛ける	過去	掛けた
# 掛ける	否定	掛けない
# 掛ける	推定	掛けるらしい
# 掛ける	様態	掛けるそう
# 掛ける	伝聞	掛けるそうだ
# 掛ける	例示	掛けるようだ
# 掛ける	勧誘	掛けよう
# 掛ける	自分の希望	掛けたい
# 掛ける	他人の希望	掛けたがる
# 掛ける	て	掛けて
# 掛ける	です・ます	掛けます
# 子音動詞マ行
# 囲む	可能	囲める
# 囲む	受け身	囲まれる
# 囲む	使役	囲ませる
# 囲む	過去	囲んだ
# 囲む	否定	囲まない
# 囲む	推定	囲むらしい
# 囲む	様態	囲むそう
# 囲む	伝聞	囲むそうだ
# 囲む	例示	囲むようだ
# 囲む	勧誘	囲もう
# 囲む	自分の希望	囲みたい
# 囲む	他人の希望	囲みたがる
# 囲む	て	囲んて
# 囲む	です・ます	囲みます
# 子音動詞ラ行
# 重なる	可能	重なれる
# 重なる	受け身	重なられる
# 重なる	使役	重ならせる
# 重なる	過去	重なった
# 重なる	否定	重ならない
# 重なる	推定	重なるらしい
# 重なる	様態	重なるそう
# 重なる	伝聞	重なるそうだ
# 重なる	例示	重なるようだ
# 重なる	勧誘	重なろう
# 重なる	自分の希望	重なりたい
# 重なる	他人の希望	重なりたがる
# 重なる	て	重なって
# 重なる	です・ます	重なります
# 母音動詞
# 重ねる	可能	重ねれる
# 重ねる	受け身	重ねられる
# 重ねる	使役	重ねさせる
# 重ねる	過去	重ねた
# 重ねる	否定	重ねない
# 重ねる	推定	重ねるらしい
# 重ねる	様態	重ねるそう
# 重ねる	伝聞	重ねるそうだ
# 重ねる	例示	重ねるようだ
# 重ねる	勧誘	重ねよう
# 重ねる	自分の希望	重ねたい
# 重ねる	他人の希望	重ねたがる
# 重ねる	て	重ねて
# 重ねる	です・ます	重ねます
# サ変動詞
# 課する	可能	課できる
# 課する	受け身	課される
# 課する	使役	課させる
# 課する	過去	課した
# 課する	否定	課しない
# 課する	推定	課するらしい
# 課する	様態	課するそう
# 課する	伝聞	課するそうだ
# 課する	例示	課するようだ
# 課する	勧誘	課しよう
# 課する	自分の希望	課したい
# 課する	他人の希望	課したがる
# 課する	て	課して
# 課する	です・ます	課します
# 子音動詞ガ行
# 稼ぐ	可能	稼げる
# 稼ぐ	受け身	稼がれる
# 稼ぐ	使役	稼がせる
# 稼ぐ	過去	稼いだ
# 稼ぐ	否定	稼がない
# 稼ぐ	推定	稼ぐらしい
# 稼ぐ	様態	稼ぐそう
# 稼ぐ	伝聞	稼ぐそうだ
# 稼ぐ	例示	稼ぐようだ
# 稼ぐ	勧誘	稼ごう
# 稼ぐ	自分の希望	稼ぎたい
# 稼ぐ	他人の希望	稼ぎたがる
# 稼ぐ	て	稼いて
# 稼ぐ	です・ます	稼ぎます
# 母音動詞
# 傾ける	可能	傾けれる
# 傾ける	受け身	傾けられる
# 傾ける	使役	傾けさせる
# 傾ける	過去	傾けた
# 傾ける	否定	傾けない
# 傾ける	推定	傾けるらしい
# 傾ける	様態	傾けるそう
# 傾ける	伝聞	傾けるそうだ
# 傾ける	例示	傾けるようだ
# 傾ける	勧誘	傾けよう
# 傾ける	自分の希望	傾けたい
# 傾ける	他人の希望	傾けたがる
# 傾ける	て	傾けて
# 傾ける	です・ます	傾けます
# 子音動詞ラ行
# 偏る	可能	偏れる
# 偏る	受け身	偏られる
# 偏る	使役	偏らせる
# 偏る	過去	偏った
# 偏る	否定	偏らない
# 偏る	推定	偏るらしい
# 偏る	様態	偏るそう
# 偏る	伝聞	偏るそうだ
# 偏る	例示	偏るようだ
# 偏る	勧誘	偏ろう
# 偏る	自分の希望	偏りたい
# 偏る	他人の希望	偏りたがる
# 偏る	て	偏って
# 偏る	です・ます	偏ります
# 子音動詞ラ行
# 語る	可能	語れる
# 語る	受け身	語られる
# 語る	使役	語らせる
# 語る	過去	語った
# 語る	否定	語らない
# 語る	推定	語るらしい
# 語る	様態	語るそう
# 語る	伝聞	語るそうだ
# 語る	例示	語るようだ
# 語る	勧誘	語ろう
# 語る	自分の希望	語りたい
# 語る	他人の希望	語りたがる
# 語る	て	語って
# 語る	です・ます	語ります
# 子音動詞マ行
# 悲しむ	可能	悲しめる
# 悲しむ	受け身	悲しまれる
# 悲しむ	使役	悲しませる
# 悲しむ	過去	悲しんだ
# 悲しむ	否定	悲しまない
# 悲しむ	推定	悲しむらしい
# 悲しむ	様態	悲しむそう
# 悲しむ	伝聞	悲しむそうだ
# 悲しむ	例示	悲しむようだ
# 悲しむ	勧誘	悲しもう
# 悲しむ	自分の希望	悲しみたい
# 悲しむ	他人の希望	悲しみたがる
# 悲しむ	て	悲しんて
# 悲しむ	です・ます	悲しみます
# 子音動詞カ行
# かみつく	可能	かみつける
# かみつく	受け身	かみつかれる
# かみつく	使役	かみつかせる
# かみつく	過去	かみついた
# かみつく	否定	かみつかない
# かみつく	推定	かみつくらしい
# かみつく	様態	かみつくそう
# かみつく	伝聞	かみつくそうだ
# かみつく	例示	かみつくようだ
# かみつく	勧誘	かみつこう
# かみつく	自分の希望	かみつきたい
# かみつく	他人の希望	かみつきたがる
# かみつく	て	かみついて
# かみつく	です・ます	かみつきます
# 子音動詞マ行
# からむ	可能	からめる
# からむ	受け身	からまれる
# からむ	使役	からませる
# からむ	過去	からんだ
# からむ	否定	からまない
# からむ	推定	からむらしい
# からむ	様態	からむそう
# からむ	伝聞	からむそうだ
# からむ	例示	からむようだ
# からむ	勧誘	からもう
# からむ	自分の希望	からみたい
# からむ	他人の希望	からみたがる
# からむ	て	からんて
# からむ	です・ます	からみます
# 子音動詞サ行
# 乾かす	可能	乾かせる
# 乾かす	受け身	乾かされる
# 乾かす	使役	乾かさせる
# 乾かす	過去	乾かした
# 乾かす	否定	乾かさない
# 乾かす	推定	乾かすらしい
# 乾かす	様態	乾かすそう
# 乾かす	伝聞	乾かすそうだ
# 乾かす	例示	乾かすようだ
# 乾かす	勧誘	乾かそう
# 乾かす	自分の希望	乾かしたい
# 乾かす	他人の希望	乾かしたがる
# 乾かす	て	乾かして
# 乾かす	です・ます	乾かします
# 子音動詞ラ行
# 代わる	可能	代われる
# 代わる	受け身	代わられる
# 代わる	使役	代わらせる
# 代わる	過去	代わった
# 代わる	否定	代わらない
# 代わる	推定	代わるらしい
# 代わる	様態	代わるそう
# 代わる	伝聞	代わるそうだ
# 代わる	例示	代わるようだ
# 代わる	勧誘	代わろう
# 代わる	自分の希望	代わりたい
# 代わる	他人の希望	代わりたがる
# 代わる	て	代わって
# 代わる	です・ます	代わります
# 子音動詞ラ行
# 取る	可能	感じ取れる
# 取る	受け身	感じ取られる
# 取る	使役	感じ取らせる
# 取る	過去	感じ取った
# 取る	否定	感じ取らない
# 取る	推定	感じ取るらしい
# 取る	様態	感じ取るそう
# 取る	伝聞	感じ取るそうだ
# 取る	例示	感じ取るようだ
# 取る	勧誘	感じ取ろう
# 取る	自分の希望	感じ取りたい
# 取る	他人の希望	感じ取りたがる
# 取る	て	感じ取って
# 取る	です・ます	感じ取ります
# 母音動詞
# 感じる	可能	感じれる
# 感じる	受け身	感じられる
# 感じる	使役	感じさせる
# 感じる	過去	感じた
# 感じる	否定	感じない
# 感じる	推定	感じるらしい
# 感じる	様態	感じるそう
# 感じる	伝聞	感じるそうだ
# 感じる	例示	感じるようだ
# 感じる	勧誘	感じよう
# 感じる	自分の希望	感じたい
# 感じる	他人の希望	感じたがる
# 感じる	て	感じて
# 感じる	です・ます	感じます
# サ変動詞
# 関する	可能	関できる
# 関する	受け身	関される
# 関する	使役	関させる
# 関する	過去	関した
# 関する	否定	関しない
# 関する	推定	関するらしい
# 関する	様態	関するそう
# 関する	伝聞	関するそうだ
# 関する	例示	関するようだ
# 関する	勧誘	関しよう
# 関する	自分の希望	関したい
# 関する	他人の希望	関したがる
# 関する	て	関して
# 関する	です・ます	関します
# 母音動詞
# 関連づける	可能	関連づけれる
# 関連づける	受け身	関連づけられる
# 関連づける	使役	関連づけさせる
# 関連づける	過去	関連づけた
# 関連づける	否定	関連づけない
# 関連づける	推定	関連づけるらしい
# 関連づける	様態	関連づけるそう
# 関連づける	伝聞	関連づけるそうだ
# 関連づける	例示	関連づけるようだ
# 関連づける	勧誘	関連づけよう
# 関連づける	自分の希望	関連づけたい
# 関連づける	他人の希望	関連づけたがる
# 関連づける	て	関連づけて
# 関連づける	です・ます	関連づけます
# 子音動詞カ行
# 聞く	可能	聞ける
# 聞く	受け身	聞かれる
# 聞く	使役	聞かせる
# 聞く	過去	聞いた
# 聞く	否定	聞かない
# 聞く	推定	聞くらしい
# 聞く	様態	聞くそう
# 聞く	伝聞	聞くそうだ
# 聞く	例示	聞くようだ
# 聞く	勧誘	聞こう
# 聞く	自分の希望	聞きたい
# 聞く	他人の希望	聞きたがる
# 聞く	て	聞いて
# 聞く	です・ます	聞きます
# 子音動詞カ行
# 効く	可能	効ける
# 効く	受け身	効かれる
# 効く	使役	効かせる
# 効く	過去	効いた
# 効く	否定	効かない
# 効く	推定	効くらしい
# 効く	様態	効くそう
# 効く	伝聞	効くそうだ
# 効く	例示	効くようだ
# 効く	勧誘	効こう
# 効く	自分の希望	効きたい
# 効く	他人の希望	効きたがる
# 効く	て	効いて
# 効く	です・ます	効きます
# 子音動詞ワ行
# 競う	可能	競える
# 競う	受け身	競われる
# 競う	使役	競わせる
# 競う	過去	競った
# 競う	否定	競わない
# 競う	推定	競うらしい
# 競う	様態	競うそう
# 競う	伝聞	競うそうだ
# 競う	例示	競うようだ
# 競う	勧誘	競おう
# 競う	自分の希望	競いたい
# 競う	他人の希望	競いたがる
# 競う	て	競って
# 競う	です・ます	競います
# 母音動詞
# 鍛える	可能	鍛えれる
# 鍛える	受け身	鍛えられる
# 鍛える	使役	鍛えさせる
# 鍛える	過去	鍛えた
# 鍛える	否定	鍛えない
# 鍛える	推定	鍛えるらしい
# 鍛える	様態	鍛えるそう
# 鍛える	伝聞	鍛えるそうだ
# 鍛える	例示	鍛えるようだ
# 鍛える	勧誘	鍛えよう
# 鍛える	自分の希望	鍛えたい
# 鍛える	他人の希望	鍛えたがる
# 鍛える	て	鍛えて
# 鍛える	です・ます	鍛えます
# 子音動詞ラ行
# 決まる	可能	決まれる
# 決まる	受け身	決まられる
# 決まる	使役	決まらせる
# 決まる	過去	決まった
# 決まる	否定	決まらない
# 決まる	推定	決まるらしい
# 決まる	様態	決まるそう
# 決まる	伝聞	決まるそうだ
# 決まる	例示	決まるようだ
# 決まる	勧誘	決まろう
# 決まる	自分の希望	決まりたい
# 決まる	他人の希望	決まりたがる
# 決まる	て	決まって
# 決まる	です・ます	決まります
# 母音動詞
# 決めつける	可能	決めつけれる
# 決めつける	受け身	決めつけられる
# 決めつける	使役	決めつけさせる
# 決めつける	過去	決めつけた
# 決めつける	否定	決めつけない
# 決めつける	推定	決めつけるらしい
# 決めつける	様態	決めつけるそう
# 決めつける	伝聞	決めつけるそうだ
# 決めつける	例示	決めつけるようだ
# 決めつける	勧誘	決めつけよう
# 決めつける	自分の希望	決めつけたい
# 決めつける	他人の希望	決めつけたがる
# 決めつける	て	決めつけて
# 決めつける	です・ます	決めつけます
# 子音動詞ワ行
# 嫌う	可能	嫌える
# 嫌う	受け身	嫌われる
# 嫌う	使役	嫌わせる
# 嫌う	過去	嫌った
# 嫌う	否定	嫌わない
# 嫌う	推定	嫌うらしい
# 嫌う	様態	嫌うそう
# 嫌う	伝聞	嫌うそうだ
# 嫌う	例示	嫌うようだ
# 嫌う	勧誘	嫌おう
# 嫌う	自分の希望	嫌いたい
# 嫌う	他人の希望	嫌いたがる
# 嫌う	て	嫌って
# 嫌う	です・ます	嫌います
# 子音動詞サ行
# 切り出す	可能	切り出せる
# 切り出す	受け身	切り出される
# 切り出す	使役	切り出させる
# 切り出す	過去	切り出した
# 切り出す	否定	切り出さない
# 切り出す	推定	切り出すらしい
# 切り出す	様態	切り出すそう
# 切り出す	伝聞	切り出すそうだ
# 切り出す	例示	切り出すようだ
# 切り出す	勧誘	切り出そう
# 切り出す	自分の希望	切り出したい
# 切り出す	他人の希望	切り出したがる
# 切り出す	て	切り出して
# 切り出す	です・ます	切り出します
# 母音動詞
# 抜ける	可能	切り抜けれる
# 抜ける	受け身	切り抜けられる
# 抜ける	使役	切り抜けさせる
# 抜ける	過去	切り抜けた
# 抜ける	否定	切り抜けない
# 抜ける	推定	切り抜けるらしい
# 抜ける	様態	切り抜けるそう
# 抜ける	伝聞	切り抜けるそうだ
# 抜ける	例示	切り抜けるようだ
# 抜ける	勧誘	切り抜けよう
# 抜ける	自分の希望	切り抜けたい
# 抜ける	他人の希望	切り抜けたがる
# 抜ける	て	切り抜けて
# 抜ける	です・ます	切り抜けます
# 子音動詞ラ行
# きる	可能	きれる
# きる	受け身	きられる
# きる	使役	きらせる
# きる	過去	きった
# きる	否定	きらない
# きる	推定	きるらしい
# きる	様態	きるそう
# きる	伝聞	きるそうだ
# きる	例示	きるようだ
# きる	勧誘	きろう
# きる	自分の希望	きりたい
# きる	他人の希望	きりたがる
# きる	て	きって
# きる	です・ます	きります
# 子音動詞タ行
# 際立つ	可能	際立てる
# 際立つ	受け身	際立たれる
# 際立つ	使役	際立たせる
# 際立つ	過去	際立った
# 際立つ	否定	際立たない
# 際立つ	推定	際立つらしい
# 際立つ	様態	際立つそう
# 際立つ	伝聞	際立つそうだ
# 際立つ	例示	際立つようだ
# 際立つ	勧誘	際立とう
# 際立つ	自分の希望	際立ちたい
# 際立つ	他人の希望	際立ちたがる
# 際立つ	て	際立って
# 際立つ	です・ます	際立ちます
# 母音動詞
# 極める	可能	極めれる
# 極める	受け身	極められる
# 極める	使役	極めさせる
# 極める	過去	極めた
# 極める	否定	極めない
# 極める	推定	極めるらしい
# 極める	様態	極めるそう
# 極める	伝聞	極めるそうだ
# 極める	例示	極めるようだ
# 極める	勧誘	極めよう
# 極める	自分の希望	極めたい
# 極める	他人の希望	極めたがる
# 極める	て	極めて
# 極める	です・ます	極めます
# 母音動詞
# 禁じる	可能	禁じれる
# 禁じる	受け身	禁じられる
# 禁じる	使役	禁じさせる
# 禁じる	過去	禁じた
# 禁じる	否定	禁じない
# 禁じる	推定	禁じるらしい
# 禁じる	様態	禁じるそう
# 禁じる	伝聞	禁じるそうだ
# 禁じる	例示	禁じるようだ
# 禁じる	勧誘	禁じよう
# 禁じる	自分の希望	禁じたい
# 禁じる	他人の希望	禁じたがる
# 禁じる	て	禁じて
# 禁じる	です・ます	禁じます
# 子音動詞ワ行
# 食い違う	可能	食い違える
# 食い違う	受け身	食い違われる
# 食い違う	使役	食い違わせる
# 食い違う	過去	食い違った
# 食い違う	否定	食い違わない
# 食い違う	推定	食い違うらしい
# 食い違う	様態	食い違うそう
# 食い違う	伝聞	食い違うそうだ
# 食い違う	例示	食い違うようだ
# 食い違う	勧誘	食い違おう
# 食い違う	自分の希望	食い違いたい
# 食い違う	他人の希望	食い違いたがる
# 食い違う	て	食い違って
# 食い違う	です・ます	食い違います
# 子音動詞ワ行
# 食う	可能	食える
# 食う	受け身	食われる
# 食う	使役	食わせる
# 食う	過去	食った
# 食う	否定	食わない
# 食う	推定	食うらしい
# 食う	様態	食うそう
# 食う	伝聞	食うそうだ
# 食う	例示	食うようだ
# 食う	勧誘	食おう
# 食う	自分の希望	食いたい
# 食う	他人の希望	食いたがる
# 食う	て	食って
# 食う	です・ます	食います
# 子音動詞ラ行
# 腐る	可能	腐れる
# 腐る	受け身	腐られる
# 腐る	使役	腐らせる
# 腐る	過去	腐った
# 腐る	否定	腐らない
# 腐る	推定	腐るらしい
# 腐る	様態	腐るそう
# 腐る	伝聞	腐るそうだ
# 腐る	例示	腐るようだ
# 腐る	勧誘	腐ろう
# 腐る	自分の希望	腐りたい
# 腐る	他人の希望	腐りたがる
# 腐る	て	腐って
# 腐る	です・ます	腐ります
# 母音動詞
# 崩れる	可能	崩れれる
# 崩れる	受け身	崩れられる
# 崩れる	使役	崩れさせる
# 崩れる	過去	崩れた
# 崩れる	否定	崩れない
# 崩れる	推定	崩れるらしい
# 崩れる	様態	崩れるそう
# 崩れる	伝聞	崩れるそうだ
# 崩れる	例示	崩れるようだ
# 崩れる	勧誘	崩れよう
# 崩れる	自分の希望	崩れたい
# 崩れる	他人の希望	崩れたがる
# 崩れる	て	崩れて
# 崩れる	です・ます	崩れます
# 子音動詞サ行
# 下す	可能	下せる
# 下す	受け身	下される
# 下す	使役	下させる
# 下す	過去	下した
# 下す	否定	下さない
# 下す	推定	下すらしい
# 下す	様態	下すそう
# 下す	伝聞	下すそうだ
# 下す	例示	下すようだ
# 下す	勧誘	下そう
# 下す	自分の希望	下したい
# 下す	他人の希望	下したがる
# 下す	て	下して
# 下す	です・ます	下します
# 子音動詞サ行
# 降す	可能	降せる
# 降す	受け身	降される
# 降す	使役	降させる
# 降す	過去	降した
# 降す	否定	降さない
# 降す	推定	降すらしい
# 降す	様態	降すそう
# 降す	伝聞	降すそうだ
# 降す	例示	降すようだ
# 降す	勧誘	降そう
# 降す	自分の希望	降したい
# 降す	他人の希望	降したがる
# 降す	て	降して
# 降す	です・ます	降します
# 子音動詞ラ行
# 下る	可能	下れる
# 下る	受け身	下られる
# 下る	使役	下らせる
# 下る	過去	下った
# 下る	否定	下らない
# 下る	推定	下るらしい
# 下る	様態	下るそう
# 下る	伝聞	下るそうだ
# 下る	例示	下るようだ
# 下る	勧誘	下ろう
# 下る	自分の希望	下りたい
# 下る	他人の希望	下りたがる
# 下る	て	下って
# 下る	です・ます	下ります
# 子音動詞カ行
# くっつく	可能	くっつける
# くっつく	受け身	くっつかれる
# くっつく	使役	くっつかせる
# くっつく	過去	くっついた
# くっつく	否定	くっつかない
# くっつく	推定	くっつくらしい
# くっつく	様態	くっつくそう
# くっつく	伝聞	くっつくそうだ
# くっつく	例示	くっつくようだ
# くっつく	勧誘	くっつこう
# くっつく	自分の希望	くっつきたい
# くっつく	他人の希望	くっつきたがる
# くっつく	て	くっついて
# くっつく	です・ます	くっつきます
# 子音動詞ラ行
# 配る	可能	配れる
# 配る	受け身	配られる
# 配る	使役	配らせる
# 配る	過去	配った
# 配る	否定	配らない
# 配る	推定	配るらしい
# 配る	様態	配るそう
# 配る	伝聞	配るそうだ
# 配る	例示	配るようだ
# 配る	勧誘	配ろう
# 配る	自分の希望	配りたい
# 配る	他人の希望	配りたがる
# 配る	て	配って
# 配る	です・ます	配ります
# 母音動詞
# 組合せる	可能	組合せれる
# 組合せる	受け身	組合せられる
# 組合せる	使役	組合せさせる
# 組合せる	過去	組合せた
# 組合せる	否定	組合せない
# 組合せる	推定	組合せるらしい
# 組合せる	様態	組合せるそう
# 組合せる	伝聞	組合せるそうだ
# 組合せる	例示	組合せるようだ
# 組合せる	勧誘	組合せよう
# 組合せる	自分の希望	組合せたい
# 組合せる	他人の希望	組合せたがる
# 組合せる	て	組合せて
# 組合せる	です・ます	組合せます
# 子音動詞マ行
# 組む	可能	組める
# 組む	受け身	組まれる
# 組む	使役	組ませる
# 組む	過去	組んだ
# 組む	否定	組まない
# 組む	推定	組むらしい
# 組む	様態	組むそう
# 組む	伝聞	組むそうだ
# 組む	例示	組むようだ
# 組む	勧誘	組もう
# 組む	自分の希望	組みたい
# 組む	他人の希望	組みたがる
# 組む	て	組んて
# 組む	です・ます	組みます
# 子音動詞マ行
# くむ	可能	くめる
# くむ	受け身	くまれる
# くむ	使役	くませる
# くむ	過去	くんだ
# くむ	否定	くまない
# くむ	推定	くむらしい
# くむ	様態	くむそう
# くむ	伝聞	くむそうだ
# くむ	例示	くむようだ
# くむ	勧誘	くもう
# くむ	自分の希望	くみたい
# くむ	他人の希望	くみたがる
# くむ	て	くんて
# くむ	です・ます	くみます
# 子音動詞マ行
# 悔やむ	可能	悔やめる
# 悔やむ	受け身	悔やまれる
# 悔やむ	使役	悔やませる
# 悔やむ	過去	悔やんだ
# 悔やむ	否定	悔やまない
# 悔やむ	推定	悔やむらしい
# 悔やむ	様態	悔やむそう
# 悔やむ	伝聞	悔やむそうだ
# 悔やむ	例示	悔やむようだ
# 悔やむ	勧誘	悔やもう
# 悔やむ	自分の希望	悔やみたい
# 悔やむ	他人の希望	悔やみたがる
# 悔やむ	て	悔やんて
# 悔やむ	です・ます	悔やみます
# 子音動詞ワ行
# 食らう	可能	食らえる
# 食らう	受け身	食らわれる
# 食らう	使役	食らわせる
# 食らう	過去	食らった
# 食らう	否定	食らわない
# 食らう	推定	食らうらしい
# 食らう	様態	食らうそう
# 食らう	伝聞	食らうそうだ
# 食らう	例示	食らうようだ
# 食らう	勧誘	食らおう
# 食らう	自分の希望	食らいたい
# 食らう	他人の希望	食らいたがる
# 食らう	て	食らって
# 食らう	です・ます	食らいます
# 子音動詞サ行
# 暮らす	可能	暮らせる
# 暮らす	受け身	暮らされる
# 暮らす	使役	暮らさせる
# 暮らす	過去	暮らした
# 暮らす	否定	暮らさない
# 暮らす	推定	暮らすらしい
# 暮らす	様態	暮らすそう
# 暮らす	伝聞	暮らすそうだ
# 暮らす	例示	暮らすようだ
# 暮らす	勧誘	暮らそう
# 暮らす	自分の希望	暮らしたい
# 暮らす	他人の希望	暮らしたがる
# 暮らす	て	暮らして
# 暮らす	です・ます	暮らします
# 母音動詞
# 比べる	可能	比べれる
# 比べる	受け身	比べられる
# 比べる	使役	比べさせる
# 比べる	過去	比べた
# 比べる	否定	比べない
# 比べる	推定	比べるらしい
# 比べる	様態	比べるそう
# 比べる	伝聞	比べるそうだ
# 比べる	例示	比べるようだ
# 比べる	勧誘	比べよう
# 比べる	自分の希望	比べたい
# 比べる	他人の希望	比べたがる
# 比べる	て	比べて
# 比べる	です・ます	比べます
# 子音動詞サ行
# 繰り返す	可能	繰り返せる
# 繰り返す	受け身	繰り返される
# 繰り返す	使役	繰り返させる
# 繰り返す	過去	繰り返した
# 繰り返す	否定	繰り返さない
# 繰り返す	推定	繰り返すらしい
# 繰り返す	様態	繰り返すそう
# 繰り返す	伝聞	繰り返すそうだ
# 繰り返す	例示	繰り返すようだ
# 繰り返す	勧誘	繰り返そう
# 繰り返す	自分の希望	繰り返したい
# 繰り返す	他人の希望	繰り返したがる
# 繰り返す	て	繰り返して
# 繰り返す	です・ます	繰り返します
# カ変動詞
# くる	可能	くるこる
# くる	受け身	くるこられる
# くる	使役	くるこさせる
# くる	過去	くるきた
# くる	否定	くるこない
# くる	推定	くるくるらしい
# くる	様態	くるくるそう
# くる	伝聞	くるくるそうだ
# くる	例示	くるくるようだ
# くる	勧誘	くるこよう
# くる	自分の希望	くるきたい
# くる	他人の希望	くるきたがる
# くる	て	くるきて
# くる	です・ます	くる
# 子音動詞ワ行
# 狂う	可能	狂える
# 狂う	受け身	狂われる
# 狂う	使役	狂わせる
# 狂う	過去	狂った
# 狂う	否定	狂わない
# 狂う	推定	狂うらしい
# 狂う	様態	狂うそう
# 狂う	伝聞	狂うそうだ
# 狂う	例示	狂うようだ
# 狂う	勧誘	狂おう
# 狂う	自分の希望	狂いたい
# 狂う	他人の希望	狂いたがる
# 狂う	て	狂って
# 狂う	です・ます	狂います
# 子音動詞マ行
# 苦しむ	可能	苦しめる
# 苦しむ	受け身	苦しまれる
# 苦しむ	使役	苦しませる
# 苦しむ	過去	苦しんだ
# 苦しむ	否定	苦しまない
# 苦しむ	推定	苦しむらしい
# 苦しむ	様態	苦しむそう
# 苦しむ	伝聞	苦しむそうだ
# 苦しむ	例示	苦しむようだ
# 苦しむ	勧誘	苦しもう
# 苦しむ	自分の希望	苦しみたい
# 苦しむ	他人の希望	苦しみたがる
# 苦しむ	て	苦しんて
# 苦しむ	です・ます	苦しみます
# 母音動詞
# 加える	可能	加えれる
# 加える	受け身	加えられる
# 加える	使役	加えさせる
# 加える	過去	加えた
# 加える	否定	加えない
# 加える	推定	加えるらしい
# 加える	様態	加えるそう
# 加える	伝聞	加えるそうだ
# 加える	例示	加えるようだ
# 加える	勧誘	加えよう
# 加える	自分の希望	加えたい
# 加える	他人の希望	加えたがる
# 加える	て	加えて
# 加える	です・ます	加えます
# 母音動詞
# れる	可能	食われれる
# れる	受け身	食われられる
# れる	使役	食われさせる
# れる	過去	食われた
# れる	否定	食われない
# れる	推定	食われるらしい
# れる	様態	食われるそう
# れる	伝聞	食われるそうだ
# れる	例示	食われるようだ
# れる	勧誘	食われよう
# れる	自分の希望	食われたい
# れる	他人の希望	食われたがる
# れる	て	食われて
# れる	です・ます	食われます
# 子音動詞ラ行
# 加わる	可能	加われる
# 加わる	受け身	加わられる
# 加わる	使役	加わらせる
# 加わる	過去	加わった
# 加わる	否定	加わらない
# 加わる	推定	加わるらしい
# 加わる	様態	加わるそう
# 加わる	伝聞	加わるそうだ
# 加わる	例示	加わるようだ
# 加わる	勧誘	加わろう
# 加わる	自分の希望	加わりたい
# 加わる	他人の希望	加わりたがる
# 加わる	て	加わって
# 加わる	です・ます	加わります
# 子音動詞ラ行
# 蹴る	可能	蹴れる
# 蹴る	受け身	蹴られる
# 蹴る	使役	蹴らせる
# 蹴る	過去	蹴った
# 蹴る	否定	蹴らない
# 蹴る	推定	蹴るらしい
# 蹴る	様態	蹴るそう
# 蹴る	伝聞	蹴るそうだ
# 蹴る	例示	蹴るようだ
# 蹴る	勧誘	蹴ろう
# 蹴る	自分の希望	蹴りたい
# 蹴る	他人の希望	蹴りたがる
# 蹴る	て	蹴って
# 蹴る	です・ます	蹴ります
# 母音動詞
# 超える	可能	超えれる
# 超える	受け身	超えられる
# 超える	使役	超えさせる
# 超える	過去	超えた
# 超える	否定	超えない
# 超える	推定	超えるらしい
# 超える	様態	超えるそう
# 超える	伝聞	超えるそうだ
# 超える	例示	超えるようだ
# 超える	勧誘	超えよう
# 超える	自分の希望	超えたい
# 超える	他人の希望	超えたがる
# 超える	て	超えて
# 超える	です・ます	超えます
# 母音動詞
# 越える	可能	越えれる
# 越える	受け身	越えられる
# 越える	使役	越えさせる
# 越える	過去	越えた
# 越える	否定	越えない
# 越える	推定	越えるらしい
# 越える	様態	越えるそう
# 越える	伝聞	越えるそうだ
# 越える	例示	越えるようだ
# 越える	勧誘	越えよう
# 越える	自分の希望	越えたい
# 越える	他人の希望	越えたがる
# 越える	て	越えて
# 越える	です・ます	越えます
# 子音動詞ラ行
# 凍る	可能	凍れる
# 凍る	受け身	凍られる
# 凍る	使役	凍らせる
# 凍る	過去	凍った
# 凍る	否定	凍らない
# 凍る	推定	凍るらしい
# 凍る	様態	凍るそう
# 凍る	伝聞	凍るそうだ
# 凍る	例示	凍るようだ
# 凍る	勧誘	凍ろう
# 凍る	自分の希望	凍りたい
# 凍る	他人の希望	凍りたがる
# 凍る	て	凍って
# 凍る	です・ます	凍ります
# 母音動詞
# 焦げる	可能	焦げれる
# 焦げる	受け身	焦げられる
# 焦げる	使役	焦げさせる
# 焦げる	過去	焦げた
# 焦げる	否定	焦げない
# 焦げる	推定	焦げるらしい
# 焦げる	様態	焦げるそう
# 焦げる	伝聞	焦げるそうだ
# 焦げる	例示	焦げるようだ
# 焦げる	勧誘	焦げよう
# 焦げる	自分の希望	焦げたい
# 焦げる	他人の希望	焦げたがる
# 焦げる	て	焦げて
# 焦げる	です・ます	焦げます
# 母音動詞
# 試みる	可能	試みれる
# 試みる	受け身	試みられる
# 試みる	使役	試みさせる
# 試みる	過去	試みた
# 試みる	否定	試みない
# 試みる	推定	試みるらしい
# 試みる	様態	試みるそう
# 試みる	伝聞	試みるそうだ
# 試みる	例示	試みるようだ
# 試みる	勧誘	試みよう
# 試みる	自分の希望	試みたい
# 試みる	他人の希望	試みたがる
# 試みる	て	試みて
# 試みる	です・ます	試みます
# 子音動詞サ行
# 越す	可能	越せる
# 越す	受け身	越される
# 越す	使役	越させる
# 越す	過去	越した
# 越す	否定	越さない
# 越す	推定	越すらしい
# 越す	様態	越すそう
# 越す	伝聞	越すそうだ
# 越す	例示	越すようだ
# 越す	勧誘	越そう
# 越す	自分の希望	越したい
# 越す	他人の希望	越したがる
# 越す	て	越して
# 越す	です・ます	越します
# 子音動詞サ行
# 超す	可能	超せる
# 超す	受け身	超される
# 超す	使役	超させる
# 超す	過去	超した
# 超す	否定	超さない
# 超す	推定	超すらしい
# 超す	様態	超すそう
# 超す	伝聞	超すそうだ
# 超す	例示	超すようだ
# 超す	勧誘	超そう
# 超す	自分の希望	超したい
# 超す	他人の希望	超したがる
# 超す	て	超して
# 超す	です・ます	超します
# 母音動詞
# こたえる	可能	こたえれる
# こたえる	受け身	こたえられる
# こたえる	使役	こたえさせる
# こたえる	過去	こたえた
# こたえる	否定	こたえない
# こたえる	推定	こたえるらしい
# こたえる	様態	こたえるそう
# こたえる	伝聞	こたえるそうだ
# こたえる	例示	こたえるようだ
# こたえる	勧誘	こたえよう
# こたえる	自分の希望	こたえたい
# こたえる	他人の希望	こたえたがる
# こたえる	て	こたえて
# こたえる	です・ます	こたえます
# 子音動詞ラ行
# こだわる	可能	こだわれる
# こだわる	受け身	こだわられる
# こだわる	使役	こだわらせる
# こだわる	過去	こだわった
# こだわる	否定	こだわらない
# こだわる	推定	こだわるらしい
# こだわる	様態	こだわるそう
# こだわる	伝聞	こだわるそうだ
# こだわる	例示	こだわるようだ
# こだわる	勧誘	こだわろう
# こだわる	自分の希望	こだわりたい
# こだわる	他人の希望	こだわりたがる
# こだわる	て	こだわって
# こだわる	です・ます	こだわります
# 子音動詞ラ行
# 異なる	可能	異なれる
# 異なる	受け身	異なられる
# 異なる	使役	異ならせる
# 異なる	過去	異なった
# 異なる	否定	異ならない
# 異なる	推定	異なるらしい
# 異なる	様態	異なるそう
# 異なる	伝聞	異なるそうだ
# 異なる	例示	異なるようだ
# 異なる	勧誘	異なろう
# 異なる	自分の希望	異なりたい
# 異なる	他人の希望	異なりたがる
# 異なる	て	異なって
# 異なる	です・ます	異なります
# 子音動詞ラ行
# 断る	可能	断れる
# 断る	受け身	断られる
# 断る	使役	断らせる
# 断る	過去	断った
# 断る	否定	断らない
# 断る	推定	断るらしい
# 断る	様態	断るそう
# 断る	伝聞	断るそうだ
# 断る	例示	断るようだ
# 断る	勧誘	断ろう
# 断る	自分の希望	断りたい
# 断る	他人の希望	断りたがる
# 断る	て	断って
# 断る	です・ます	断ります
# 子音動詞マ行
# 好む	可能	好める
# 好む	受け身	好まれる
# 好む	使役	好ませる
# 好む	過去	好んだ
# 好む	否定	好まない
# 好む	推定	好むらしい
# 好む	様態	好むそう
# 好む	伝聞	好むそうだ
# 好む	例示	好むようだ
# 好む	勧誘	好もう
# 好む	自分の希望	好みたい
# 好む	他人の希望	好みたがる
# 好む	て	好んて
# 好む	です・ます	好みます
# 子音動詞サ行
# こぼす	可能	こぼせる
# こぼす	受け身	こぼされる
# こぼす	使役	こぼさせる
# こぼす	過去	こぼした
# こぼす	否定	こぼさない
# こぼす	推定	こぼすらしい
# こぼす	様態	こぼすそう
# こぼす	伝聞	こぼすそうだ
# こぼす	例示	こぼすようだ
# こぼす	勧誘	こぼそう
# こぼす	自分の希望	こぼしたい
# こぼす	他人の希望	こぼしたがる
# こぼす	て	こぼして
# こぼす	です・ます	こぼします
# 子音動詞サ行
# ごまかす	可能	ごまかせる
# ごまかす	受け身	ごまかされる
# ごまかす	使役	ごまかさせる
# ごまかす	過去	ごまかした
# ごまかす	否定	ごまかさない
# ごまかす	推定	ごまかすらしい
# ごまかす	様態	ごまかすそう
# ごまかす	伝聞	ごまかすそうだ
# ごまかす	例示	ごまかすようだ
# ごまかす	勧誘	ごまかそう
# ごまかす	自分の希望	ごまかしたい
# ごまかす	他人の希望	ごまかしたがる
# ごまかす	て	ごまかして
# ごまかす	です・ます	ごまかします
# 母音動詞
# 込める	可能	込めれる
# 込める	受け身	込められる
# 込める	使役	込めさせる
# 込める	過去	込めた
# 込める	否定	込めない
# 込める	推定	込めるらしい
# 込める	様態	込めるそう
# 込める	伝聞	込めるそうだ
# 込める	例示	込めるようだ
# 込める	勧誘	込めよう
# 込める	自分の希望	込めたい
# 込める	他人の希望	込めたがる
# 込める	て	込めて
# 込める	です・ます	込めます
# 子音動詞ラ行
# こる	可能	これる
# こる	受け身	こられる
# こる	使役	こらせる
# こる	過去	こった
# こる	否定	こらない
# こる	推定	こるらしい
# こる	様態	こるそう
# こる	伝聞	こるそうだ
# こる	例示	こるようだ
# こる	勧誘	ころう
# こる	自分の希望	こりたい
# こる	他人の希望	こりたがる
# こる	て	こって
# こる	です・ます	こります
# 子音動詞サ行
# 転がす	可能	転がせる
# 転がす	受け身	転がされる
# 転がす	使役	転がさせる
# 転がす	過去	転がした
# 転がす	否定	転がさない
# 転がす	推定	転がすらしい
# 転がす	様態	転がすそう
# 転がす	伝聞	転がすそうだ
# 転がす	例示	転がすようだ
# 転がす	勧誘	転がそう
# 転がす	自分の希望	転がしたい
# 転がす	他人の希望	転がしたがる
# 転がす	て	転がして
# 転がす	です・ます	転がします
# 子音動詞ラ行
# 転がる	可能	転がれる
# 転がる	受け身	転がられる
# 転がる	使役	転がらせる
# 転がる	過去	転がった
# 転がる	否定	転がらない
# 転がる	推定	転がるらしい
# 転がる	様態	転がるそう
# 転がる	伝聞	転がるそうだ
# 転がる	例示	転がるようだ
# 転がる	勧誘	転がろう
# 転がる	自分の希望	転がりたい
# 転がる	他人の希望	転がりたがる
# 転がる	て	転がって
# 転がる	です・ます	転がります
# 子音動詞サ行
# 殺す	可能	殺せる
# 殺す	受け身	殺される
# 殺す	使役	殺させる
# 殺す	過去	殺した
# 殺す	否定	殺さない
# 殺す	推定	殺すらしい
# 殺す	様態	殺すそう
# 殺す	伝聞	殺すそうだ
# 殺す	例示	殺すようだ
# 殺す	勧誘	殺そう
# 殺す	自分の希望	殺したい
# 殺す	他人の希望	殺したがる
# 殺す	て	殺して
# 殺す	です・ます	殺します
# 子音動詞バ行
# 転ぶ	可能	転べる
# 転ぶ	受け身	転ばれる
# 転ぶ	使役	転ばせる
# 転ぶ	過去	転んだ
# 転ぶ	否定	転ばない
# 転ぶ	推定	転ぶらしい
# 転ぶ	様態	転ぶそう
# 転ぶ	伝聞	転ぶそうだ
# 転ぶ	例示	転ぶようだ
# 転ぶ	勧誘	転ぼう
# 転ぶ	自分の希望	転びたい
# 転ぶ	他人の希望	転びたがる
# 転ぶ	て	転んて
# 転ぶ	です・ます	転びます
# サ変動詞
# 際する	可能	際できる
# 際する	受け身	際される
# 際する	使役	際させる
# 際する	過去	際した
# 際する	否定	際しない
# 際する	推定	際するらしい
# 際する	様態	際するそう
# 際する	伝聞	際するそうだ
# 際する	例示	際するようだ
# 際する	勧誘	際しよう
# 際する	自分の希望	際したい
# 際する	他人の希望	際したがる
# 際する	て	際して
# 際する	です・ます	際します
# 子音動詞バ行
# 叫ぶ	可能	叫べる
# 叫ぶ	受け身	叫ばれる
# 叫ぶ	使役	叫ばせる
# 叫ぶ	過去	叫んだ
# 叫ぶ	否定	叫ばない
# 叫ぶ	推定	叫ぶらしい
# 叫ぶ	様態	叫ぶそう
# 叫ぶ	伝聞	叫ぶそうだ
# 叫ぶ	例示	叫ぶようだ
# 叫ぶ	勧誘	叫ぼう
# 叫ぶ	自分の希望	叫びたい
# 叫ぶ	他人の希望	叫びたがる
# 叫ぶ	て	叫んて
# 叫ぶ	です・ます	叫びます
# 母音動詞
# 支える	可能	支えれる
# 支える	受け身	支えられる
# 支える	使役	支えさせる
# 支える	過去	支えた
# 支える	否定	支えない
# 支える	推定	支えるらしい
# 支える	様態	支えるそう
# 支える	伝聞	支えるそうだ
# 支える	例示	支えるようだ
# 支える	勧誘	支えよう
# 支える	自分の希望	支えたい
# 支える	他人の希望	支えたがる
# 支える	て	支えて
# 支える	です・ます	支えます
# 子音動詞カ行
# ささやく	可能	ささやける
# ささやく	受け身	ささやかれる
# ささやく	使役	ささやかせる
# ささやく	過去	ささやいた
# ささやく	否定	ささやかない
# ささやく	推定	ささやくらしい
# ささやく	様態	ささやくそう
# ささやく	伝聞	ささやくそうだ
# ささやく	例示	ささやくようだ
# ささやく	勧誘	ささやこう
# ささやく	自分の希望	ささやきたい
# ささやく	他人の希望	ささやきたがる
# ささやく	て	ささやいて
# ささやく	です・ます	ささやきます
# 子音動詞ラ行
# 刺さる	可能	刺される
# 刺さる	受け身	刺さられる
# 刺さる	使役	刺さらせる
# 刺さる	過去	刺さった
# 刺さる	否定	刺さらない
# 刺さる	推定	刺さるらしい
# 刺さる	様態	刺さるそう
# 刺さる	伝聞	刺さるそうだ
# 刺さる	例示	刺さるようだ
# 刺さる	勧誘	刺さろう
# 刺さる	自分の希望	刺さりたい
# 刺さる	他人の希望	刺さりたがる
# 刺さる	て	刺さって
# 刺さる	です・ます	刺さります
# 子音動詞サ行
# 指す	可能	指せる
# 指す	受け身	指される
# 指す	使役	指させる
# 指す	過去	指した
# 指す	否定	指さない
# 指す	推定	指すらしい
# 指す	様態	指すそう
# 指す	伝聞	指すそうだ
# 指す	例示	指すようだ
# 指す	勧誘	指そう
# 指す	自分の希望	指したい
# 指す	他人の希望	指したがる
# 指す	て	指して
# 指す	です・ます	指します
# 子音動詞サ行
# 刺す	可能	刺せる
# 刺す	受け身	刺される
# 刺す	使役	刺させる
# 刺す	過去	刺した
# 刺す	否定	刺さない
# 刺す	推定	刺すらしい
# 刺す	様態	刺すそう
# 刺す	伝聞	刺すそうだ
# 刺す	例示	刺すようだ
# 刺す	勧誘	刺そう
# 刺す	自分の希望	刺したい
# 刺す	他人の希望	刺したがる
# 刺す	て	刺して
# 刺す	です・ます	刺します
# 子音動詞ラ行
# さぼる	可能	さぼれる
# さぼる	受け身	さぼられる
# さぼる	使役	さぼらせる
# さぼる	過去	さぼった
# さぼる	否定	さぼらない
# さぼる	推定	さぼるらしい
# さぼる	様態	さぼるそう
# さぼる	伝聞	さぼるそうだ
# さぼる	例示	さぼるようだ
# さぼる	勧誘	さぼろう
# さぼる	自分の希望	さぼりたい
# さぼる	他人の希望	さぼりたがる
# さぼる	て	さぼって
# さぼる	です・ます	さぼります
# サ変動詞
# 左右する	可能	左右できる
# 左右する	受け身	左右される
# 左右する	使役	左右させる
# 左右する	過去	左右した
# 左右する	否定	左右しない
# 左右する	推定	左右するらしい
# 左右する	様態	左右するそう
# 左右する	伝聞	左右するそうだ
# 左右する	例示	左右するようだ
# 左右する	勧誘	左右しよう
# 左右する	自分の希望	左右したい
# 左右する	他人の希望	左右したがる
# 左右する	て	左右して
# 左右する	です・ます	左右します
# 子音動詞ガ行
# 騒ぐ	可能	騒げる
# 騒ぐ	受け身	騒がれる
# 騒ぐ	使役	騒がせる
# 騒ぐ	過去	騒いだ
# 騒ぐ	否定	騒がない
# 騒ぐ	推定	騒ぐらしい
# 騒ぐ	様態	騒ぐそう
# 騒ぐ	伝聞	騒ぐそうだ
# 騒ぐ	例示	騒ぐようだ
# 騒ぐ	勧誘	騒ごう
# 騒ぐ	自分の希望	騒ぎたい
# 騒ぐ	他人の希望	騒ぎたがる
# 騒ぐ	て	騒いて
# 騒ぐ	です・ます	騒ぎます
# 子音動詞ラ行
# 触る	可能	触れる
# 触る	受け身	触られる
# 触る	使役	触らせる
# 触る	過去	触った
# 触る	否定	触らない
# 触る	推定	触るらしい
# 触る	様態	触るそう
# 触る	伝聞	触るそうだ
# 触る	例示	触るようだ
# 触る	勧誘	触ろう
# 触る	自分の希望	触りたい
# 触る	他人の希望	触りたがる
# 触る	て	触って
# 触る	です・ます	触ります
# 子音動詞ラ行
# 仕上がる	可能	仕上がれる
# 仕上がる	受け身	仕上がられる
# 仕上がる	使役	仕上がらせる
# 仕上がる	過去	仕上がった
# 仕上がる	否定	仕上がらない
# 仕上がる	推定	仕上がるらしい
# 仕上がる	様態	仕上がるそう
# 仕上がる	伝聞	仕上がるそうだ
# 仕上がる	例示	仕上がるようだ
# 仕上がる	勧誘	仕上がろう
# 仕上がる	自分の希望	仕上がりたい
# 仕上がる	他人の希望	仕上がりたがる
# 仕上がる	て	仕上がって
# 仕上がる	です・ます	仕上がります
# 母音動詞
# 仕上げる	可能	仕上げれる
# 仕上げる	受け身	仕上げられる
# 仕上げる	使役	仕上げさせる
# 仕上げる	過去	仕上げた
# 仕上げる	否定	仕上げない
# 仕上げる	推定	仕上げるらしい
# 仕上げる	様態	仕上げるそう
# 仕上げる	伝聞	仕上げるそうだ
# 仕上げる	例示	仕上げるようだ
# 仕上げる	勧誘	仕上げよう
# 仕上げる	自分の希望	仕上げたい
# 仕上げる	他人の希望	仕上げたがる
# 仕上げる	て	仕上げて
# 仕上げる	です・ます	仕上げます
# 母音動詞
# 強いる	可能	強いれる
# 強いる	受け身	強いられる
# 強いる	使役	強いさせる
# 強いる	過去	強いた
# 強いる	否定	強いない
# 強いる	推定	強いるらしい
# 強いる	様態	強いるそう
# 強いる	伝聞	強いるそうだ
# 強いる	例示	強いるようだ
# 強いる	勧誘	強いよう
# 強いる	自分の希望	強いたい
# 強いる	他人の希望	強いたがる
# 強いる	て	強いて
# 強いる	です・ます	強います
# 子音動詞マ行
# 沈む	可能	沈める
# 沈む	受け身	沈まれる
# 沈む	使役	沈ませる
# 沈む	過去	沈んだ
# 沈む	否定	沈まない
# 沈む	推定	沈むらしい
# 沈む	様態	沈むそう
# 沈む	伝聞	沈むそうだ
# 沈む	例示	沈むようだ
# 沈む	勧誘	沈もう
# 沈む	自分の希望	沈みたい
# 沈む	他人の希望	沈みたがる
# 沈む	て	沈んて
# 沈む	です・ます	沈みます
# 子音動詞ワ行
# 従う	可能	従える
# 従う	受け身	従われる
# 従う	使役	従わせる
# 従う	過去	従った
# 従う	否定	従わない
# 従う	推定	従うらしい
# 従う	様態	従うそう
# 従う	伝聞	従うそうだ
# 従う	例示	従うようだ
# 従う	勧誘	従おう
# 従う	自分の希望	従いたい
# 従う	他人の希望	従いたがる
# 従う	て	従って
# 従う	です・ます	従います
# 子音動詞マ行
# 親しむ	可能	親しめる
# 親しむ	受け身	親しまれる
# 親しむ	使役	親しませる
# 親しむ	過去	親しんだ
# 親しむ	否定	親しまない
# 親しむ	推定	親しむらしい
# 親しむ	様態	親しむそう
# 親しむ	伝聞	親しむそうだ
# 親しむ	例示	親しむようだ
# 親しむ	勧誘	親しもう
# 親しむ	自分の希望	親しみたい
# 親しむ	他人の希望	親しみたがる
# 親しむ	て	親しんて
# 親しむ	です・ます	親しみます
# 子音動詞ラ行
# 下回る	可能	下回れる
# 下回る	受け身	下回られる
# 下回る	使役	下回らせる
# 下回る	過去	下回った
# 下回る	否定	下回らない
# 下回る	推定	下回るらしい
# 下回る	様態	下回るそう
# 下回る	伝聞	下回るそうだ
# 下回る	例示	下回るようだ
# 下回る	勧誘	下回ろう
# 下回る	自分の希望	下回りたい
# 下回る	他人の希望	下回りたがる
# 下回る	て	下回って
# 下回る	です・ます	下回ります
# 母音動詞
# しつける	可能	しつけれる
# しつける	受け身	しつけられる
# しつける	使役	しつけさせる
# しつける	過去	しつけた
# しつける	否定	しつけない
# しつける	推定	しつけるらしい
# しつける	様態	しつけるそう
# しつける	伝聞	しつけるそうだ
# しつける	例示	しつけるようだ
# しつける	勧誘	しつけよう
# しつける	自分の希望	しつけたい
# しつける	他人の希望	しつけたがる
# しつける	て	しつけて
# しつける	です・ます	しつけます
# 子音動詞ワ行
# 支払う	可能	支払える
# 支払う	受け身	支払われる
# 支払う	使役	支払わせる
# 支払う	過去	支払った
# 支払う	否定	支払わない
# 支払う	推定	支払うらしい
# 支払う	様態	支払うそう
# 支払う	伝聞	支払うそうだ
# 支払う	例示	支払うようだ
# 支払う	勧誘	支払おう
# 支払う	自分の希望	支払いたい
# 支払う	他人の希望	支払いたがる
# 支払う	て	支払って
# 支払う	です・ます	支払います
# 子音動詞ラ行
# 縛る	可能	縛れる
# 縛る	受け身	縛られる
# 縛る	使役	縛らせる
# 縛る	過去	縛った
# 縛る	否定	縛らない
# 縛る	推定	縛るらしい
# 縛る	様態	縛るそう
# 縛る	伝聞	縛るそうだ
# 縛る	例示	縛るようだ
# 縛る	勧誘	縛ろう
# 縛る	自分の希望	縛りたい
# 縛る	他人の希望	縛りたがる
# 縛る	て	縛って
# 縛る	です・ます	縛ります
# 子音動詞ラ行
# 絞る	可能	絞れる
# 絞る	受け身	絞られる
# 絞る	使役	絞らせる
# 絞る	過去	絞った
# 絞る	否定	絞らない
# 絞る	推定	絞るらしい
# 絞る	様態	絞るそう
# 絞る	伝聞	絞るそうだ
# 絞る	例示	絞るようだ
# 絞る	勧誘	絞ろう
# 絞る	自分の希望	絞りたい
# 絞る	他人の希望	絞りたがる
# 絞る	て	絞って
# 絞る	です・ます	絞ります
# 子音動詞ワ行
# しまう	可能	しまえる
# しまう	受け身	しまわれる
# しまう	使役	しまわせる
# しまう	過去	しまった
# しまう	否定	しまわない
# しまう	推定	しまうらしい
# しまう	様態	しまうそう
# しまう	伝聞	しまうそうだ
# しまう	例示	しまうようだ
# しまう	勧誘	しまおう
# しまう	自分の希望	しまいたい
# しまう	他人の希望	しまいたがる
# しまう	て	しまって
# しまう	です・ます	しまう
# 子音動詞ラ行
# 締め切る	可能	締め切れる
# 締め切る	受け身	締め切られる
# 締め切る	使役	締め切らせる
# 締め切る	過去	締め切った
# 締め切る	否定	締め切らない
# 締め切る	推定	締め切るらしい
# 締め切る	様態	締め切るそう
# 締め切る	伝聞	締め切るそうだ
# 締め切る	例示	締め切るようだ
# 締め切る	勧誘	締め切ろう
# 締め切る	自分の希望	締め切りたい
# 締め切る	他人の希望	締め切りたがる
# 締め切る	て	締め切って
# 締め切る	です・ます	締め切ります
# 子音動詞サ行
# 示す	可能	示せる
# 示す	受け身	示される
# 示す	使役	示させる
# 示す	過去	示した
# 示す	否定	示さない
# 示す	推定	示すらしい
# 示す	様態	示すそう
# 示す	伝聞	示すそうだ
# 示す	例示	示すようだ
# 示す	勧誘	示そう
# 示す	自分の希望	示したい
# 示す	他人の希望	示したがる
# 示す	て	示して
# 示す	です・ます	示します
# 子音動詞ラ行
# 湿る	可能	湿れる
# 湿る	受け身	湿られる
# 湿る	使役	湿らせる
# 湿る	過去	湿った
# 湿る	否定	湿らない
# 湿る	推定	湿るらしい
# 湿る	様態	湿るそう
# 湿る	伝聞	湿るそうだ
# 湿る	例示	湿るようだ
# 湿る	勧誘	湿ろう
# 湿る	自分の希望	湿りたい
# 湿る	他人の希望	湿りたがる
# 湿る	て	湿って
# 湿る	です・ます	湿ります
# 母音動詞
# 占める	可能	占めれる
# 占める	受け身	占められる
# 占める	使役	占めさせる
# 占める	過去	占めた
# 占める	否定	占めない
# 占める	推定	占めるらしい
# 占める	様態	占めるそう
# 占める	伝聞	占めるそうだ
# 占める	例示	占めるようだ
# 占める	勧誘	占めよう
# 占める	自分の希望	占めたい
# 占める	他人の希望	占めたがる
# 占める	て	占めて
# 占める	です・ます	占めます
# 子音動詞マ行
# しゃがむ	可能	しゃがめる
# しゃがむ	受け身	しゃがまれる
# しゃがむ	使役	しゃがませる
# しゃがむ	過去	しゃがんだ
# しゃがむ	否定	しゃがまない
# しゃがむ	推定	しゃがむらしい
# しゃがむ	様態	しゃがむそう
# しゃがむ	伝聞	しゃがむそうだ
# しゃがむ	例示	しゃがむようだ
# しゃがむ	勧誘	しゃがもう
# しゃがむ	自分の希望	しゃがみたい
# しゃがむ	他人の希望	しゃがみたがる
# しゃがむ	て	しゃがんて
# しゃがむ	です・ます	しゃがみます
# 子音動詞ラ行
# しゃべる	可能	しゃべれる
# しゃべる	受け身	しゃべられる
# しゃべる	使役	しゃべらせる
# しゃべる	過去	しゃべった
# しゃべる	否定	しゃべらない
# しゃべる	推定	しゃべるらしい
# しゃべる	様態	しゃべるそう
# しゃべる	伝聞	しゃべるそうだ
# しゃべる	例示	しゃべるようだ
# しゃべる	勧誘	しゃべろう
# しゃべる	自分の希望	しゃべりたい
# しゃべる	他人の希望	しゃべりたがる
# しゃべる	て	しゃべって
# しゃべる	です・ます	しゃべります
# 母音動詞
# 生じる	可能	生じれる
# 生じる	受け身	生じられる
# 生じる	使役	生じさせる
# 生じる	過去	生じた
# 生じる	否定	生じない
# 生じる	推定	生じるらしい
# 生じる	様態	生じるそう
# 生じる	伝聞	生じるそうだ
# 生じる	例示	生じるようだ
# 生じる	勧誘	生じよう
# 生じる	自分の希望	生じたい
# 生じる	他人の希望	生じたがる
# 生じる	て	生じて
# 生じる	です・ます	生じます
# イ形容詞アウオ段
# ない	可能	すぎなかろる
# ない	受け身	すぎなかろられる
# ない	使役	すぎなかろさせる
# ない	過去	すぎなかった
# ない	否定	すぎなくない
# ない	推定	すぎないらしい
# ない	様態	すぎないそう
# ない	伝聞	すぎないそうだ
# ない	例示	すぎないようだ
# ない	勧誘	すぎなかろう
# ない	自分の希望	すぎなくたい
# ない	他人の希望	すぎなくたがる
# ない	て	すぎなかって
# ない	です・ます	すぎないです
# イ形容詞アウオ段
# 好い	可能	好く好かろる
# 好い	受け身	好く好かろられる
# 好い	使役	好く好かろさせる
# 好い	過去	好く好かった
# 好い	否定	好く好くない
# 好い	推定	好く好いらしい
# 好い	様態	好く好いそう
# 好い	伝聞	好く好いそうだ
# 好い	例示	好く好いようだ
# 好い	勧誘	好く好かろう
# 好い	自分の希望	好く好くたい
# 好い	他人の希望	好く好くたがる
# 好い	て	好く好かって
# 好い	です・ます	好く好いです
# 子音動詞ワ行
# 救う	可能	救える
# 救う	受け身	救われる
# 救う	使役	救わせる
# 救う	過去	救った
# 救う	否定	救わない
# 救う	推定	救うらしい
# 救う	様態	救うそう
# 救う	伝聞	救うそうだ
# 救う	例示	救うようだ
# 救う	勧誘	救おう
# 救う	自分の希望	救いたい
# 救う	他人の希望	救いたがる
# 救う	て	救って
# 救う	です・ます	救います
# 子音動詞サ行
# 過ごす	可能	過ごせる
# 過ごす	受け身	過ごされる
# 過ごす	使役	過ごさせる
# 過ごす	過去	過ごした
# 過ごす	否定	過ごさない
# 過ごす	推定	過ごすらしい
# 過ごす	様態	過ごすそう
# 過ごす	伝聞	過ごすそうだ
# 過ごす	例示	過ごすようだ
# 過ごす	勧誘	過ごそう
# 過ごす	自分の希望	過ごしたい
# 過ごす	他人の希望	過ごしたがる
# 過ごす	て	過ごして
# 過ごす	です・ます	過ごします
# 子音動詞マ行
# 進む	可能	進める
# 進む	受け身	進まれる
# 進む	使役	進ませる
# 進む	過去	進んだ
# 進む	否定	進まない
# 進む	推定	進むらしい
# 進む	様態	進むそう
# 進む	伝聞	進むそうだ
# 進む	例示	進むようだ
# 進む	勧誘	進もう
# 進む	自分の希望	進みたい
# 進む	他人の希望	進みたがる
# 進む	て	進んて
# 進む	です・ます	進みます
# 母音動詞
# 進める	可能	進めれる
# 進める	受け身	進められる
# 進める	使役	進めさせる
# 進める	過去	進めた
# 進める	否定	進めない
# 進める	推定	進めるらしい
# 進める	様態	進めるそう
# 進める	伝聞	進めるそうだ
# 進める	例示	進めるようだ
# 進める	勧誘	進めよう
# 進める	自分の希望	進めたい
# 進める	他人の希望	進めたがる
# 進める	て	進めて
# 進める	です・ます	進めます
# 母音動詞
# 勧める	可能	勧めれる
# 勧める	受け身	勧められる
# 勧める	使役	勧めさせる
# 勧める	過去	勧めた
# 勧める	否定	勧めない
# 勧める	推定	勧めるらしい
# 勧める	様態	勧めるそう
# 勧める	伝聞	勧めるそうだ
# 勧める	例示	勧めるようだ
# 勧める	勧誘	勧めよう
# 勧める	自分の希望	勧めたい
# 勧める	他人の希望	勧めたがる
# 勧める	て	勧めて
# 勧める	です・ます	勧めます
# 子音動詞ラ行
# 滑る	可能	滑れる
# 滑る	受け身	滑られる
# 滑る	使役	滑らせる
# 滑る	過去	滑った
# 滑る	否定	滑らない
# 滑る	推定	滑るらしい
# 滑る	様態	滑るそう
# 滑る	伝聞	滑るそうだ
# 滑る	例示	滑るようだ
# 滑る	勧誘	滑ろう
# 滑る	自分の希望	滑りたい
# 滑る	他人の希望	滑りたがる
# 滑る	て	滑って
# 滑る	です・ます	滑ります
# 母音動詞
# 済ませる	可能	済ませれる
# 済ませる	受け身	済ませられる
# 済ませる	使役	済ませさせる
# 済ませる	過去	済ませた
# 済ませる	否定	済ませない
# 済ませる	推定	済ませるらしい
# 済ませる	様態	済ませるそう
# 済ませる	伝聞	済ませるそうだ
# 済ませる	例示	済ませるようだ
# 済ませる	勧誘	済ませよう
# 済ませる	自分の希望	済ませたい
# 済ませる	他人の希望	済ませたがる
# 済ませる	て	済ませて
# 済ませる	です・ます	済ませます
# 子音動詞マ行
# 済む	可能	済める
# 済む	受け身	済まれる
# 済む	使役	済ませる
# 済む	過去	済んだ
# 済む	否定	済まない
# 済む	推定	済むらしい
# 済む	様態	済むそう
# 済む	伝聞	済むそうだ
# 済む	例示	済むようだ
# 済む	勧誘	済もう
# 済む	自分の希望	済みたい
# 済む	他人の希望	済みたがる
# 済む	て	済んて
# 済む	です・ます	済みます
# 子音動詞サ行
# ずらす	可能	ずらせる
# ずらす	受け身	ずらされる
# ずらす	使役	ずらさせる
# ずらす	過去	ずらした
# ずらす	否定	ずらさない
# ずらす	推定	ずらすらしい
# ずらす	様態	ずらすそう
# ずらす	伝聞	ずらすそうだ
# ずらす	例示	ずらすようだ
# ずらす	勧誘	ずらそう
# ずらす	自分の希望	ずらしたい
# ずらす	他人の希望	ずらしたがる
# ずらす	て	ずらして
# ずらす	です・ます	ずらします
# 子音動詞ワ行
# すれ違う	可能	すれ違える
# すれ違う	受け身	すれ違われる
# すれ違う	使役	すれ違わせる
# すれ違う	過去	すれ違った
# すれ違う	否定	すれ違わない
# すれ違う	推定	すれ違うらしい
# すれ違う	様態	すれ違うそう
# すれ違う	伝聞	すれ違うそうだ
# すれ違う	例示	すれ違うようだ
# すれ違う	勧誘	すれ違おう
# すれ違う	自分の希望	すれ違いたい
# すれ違う	他人の希望	すれ違いたがる
# すれ違う	て	すれ違って
# すれ違う	です・ます	すれ違います
# サ変動詞
# 接する	可能	接できる
# 接する	受け身	接される
# 接する	使役	接させる
# 接する	過去	接した
# 接する	否定	接しない
# 接する	推定	接するらしい
# 接する	様態	接するそう
# 接する	伝聞	接するそうだ
# 接する	例示	接するようだ
# 接する	勧誘	接しよう
# 接する	自分の希望	接したい
# 接する	他人の希望	接したがる
# 接する	て	接して
# 接する	です・ます	接します
# 子音動詞ラ行
# 迫る	可能	迫れる
# 迫る	受け身	迫られる
# 迫る	使役	迫らせる
# 迫る	過去	迫った
# 迫る	否定	迫らない
# 迫る	推定	迫るらしい
# 迫る	様態	迫るそう
# 迫る	伝聞	迫るそうだ
# 迫る	例示	迫るようだ
# 迫る	勧誘	迫ろう
# 迫る	自分の希望	迫りたい
# 迫る	他人の希望	迫りたがる
# 迫る	て	迫って
# 迫る	です・ます	迫ります
# 母音動詞
# 攻める	可能	攻めれる
# 攻める	受け身	攻められる
# 攻める	使役	攻めさせる
# 攻める	過去	攻めた
# 攻める	否定	攻めない
# 攻める	推定	攻めるらしい
# 攻める	様態	攻めるそう
# 攻める	伝聞	攻めるそうだ
# 攻める	例示	攻めるようだ
# 攻める	勧誘	攻めよう
# 攻める	自分の希望	攻めたい
# 攻める	他人の希望	攻めたがる
# 攻める	て	攻めて
# 攻める	です・ます	攻めます
# 母音動詞
# 責める	可能	責めれる
# 責める	受け身	責められる
# 責める	使役	責めさせる
# 責める	過去	責めた
# 責める	否定	責めない
# 責める	推定	責めるらしい
# 責める	様態	責めるそう
# 責める	伝聞	責めるそうだ
# 責める	例示	責めるようだ
# 責める	勧誘	責めよう
# 責める	自分の希望	責めたい
# 責める	他人の希望	責めたがる
# 責める	て	責めて
# 責める	です・ます	責めます
# 子音動詞ワ行
# 沿う	可能	沿える
# 沿う	受け身	沿われる
# 沿う	使役	沿わせる
# 沿う	過去	沿った
# 沿う	否定	沿わない
# 沿う	推定	沿うらしい
# 沿う	様態	沿うそう
# 沿う	伝聞	沿うそうだ
# 沿う	例示	沿うようだ
# 沿う	勧誘	沿おう
# 沿う	自分の希望	沿いたい
# 沿う	他人の希望	沿いたがる
# 沿う	て	沿って
# 沿う	です・ます	沿います
# 子音動詞ワ行
# 添う	可能	添える
# 添う	受け身	添われる
# 添う	使役	添わせる
# 添う	過去	添った
# 添う	否定	添わない
# 添う	推定	添うらしい
# 添う	様態	添うそう
# 添う	伝聞	添うそうだ
# 添う	例示	添うようだ
# 添う	勧誘	添おう
# 添う	自分の希望	添いたい
# 添う	他人の希望	添いたがる
# 添う	て	添って
# 添う	です・ます	添います
# 母音動詞
# 添える	可能	添えれる
# 添える	受け身	添えられる
# 添える	使役	添えさせる
# 添える	過去	添えた
# 添える	否定	添えない
# 添える	推定	添えるらしい
# 添える	様態	添えるそう
# 添える	伝聞	添えるそうだ
# 添える	例示	添えるようだ
# 添える	勧誘	添えよう
# 添える	自分の希望	添えたい
# 添える	他人の希望	添えたがる
# 添える	て	添えて
# 添える	です・ます	添えます
# 子音動詞タ行
# 育つ	可能	育てる
# 育つ	受け身	育たれる
# 育つ	使役	育たせる
# 育つ	過去	育った
# 育つ	否定	育たない
# 育つ	推定	育つらしい
# 育つ	様態	育つそう
# 育つ	伝聞	育つそうだ
# 育つ	例示	育つようだ
# 育つ	勧誘	育とう
# 育つ	自分の希望	育ちたい
# 育つ	他人の希望	育ちたがる
# 育つ	て	育って
# 育つ	です・ます	育ちます
# 母音動詞
# 備える	可能	備えれる
# 備える	受け身	備えられる
# 備える	使役	備えさせる
# 備える	過去	備えた
# 備える	否定	備えない
# 備える	推定	備えるらしい
# 備える	様態	備えるそう
# 備える	伝聞	備えるそうだ
# 備える	例示	備えるようだ
# 備える	勧誘	備えよう
# 備える	自分の希望	備えたい
# 備える	他人の希望	備えたがる
# 備える	て	備えて
# 備える	です・ます	備えます
# 母音動詞
# 染める	可能	染めれる
# 染める	受け身	染められる
# 染める	使役	染めさせる
# 染める	過去	染めた
# 染める	否定	染めない
# 染める	推定	染めるらしい
# 染める	様態	染めるそう
# 染める	伝聞	染めるそうだ
# 染める	例示	染めるようだ
# 染める	勧誘	染めよう
# 染める	自分の希望	染めたい
# 染める	他人の希望	染めたがる
# 染める	て	染めて
# 染める	です・ます	染めます
# 母音動詞
# それる	可能	それれる
# それる	受け身	それられる
# それる	使役	それさせる
# それる	過去	それた
# それる	否定	それない
# それる	推定	それるらしい
# それる	様態	それるそう
# それる	伝聞	それるそうだ
# それる	例示	それるようだ
# それる	勧誘	それよう
# それる	自分の希望	それたい
# それる	他人の希望	それたがる
# それる	て	それて
# それる	です・ます	それます
# 子音動詞ラ行
# そる	可能	そろうそれる
# そる	受け身	そろうそられる
# そる	使役	そろうそらせる
# そる	過去	そろうそった
# そる	否定	そろうそらない
# そる	推定	そろうそるらしい
# そる	様態	そろうそるそう
# そる	伝聞	そろうそるそうだ
# ...
# 母音動詞
# ほどける	可能	ほどけれる
# ほどける	受け身	ほどけられる
# ほどける	使役	ほどけさせる
# ほどける	過去	ほどけた
# ほどける	否定	ほどけない
# ほどける	推定	ほどけるらしい
# ほどける	様態	ほどけるそう
# ほどける	伝聞	ほどけるそうだ
# ほどける	例示	ほどけるようだ
# ほどける	勧誘	ほどけよう
# ほどける	自分の希望	ほどけたい
# ほどける	他人の希望	ほどけたがる
# ほどける	て	ほどけて
# ほどける	です・ます	ほどけます
# 母音動詞
# ほめる	可能	ほめれる
# ほめる	受け身	ほめられる
# ほめる	使役	ほめさせる
# ほめる	過去	ほめた
# ほめる	否定	ほめない
# ほめる	推定	ほめるらしい
# ほめる	様態	ほめるそう
# ほめる	伝聞	ほめるそうだ
# ほめる	例示	ほめるようだ
# ほめる	勧誘	ほめよう
# ほめる	自分の希望	ほめたい
# ほめる	他人の希望	ほめたがる
# ほめる	て	ほめて
# ほめる	です・ます	ほめます
# 子音動詞ラ行
# 掘る	可能	掘れる
# 掘る	受け身	掘られる
# 掘る	使役	掘らせる
# 掘る	過去	掘った
# 掘る	否定	掘らない
# 掘る	推定	掘るらしい
# 掘る	様態	掘るそう
# 掘る	伝聞	掘るそうだ
# 掘る	例示	掘るようだ
# 掘る	勧誘	掘ろう
# 掘る	自分の希望	掘りたい
# 掘る	他人の希望	掘りたがる
# 掘る	て	掘って
# 掘る	です・ます	掘ります
# 母音動詞
# 任せる	可能	任せれる
# 任せる	受け身	任せられる
# 任せる	使役	任せさせる
# 任せる	過去	任せた
# 任せる	否定	任せない
# 任せる	推定	任せるらしい
# 任せる	様態	任せるそう
# 任せる	伝聞	任せるそうだ
# 任せる	例示	任せるようだ
# 任せる	勧誘	任せよう
# 任せる	自分の希望	任せたい
# 任せる	他人の希望	任せたがる
# 任せる	て	任せて
# 任せる	です・ます	任せます
# 子音動詞カ行
# 巻く	可能	巻ける
# 巻く	受け身	巻かれる
# 巻く	使役	巻かせる
# 巻く	過去	巻いた
# 巻く	否定	巻かない
# 巻く	推定	巻くらしい
# 巻く	様態	巻くそう
# 巻く	伝聞	巻くそうだ
# 巻く	例示	巻くようだ
# 巻く	勧誘	巻こう
# 巻く	自分の希望	巻きたい
# 巻く	他人の希望	巻きたがる
# 巻く	て	巻いて
# 巻く	です・ます	巻きます
# 母音動詞
# 交える	可能	交えれる
# 交える	受け身	交えられる
# 交える	使役	交えさせる
# 交える	過去	交えた
# 交える	否定	交えない
# 交える	推定	交えるらしい
# 交える	様態	交えるそう
# 交える	伝聞	交えるそうだ
# 交える	例示	交えるようだ
# 交える	勧誘	交えよう
# 交える	自分の希望	交えたい
# 交える	他人の希望	交えたがる
# 交える	て	交えて
# 交える	です・ます	交えます
# 子音動詞ラ行
# 混じる	可能	混じれる
# 混じる	受け身	混じられる
# 混じる	使役	混じらせる
# 混じる	過去	混じった
# 混じる	否定	混じらない
# 混じる	推定	混じるらしい
# 混じる	様態	混じるそう
# 混じる	伝聞	混じるそうだ
# 混じる	例示	混じるようだ
# 混じる	勧誘	混じろう
# 混じる	自分の希望	混じりたい
# 混じる	他人の希望	混じりたがる
# 混じる	て	混じって
# 混じる	です・ます	混じります
# 子音動詞サ行
# 増す	可能	増せる
# 増す	受け身	増される
# 増す	使役	増させる
# 増す	過去	増した
# 増す	否定	増さない
# 増す	推定	増すらしい
# 増す	様態	増すそう
# 増す	伝聞	増すそうだ
# 増す	例示	増すようだ
# 増す	勧誘	増そう
# 増す	自分の希望	増したい
# 増す	他人の希望	増したがる
# 増す	て	増して
# 増す	です・ます	増します
# 子音動詞ワ行
# 間違う	可能	間違える
# 間違う	受け身	間違われる
# 間違う	使役	間違わせる
# 間違う	過去	間違った
# 間違う	否定	間違わない
# 間違う	推定	間違うらしい
# 間違う	様態	間違うそう
# 間違う	伝聞	間違うそうだ
# 間違う	例示	間違うようだ
# 間違う	勧誘	間違おう
# 間違う	自分の希望	間違いたい
# 間違う	他人の希望	間違いたがる
# 間違う	て	間違って
# 間違う	です・ます	間違います
# 母音動詞
# 待ち構える	可能	待ち構えれる
# 待ち構える	受け身	待ち構えられる
# 待ち構える	使役	待ち構えさせる
# 待ち構える	過去	待ち構えた
# 待ち構える	否定	待ち構えない
# 待ち構える	推定	待ち構えるらしい
# 待ち構える	様態	待ち構えるそう
# 待ち構える	伝聞	待ち構えるそうだ
# 待ち構える	例示	待ち構えるようだ
# 待ち構える	勧誘	待ち構えよう
# 待ち構える	自分の希望	待ち構えたい
# 待ち構える	他人の希望	待ち構えたがる
# 待ち構える	て	待ち構えて
# 待ち構える	です・ます	待ち構えます
# 子音動詞バ行
# 学ぶ	可能	学べる
# 学ぶ	受け身	学ばれる
# 学ぶ	使役	学ばせる
# 学ぶ	過去	学んだ
# 学ぶ	否定	学ばない
# 学ぶ	推定	学ぶらしい
# 学ぶ	様態	学ぶそう
# 学ぶ	伝聞	学ぶそうだ
# 学ぶ	例示	学ぶようだ
# 学ぶ	勧誘	学ぼう
# 学ぶ	自分の希望	学びたい
# 学ぶ	他人の希望	学びたがる
# 学ぶ	て	学んて
# 学ぶ	です・ます	学びます
# 子音動詞カ行
# 招く	可能	招ける
# 招く	受け身	招かれる
# 招く	使役	招かせる
# 招く	過去	招いた
# 招く	否定	招かない
# 招く	推定	招くらしい
# 招く	様態	招くそう
# 招く	伝聞	招くそうだ
# 招く	例示	招くようだ
# 招く	勧誘	招こう
# 招く	自分の希望	招きたい
# 招く	他人の希望	招きたがる
# 招く	て	招いて
# 招く	です・ます	招きます
# 子音動詞ワ行
# 迷う	可能	迷える
# 迷う	受け身	迷われる
# 迷う	使役	迷わせる
# 迷う	過去	迷った
# 迷う	否定	迷わない
# 迷う	推定	迷うらしい
# 迷う	様態	迷うそう
# 迷う	伝聞	迷うそうだ
# 迷う	例示	迷うようだ
# 迷う	勧誘	迷おう
# 迷う	自分の希望	迷いたい
# 迷う	他人の希望	迷いたがる
# 迷う	て	迷って
# 迷う	です・ます	迷います
# 母音動詞
# 見上げる	可能	見上げれる
# 見上げる	受け身	見上げられる
# 見上げる	使役	見上げさせる
# 見上げる	過去	見上げた
# 見上げる	否定	見上げない
# 見上げる	推定	見上げるらしい
# 見上げる	様態	見上げるそう
# 見上げる	伝聞	見上げるそうだ
# 見上げる	例示	見上げるようだ
# 見上げる	勧誘	見上げよう
# 見上げる	自分の希望	見上げたい
# 見上げる	他人の希望	見上げたがる
# 見上げる	て	見上げて
# 見上げる	です・ます	見上げます
# 母音動詞
# 見える	可能	見えれる
# 見える	受け身	見えられる
# 見える	使役	見えさせる
# 見える	過去	見えた
# 見える	否定	見えない
# 見える	推定	見えるらしい
# 見える	様態	見えるそう
# 見える	伝聞	見えるそうだ
# 見える	例示	見えるようだ
# 見える	勧誘	見えよう
# 見える	自分の希望	見えたい
# 見える	他人の希望	見えたがる
# 見える	て	見えて
# 見える	です・ます	見えます
# 母音動詞
# 見かける	可能	見かけれる
# 見かける	受け身	見かけられる
# 見かける	使役	見かけさせる
# 見かける	過去	見かけた
# 見かける	否定	見かけない
# 見かける	推定	見かけるらしい
# 見かける	様態	見かけるそう
# 見かける	伝聞	見かけるそうだ
# 見かける	例示	見かけるようだ
# 見かける	勧誘	見かけよう
# 見かける	自分の希望	見かけたい
# 見かける	他人の希望	見かけたがる
# 見かける	て	見かけて
# 見かける	です・ます	見かけます
# 子音動詞マ行
# 見込む	可能	見込める
# 見込む	受け身	見込まれる
# 見込む	使役	見込ませる
# 見込む	過去	見込んだ
# 見込む	否定	見込まない
# 見込む	推定	見込むらしい
# 見込む	様態	見込むそう
# 見込む	伝聞	見込むそうだ
# 見込む	例示	見込むようだ
# 見込む	勧誘	見込もう
# 見込む	自分の希望	見込みたい
# 見込む	他人の希望	見込みたがる
# 見込む	て	見込んて
# 見込む	です・ます	見込みます
# 母音動詞
# 見立てる	可能	見立てれる
# 見立てる	受け身	見立てられる
# 見立てる	使役	見立てさせる
# 見立てる	過去	見立てた
# 見立てる	否定	見立てない
# 見立てる	推定	見立てるらしい
# 見立てる	様態	見立てるそう
# 見立てる	伝聞	見立てるそうだ
# 見立てる	例示	見立てるようだ
# 見立てる	勧誘	見立てよう
# 見立てる	自分の希望	見立てたい
# 見立てる	他人の希望	見立てたがる
# 見立てる	て	見立てて
# 見立てる	です・ます	見立てます
# イ形容詞アウオ段
# 満たない	可能	満たなかろる
# 満たない	受け身	満たなかろられる
# 満たない	使役	満たなかろさせる
# 満たない	過去	満たなかった
# 満たない	否定	満たなくない
# 満たない	推定	満たないらしい
# 満たない	様態	満たないそう
# 満たない	伝聞	満たないそうだ
# 満たない	例示	満たないようだ
# 満たない	勧誘	満たなかろう
# 満たない	自分の希望	満たなくたい
# 満たない	他人の希望	満たなくたがる
# 満たない	て	満たなかって
# 満たない	です・ます	満たないです
# 子音動詞カ行
# 導く	可能	導ける
# 導く	受け身	導かれる
# 導く	使役	導かせる
# 導く	過去	導いた
# 導く	否定	導かない
# 導く	推定	導くらしい
# 導く	様態	導くそう
# 導く	伝聞	導くそうだ
# 導く	例示	導くようだ
# 導く	勧誘	導こう
# 導く	自分の希望	導きたい
# 導く	他人の希望	導きたがる
# 導く	て	導いて
# 導く	です・ます	導きます
# 子音動詞ラ行
# 見積もる	可能	見積もれる
# 見積もる	受け身	見積もられる
# 見積もる	使役	見積もらせる
# 見積もる	過去	見積もった
# 見積もる	否定	見積もらない
# 見積もる	推定	見積もるらしい
# 見積もる	様態	見積もるそう
# 見積もる	伝聞	見積もるそうだ
# 見積もる	例示	見積もるようだ
# 見積もる	勧誘	見積もろう
# 見積もる	自分の希望	見積もりたい
# 見積もる	他人の希望	見積もりたがる
# 見積もる	て	見積もって
# 見積もる	です・ます	見積もります
# 母音動詞
# 満ちる	可能	満ちれる
# 満ちる	受け身	満ちられる
# 満ちる	使役	満ちさせる
# 満ちる	過去	満ちた
# 満ちる	否定	満ちない
# 満ちる	推定	満ちるらしい
# 満ちる	様態	満ちるそう
# 満ちる	伝聞	満ちるそうだ
# 満ちる	例示	満ちるようだ
# 満ちる	勧誘	満ちよう
# 満ちる	自分の希望	満ちたい
# 満ちる	他人の希望	満ちたがる
# 満ちる	て	満ちて
# 満ちる	です・ます	満ちます
# 母音動詞
# 認める	可能	認めれる
# 認める	受け身	認められる
# 認める	使役	認めさせる
# 認める	過去	認めた
# 認める	否定	認めない
# 認める	推定	認めるらしい
# 認める	様態	認めるそう
# 認める	伝聞	認めるそうだ
# 認める	例示	認めるようだ
# 認める	勧誘	認めよう
# 認める	自分の希望	認めたい
# 認める	他人の希望	認めたがる
# 認める	て	認めて
# 認める	です・ます	認めます
# 子音動詞サ行
# 見直す	可能	見直せる
# 見直す	受け身	見直される
# 見直す	使役	見直させる
# 見直す	過去	見直した
# 見直す	否定	見直さない
# 見直す	推定	見直すらしい
# 見直す	様態	見直すそう
# 見直す	伝聞	見直すそうだ
# 見直す	例示	見直すようだ
# 見直す	勧誘	見直そう
# 見直す	自分の希望	見直したい
# 見直す	他人の希望	見直したがる
# 見直す	て	見直して
# 見直す	です・ます	見直します
# 子音動詞サ行
# みなす	可能	みなせる
# みなす	受け身	みなされる
# みなす	使役	みなさせる
# みなす	過去	みなした
# みなす	否定	みなさない
# みなす	推定	みなすらしい
# みなす	様態	みなすそう
# みなす	伝聞	みなすそうだ
# みなす	例示	みなすようだ
# みなす	勧誘	みなそう
# みなす	自分の希望	みなしたい
# みなす	他人の希望	みなしたがる
# みなす	て	みなして
# みなす	です・ます	みなします
# 母音動詞
# 慣れる	可能	見慣れれる
# 慣れる	受け身	見慣れられる
# 慣れる	使役	見慣れさせる
# 慣れる	過去	見慣れた
# 慣れる	否定	見慣れない
# 慣れる	推定	見慣れるらしい
# 慣れる	様態	見慣れるそう
# 慣れる	伝聞	見慣れるそうだ
# 慣れる	例示	見慣れるようだ
# 慣れる	勧誘	見慣れよう
# 慣れる	自分の希望	見慣れたい
# 慣れる	他人の希望	見慣れたがる
# 慣れる	て	見慣れて
# 慣れる	です・ます	見慣れます
# 子音動詞サ行
# 見逃す	可能	見逃せる
# 見逃す	受け身	見逃される
# 見逃す	使役	見逃させる
# 見逃す	過去	見逃した
# 見逃す	否定	見逃さない
# 見逃す	推定	見逃すらしい
# 見逃す	様態	見逃すそう
# 見逃す	伝聞	見逃すそうだ
# 見逃す	例示	見逃すようだ
# 見逃す	勧誘	見逃そう
# 見逃す	自分の希望	見逃したい
# 見逃す	他人の希望	見逃したがる
# 見逃す	て	見逃して
# 見逃す	です・ます	見逃します
# 子音動詞ラ行
# 見守る	可能	見守れる
# 見守る	受け身	見守られる
# 見守る	使役	見守らせる
# 見守る	過去	見守った
# 見守る	否定	見守らない
# 見守る	推定	見守るらしい
# 見守る	様態	見守るそう
# 見守る	伝聞	見守るそうだ
# 見守る	例示	見守るようだ
# 見守る	勧誘	見守ろう
# 見守る	自分の希望	見守りたい
# 見守る	他人の希望	見守りたがる
# 見守る	て	見守って
# 見守る	です・ます	見守ります
# 母音動詞
# 迎える	可能	迎えれる
# 迎える	受け身	迎えられる
# 迎える	使役	迎えさせる
# 迎える	過去	迎えた
# 迎える	否定	迎えない
# 迎える	推定	迎えるらしい
# 迎える	様態	迎えるそう
# 迎える	伝聞	迎えるそうだ
# 迎える	例示	迎えるようだ
# 迎える	勧誘	迎えよう
# 迎える	自分の希望	迎えたい
# 迎える	他人の希望	迎えたがる
# 迎える	て	迎えて
# 迎える	です・ます	迎えます
# 子音動詞カ行
# 向く	可能	向ける
# 向く	受け身	向かれる
# 向く	使役	向かせる
# 向く	過去	向いた
# 向く	否定	向かない
# 向く	推定	向くらしい
# 向く	様態	向くそう
# 向く	伝聞	向くそうだ
# 向く	例示	向くようだ
# 向く	勧誘	向こう
# 向く	自分の希望	向きたい
# 向く	他人の希望	向きたがる
# 向く	て	向いて
# 向く	です・ます	向きます
# 子音動詞カ行
# むく	可能	むける
# むく	受け身	むかれる
# むく	使役	むかせる
# むく	過去	むいた
# むく	否定	むかない
# むく	推定	むくらしい
# むく	様態	むくそう
# むく	伝聞	むくそうだ
# むく	例示	むくようだ
# むく	勧誘	むこう
# むく	自分の希望	むきたい
# むく	他人の希望	むきたがる
# むく	て	むいて
# むく	です・ます	むきます
# イ形容詞アウオ段
# い	可能	報うかろる
# い	受け身	報うかろられる
# い	使役	報うかろさせる
# い	過去	報うかった
# い	否定	報うくない
# い	推定	報ういらしい
# い	様態	報ういそう
# い	伝聞	報ういそうだ
# い	例示	報ういようだ
# い	勧誘	報うかろう
# い	自分の希望	報うくたい
# い	他人の希望	報うくたがる
# い	て	報うかって
# い	です・ます	報ういです
# 母音動詞
# 報われる	可能	報われれる
# 報われる	受け身	報われられる
# 報われる	使役	報われさせる
# 報われる	過去	報われた
# 報われる	否定	報われない
# 報われる	推定	報われるらしい
# 報われる	様態	報われるそう
# 報われる	伝聞	報われるそうだ
# 報われる	例示	報われるようだ
# 報われる	勧誘	報われよう
# 報われる	自分の希望	報われたい
# 報われる	他人の希望	報われたがる
# 報われる	て	報われて
# 報われる	です・ます	報われます
# 母音動詞
# 向ける	可能	向けれる
# 向ける	受け身	向けられる
# 向ける	使役	向けさせる
# 向ける	過去	向けた
# 向ける	否定	向けない
# 向ける	推定	向けるらしい
# 向ける	様態	向けるそう
# 向ける	伝聞	向けるそうだ
# 向ける	例示	向けるようだ
# 向ける	勧誘	向けよう
# 向ける	自分の希望	向けたい
# 向ける	他人の希望	向けたがる
# 向ける	て	向けて
# 向ける	です・ます	向けます
# 母音動詞
# むける	可能	むけれる
# むける	受け身	むけられる
# むける	使役	むけさせる
# むける	過去	むけた
# むける	否定	むけない
# むける	推定	むけるらしい
# むける	様態	むけるそう
# むける	伝聞	むけるそうだ
# むける	例示	むけるようだ
# むける	勧誘	むけよう
# むける	自分の希望	むけたい
# むける	他人の希望	むけたがる
# むける	て	むけて
# むける	です・ます	むけます
# 子音動詞サ行
# 蒸す	可能	蒸せる
# 蒸す	受け身	蒸される
# 蒸す	使役	蒸させる
# 蒸す	過去	蒸した
# 蒸す	否定	蒸さない
# 蒸す	推定	蒸すらしい
# 蒸す	様態	蒸すそう
# 蒸す	伝聞	蒸すそうだ
# 蒸す	例示	蒸すようだ
# 蒸す	勧誘	蒸そう
# 蒸す	自分の希望	蒸したい
# 蒸す	他人の希望	蒸したがる
# 蒸す	て	蒸して
# 蒸す	です・ます	蒸します
# 母音動詞
# 付ける	可能	結び付けれる
# 付ける	受け身	結び付けられる
# 付ける	使役	結び付けさせる
# 付ける	過去	結び付けた
# 付ける	否定	結び付けない
# 付ける	推定	結び付けるらしい
# 付ける	様態	結び付けるそう
# 付ける	伝聞	結び付けるそうだ
# 付ける	例示	結び付けるようだ
# 付ける	勧誘	結び付けよう
# 付ける	自分の希望	結び付けたい
# 付ける	他人の希望	結び付けたがる
# 付ける	て	結び付けて
# 付ける	です・ます	結び付けます
# 子音動詞バ行
# 結ぶ	可能	結べる
# 結ぶ	受け身	結ばれる
# 結ぶ	使役	結ばせる
# 結ぶ	過去	結んだ
# 結ぶ	否定	結ばない
# 結ぶ	推定	結ぶらしい
# 結ぶ	様態	結ぶそう
# 結ぶ	伝聞	結ぶそうだ
# 結ぶ	例示	結ぶようだ
# 結ぶ	勧誘	結ぼう
# 結ぶ	自分の希望	結びたい
# 結ぶ	他人の希望	結びたがる
# 結ぶ	て	結んて
# 結ぶ	です・ます	結びます
# 母音動詞
# 命じる	可能	命じれる
# 命じる	受け身	命じられる
# 命じる	使役	命じさせる
# 命じる	過去	命じた
# 命じる	否定	命じない
# 命じる	推定	命じるらしい
# 命じる	様態	命じるそう
# 命じる	伝聞	命じるそうだ
# 命じる	例示	命じるようだ
# 命じる	勧誘	命じよう
# 命じる	自分の希望	命じたい
# 命じる	他人の希望	命じたがる
# 命じる	て	命じて
# 命じる	です・ます	命じます
# 子音動詞マ行
# 恵む	可能	恵める
# 恵む	受け身	恵まれる
# 恵む	使役	恵ませる
# 恵む	過去	恵んだ
# 恵む	否定	恵まない
# 恵む	推定	恵むらしい
# 恵む	様態	恵むそう
# 恵む	伝聞	恵むそうだ
# 恵む	例示	恵むようだ
# 恵む	勧誘	恵もう
# 恵む	自分の希望	恵みたい
# 恵む	他人の希望	恵みたがる
# 恵む	て	恵んて
# 恵む	です・ます	恵みます
# 子音動詞ラ行
# 巡る	可能	巡れる
# 巡る	受け身	巡られる
# 巡る	使役	巡らせる
# 巡る	過去	巡った
# 巡る	否定	巡らない
# 巡る	推定	巡るらしい
# 巡る	様態	巡るそう
# 巡る	伝聞	巡るそうだ
# 巡る	例示	巡るようだ
# 巡る	勧誘	巡ろう
# 巡る	自分の希望	巡りたい
# 巡る	他人の希望	巡りたがる
# 巡る	て	巡って
# 巡る	です・ます	巡ります
# 子音動詞サ行
# 目指す	可能	目指せる
# 目指す	受け身	目指される
# 目指す	使役	目指させる
# 目指す	過去	目指した
# 目指す	否定	目指さない
# 目指す	推定	目指すらしい
# 目指す	様態	目指すそう
# 目指す	伝聞	目指すそうだ
# 目指す	例示	目指すようだ
# 目指す	勧誘	目指そう
# 目指す	自分の希望	目指したい
# 目指す	他人の希望	目指したがる
# 目指す	て	目指して
# 目指す	です・ます	目指します
# 子音動詞タ行
# 目立つ	可能	目立てる
# 目立つ	受け身	目立たれる
# 目立つ	使役	目立たせる
# 目立つ	過去	目立った
# 目立つ	否定	目立たない
# 目立つ	推定	目立つらしい
# 目立つ	様態	目立つそう
# 目立つ	伝聞	目立つそうだ
# 目立つ	例示	目立つようだ
# 目立つ	勧誘	目立とう
# 目立つ	自分の希望	目立ちたい
# 目立つ	他人の希望	目立ちたがる
# 目立つ	て	目立って
# 目立つ	です・ます	目立ちます
# 子音動詞ラ行
# もうかる	可能	もうかれる
# もうかる	受け身	もうかられる
# もうかる	使役	もうからせる
# もうかる	過去	もうかった
# もうかる	否定	もうからない
# もうかる	推定	もうかるらしい
# もうかる	様態	もうかるそう
# もうかる	伝聞	もうかるそうだ
# もうかる	例示	もうかるようだ
# もうかる	勧誘	もうかろう
# もうかる	自分の希望	もうかりたい
# もうかる	他人の希望	もうかりたがる
# もうかる	て	もうかって
# もうかる	です・ます	もうかります
# 母音動詞
# もうける	可能	もうけれる
# もうける	受け身	もうけられる
# もうける	使役	もうけさせる
# もうける	過去	もうけた
# もうける	否定	もうけない
# もうける	推定	もうけるらしい
# もうける	様態	もうけるそう
# もうける	伝聞	もうけるそうだ
# もうける	例示	もうけるようだ
# もうける	勧誘	もうけよう
# もうける	自分の希望	もうけたい
# もうける	他人の希望	もうけたがる
# もうける	て	もうけて
# もうける	です・ます	もうけます
# 母音動詞
# 設ける	可能	設けれる
# 設ける	受け身	設けられる
# 設ける	使役	設けさせる
# 設ける	過去	設けた
# 設ける	否定	設けない
# 設ける	推定	設けるらしい
# 設ける	様態	設けるそう
# 設ける	伝聞	設けるそうだ
# 設ける	例示	設けるようだ
# 設ける	勧誘	設けよう
# 設ける	自分の希望	設けたい
# 設ける	他人の希望	設けたがる
# 設ける	て	設けて
# 設ける	です・ます	設けます
# 母音動詞
# 申し出る	可能	申し出れる
# 申し出る	受け身	申し出られる
# 申し出る	使役	申し出させる
# 申し出る	過去	申し出た
# 申し出る	否定	申し出ない
# 申し出る	推定	申し出るらしい
# 申し出る	様態	申し出るそう
# 申し出る	伝聞	申し出るそうだ
# 申し出る	例示	申し出るようだ
# 申し出る	勧誘	申し出よう
# 申し出る	自分の希望	申し出たい
# 申し出る	他人の希望	申し出たがる
# 申し出る	て	申し出て
# 申し出る	です・ます	申し出ます
# 子音動詞ラ行
# 潜る	可能	潜れる
# 潜る	受け身	潜られる
# 潜る	使役	潜らせる
# 潜る	過去	潜った
# 潜る	否定	潜らない
# 潜る	推定	潜るらしい
# 潜る	様態	潜るそう
# 潜る	伝聞	潜るそうだ
# 潜る	例示	潜るようだ
# 潜る	勧誘	潜ろう
# 潜る	自分の希望	潜りたい
# 潜る	他人の希望	潜りたがる
# 潜る	て	潜って
# 潜る	です・ます	潜ります
# 子音動詞サ行
# もたらす	可能	もたらせる
# もたらす	受け身	もたらされる
# もたらす	使役	もたらさせる
# もたらす	過去	もたらした
# もたらす	否定	もたらさない
# もたらす	推定	もたらすらしい
# もたらす	様態	もたらすそう
# もたらす	伝聞	もたらすそうだ
# もたらす	例示	もたらすようだ
# もたらす	勧誘	もたらそう
# もたらす	自分の希望	もたらしたい
# もたらす	他人の希望	もたらしたがる
# もたらす	て	もたらして
# もたらす	です・ます	もたらします
# 子音動詞ラ行
# 持ち寄る	可能	持ち寄れる
# 持ち寄る	受け身	持ち寄られる
# 持ち寄る	使役	持ち寄らせる
# 持ち寄る	過去	持ち寄った
# 持ち寄る	否定	持ち寄らない
# 持ち寄る	推定	持ち寄るらしい
# 持ち寄る	様態	持ち寄るそう
# 持ち寄る	伝聞	持ち寄るそうだ
# 持ち寄る	例示	持ち寄るようだ
# 持ち寄る	勧誘	持ち寄ろう
# 持ち寄る	自分の希望	持ち寄りたい
# 持ち寄る	他人の希望	持ち寄りたがる
# 持ち寄る	て	持ち寄って
# 持ち寄る	です・ます	持ち寄ります
# 子音動詞カ行
# 基づく	可能	基づける
# 基づく	受け身	基づかれる
# 基づく	使役	基づかせる
# 基づく	過去	基づいた
# 基づく	否定	基づかない
# 基づく	推定	基づくらしい
# 基づく	様態	基づくそう
# 基づく	伝聞	基づくそうだ
# 基づく	例示	基づくようだ
# 基づく	勧誘	基づこう
# 基づく	自分の希望	基づきたい
# 基づく	他人の希望	基づきたがる
# 基づく	て	基づいて
# 基づく	です・ます	基づきます
# 母音動詞
# 求める	可能	求めれる
# 求める	受け身	求められる
# 求める	使役	求めさせる
# 求める	過去	求めた
# 求める	否定	求めない
# 求める	推定	求めるらしい
# 求める	様態	求めるそう
# 求める	伝聞	求めるそうだ
# 求める	例示	求めるようだ
# 求める	勧誘	求めよう
# 求める	自分の希望	求めたい
# 求める	他人の希望	求めたがる
# 求める	て	求めて
# 求める	です・ます	求めます
# 子音動詞マ行
# もむ	可能	もめる
# もむ	受け身	もまれる
# もむ	使役	もませる
# もむ	過去	もんだ
# もむ	否定	もまない
# もむ	推定	もむらしい
# もむ	様態	もむそう
# もむ	伝聞	もむそうだ
# もむ	例示	もむようだ
# もむ	勧誘	ももう
# もむ	自分の希望	もみたい
# もむ	他人の希望	もみたがる
# もむ	て	もんて
# もむ	です・ます	もみます
# 子音動詞サ行
# 燃やす	可能	燃やせる
# 燃やす	受け身	燃やされる
# 燃やす	使役	燃やさせる
# 燃やす	過去	燃やした
# 燃やす	否定	燃やさない
# 燃やす	推定	燃やすらしい
# 燃やす	様態	燃やすそう
# 燃やす	伝聞	燃やすそうだ
# 燃やす	例示	燃やすようだ
# 燃やす	勧誘	燃やそう
# 燃やす	自分の希望	燃やしたい
# 燃やす	他人の希望	燃やしたがる
# 燃やす	て	燃やして
# 燃やす	です・ます	燃やします
# 子音動詞サ行
# 催す	可能	催せる
# 催す	受け身	催される
# 催す	使役	催させる
# 催す	過去	催した
# 催す	否定	催さない
# 催す	推定	催すらしい
# 催す	様態	催すそう
# 催す	伝聞	催すそうだ
# 催す	例示	催すようだ
# 催す	勧誘	催そう
# 催す	自分の希望	催したい
# 催す	他人の希望	催したがる
# 催す	て	催して
# 催す	です・ます	催します
# 子音動詞ラ行
# 盛り上がる	可能	盛り上がれる
# 盛り上がる	受け身	盛り上がられる
# 盛り上がる	使役	盛り上がらせる
# 盛り上がる	過去	盛り上がった
# 盛り上がる	否定	盛り上がらない
# 盛り上がる	推定	盛り上がるらしい
# 盛り上がる	様態	盛り上がるそう
# 盛り上がる	伝聞	盛り上がるそうだ
# 盛り上がる	例示	盛り上がるようだ
# 盛り上がる	勧誘	盛り上がろう
# 盛り上がる	自分の希望	盛り上がりたい
# 盛り上がる	他人の希望	盛り上がりたがる
# 盛り上がる	て	盛り上がって
# 盛り上がる	です・ます	盛り上がります
# 母音動詞
# 盛り上げる	可能	盛り上げれる
# 盛り上げる	受け身	盛り上げられる
# 盛り上げる	使役	盛り上げさせる
# 盛り上げる	過去	盛り上げた
# 盛り上げる	否定	盛り上げない
# 盛り上げる	推定	盛り上げるらしい
# 盛り上げる	様態	盛り上げるそう
# 盛り上げる	伝聞	盛り上げるそうだ
# 盛り上げる	例示	盛り上げるようだ
# 盛り上げる	勧誘	盛り上げよう
# 盛り上げる	自分の希望	盛り上げたい
# 盛り上げる	他人の希望	盛り上げたがる
# 盛り上げる	て	盛り上げて
# 盛り上げる	です・ます	盛り上げます
# 子音動詞ラ行
# 盛る	可能	盛れる
# 盛る	受け身	盛られる
# 盛る	使役	盛らせる
# 盛る	過去	盛った
# 盛る	否定	盛らない
# 盛る	推定	盛るらしい
# 盛る	様態	盛るそう
# 盛る	伝聞	盛るそうだ
# 盛る	例示	盛るようだ
# 盛る	勧誘	盛ろう
# 盛る	自分の希望	盛りたい
# 盛る	他人の希望	盛りたがる
# 盛る	て	盛って
# 盛る	です・ます	盛ります
# 子音動詞サ行
# 訳す	可能	訳せる
# 訳す	受け身	訳される
# 訳す	使役	訳させる
# 訳す	過去	訳した
# 訳す	否定	訳さない
# 訳す	推定	訳すらしい
# 訳す	様態	訳すそう
# 訳す	伝聞	訳すそうだ
# 訳す	例示	訳すようだ
# 訳す	勧誘	訳そう
# 訳す	自分の希望	訳したい
# 訳す	他人の希望	訳したがる
# 訳す	て	訳して
# 訳す	です・ます	訳します
# カ変動詞
# やってくる	可能	やってくるこる
# やってくる	受け身	やってくるこられる
# やってくる	使役	やってくるこさせる
# やってくる	過去	やってくるきた
# やってくる	否定	やってくるこない
# やってくる	推定	やってくるくるらしい
# やってくる	様態	やってくるくるそう
# やってくる	伝聞	やってくるくるそうだ
# やってくる	例示	やってくるくるようだ
# やってくる	勧誘	やってくるこよう
# やってくる	自分の希望	やってくるきたい
# やってくる	他人の希望	やってくるきたがる
# やってくる	て	やってくるきて
# やってくる	です・ます	やってくるきます
# 子音動詞ワ行
# 雇う	可能	雇える
# 雇う	受け身	雇われる
# 雇う	使役	雇わせる
# 雇う	過去	雇った
# 雇う	否定	雇わない
# 雇う	推定	雇うらしい
# 雇う	様態	雇うそう
# 雇う	伝聞	雇うそうだ
# 雇う	例示	雇うようだ
# 雇う	勧誘	雇おう
# 雇う	自分の希望	雇いたい
# 雇う	他人の希望	雇いたがる
# 雇う	て	雇って
# 雇う	です・ます	雇います
# 子音動詞ラ行
# 破る	可能	破れる
# 破る	受け身	破られる
# 破る	使役	破らせる
# 破る	過去	破った
# 破る	否定	破らない
# 破る	推定	破るらしい
# 破る	様態	破るそう
# 破る	伝聞	破るそうだ
# 破る	例示	破るようだ
# 破る	勧誘	破ろう
# 破る	自分の希望	破りたい
# 破る	他人の希望	破りたがる
# 破る	て	破って
# 破る	です・ます	破ります
# 母音動詞
# 敗れる	可能	敗れれる
# 敗れる	受け身	敗れられる
# 敗れる	使役	敗れさせる
# 敗れる	過去	敗れた
# 敗れる	否定	敗れない
# 敗れる	推定	敗れるらしい
# 敗れる	様態	敗れるそう
# 敗れる	伝聞	敗れるそうだ
# 敗れる	例示	敗れるようだ
# 敗れる	勧誘	敗れよう
# 敗れる	自分の希望	敗れたい
# 敗れる	他人の希望	敗れたがる
# 敗れる	て	敗れて
# 敗れる	です・ます	敗れます
# 母音動詞
# 遂げる	可能	やり遂げれる
# 遂げる	受け身	やり遂げられる
# 遂げる	使役	やり遂げさせる
# 遂げる	過去	やり遂げた
# 遂げる	否定	やり遂げない
# 遂げる	推定	やり遂げるらしい
# 遂げる	様態	やり遂げるそう
# 遂げる	伝聞	やり遂げるそうだ
# 遂げる	例示	やり遂げるようだ
# 遂げる	勧誘	やり遂げよう
# 遂げる	自分の希望	やり遂げたい
# 遂げる	他人の希望	やり遂げたがる
# 遂げる	て	やり遂げて
# 遂げる	です・ます	やり遂げます
# 子音動詞ラ行
# 譲る	可能	譲れる
# 譲る	受け身	譲られる
# 譲る	使役	譲らせる
# 譲る	過去	譲った
# 譲る	否定	譲らない
# 譲る	推定	譲るらしい
# 譲る	様態	譲るそう
# 譲る	伝聞	譲るそうだ
# 譲る	例示	譲るようだ
# 譲る	勧誘	譲ろう
# 譲る	自分の希望	譲りたい
# 譲る	他人の希望	譲りたがる
# 譲る	て	譲って
# 譲る	です・ます	譲ります
# 母音動詞
# ゆでる	可能	ゆでれる
# ゆでる	受け身	ゆでられる
# ゆでる	使役	ゆでさせる
# ゆでる	過去	ゆでた
# ゆでる	否定	ゆでない
# ゆでる	推定	ゆでるらしい
# ゆでる	様態	ゆでるそう
# ゆでる	伝聞	ゆでるそうだ
# ゆでる	例示	ゆでるようだ
# ゆでる	勧誘	ゆでよう
# ゆでる	自分の希望	ゆでたい
# ゆでる	他人の希望	ゆでたがる
# ゆでる	て	ゆでて
# ゆでる	です・ます	ゆでます
# 子音動詞サ行
# 許す	可能	許せる
# 許す	受け身	許される
# 許す	使役	許させる
# 許す	過去	許した
# 許す	否定	許さない
# 許す	推定	許すらしい
# 許す	様態	許すそう
# 許す	伝聞	許すそうだ
# 許す	例示	許すようだ
# 許す	勧誘	許そう
# 許す	自分の希望	許したい
# 許す	他人の希望	許したがる
# 許す	て	許して
# 許す	です・ます	許します
# 母音動詞
# 揺れる	可能	揺れれる
# 揺れる	受け身	揺れられる
# 揺れる	使役	揺れさせる
# 揺れる	過去	揺れた
# 揺れる	否定	揺れない
# 揺れる	推定	揺れるらしい
# 揺れる	様態	揺れるそう
# 揺れる	伝聞	揺れるそうだ
# 揺れる	例示	揺れるようだ
# 揺れる	勧誘	揺れよう
# 揺れる	自分の希望	揺れたい
# 揺れる	他人の希望	揺れたがる
# 揺れる	て	揺れて
# 揺れる	です・ます	揺れます
# 子音動詞サ行
# よす	可能	よせる
# よす	受け身	よされる
# よす	使役	よさせる
# よす	過去	よした
# よす	否定	よさない
# よす	推定	よすらしい
# よす	様態	よすそう
# よす	伝聞	よすそうだ
# よす	例示	よすようだ
# よす	勧誘	よそう
# よす	自分の希望	よしたい
# よす	他人の希望	よしたがる
# よす	て	よして
# よす	です・ます	よします
# 母音動詞
# 寄せる	可能	寄せれる
# 寄せる	受け身	寄せられる
# 寄せる	使役	寄せさせる
# 寄せる	過去	寄せた
# 寄せる	否定	寄せない
# 寄せる	推定	寄せるらしい
# 寄せる	様態	寄せるそう
# 寄せる	伝聞	寄せるそうだ
# 寄せる	例示	寄せるようだ
# 寄せる	勧誘	寄せよう
# 寄せる	自分の希望	寄せたい
# 寄せる	他人の希望	寄せたがる
# 寄せる	て	寄せて
# 寄せる	です・ます	寄せます
# 子音動詞ワ行
# 酔っ払う	可能	酔っ払える
# 酔っ払う	受け身	酔っ払われる
# 酔っ払う	使役	酔っ払わせる
# 酔っ払う	過去	酔っ払った
# 酔っ払う	否定	酔っ払わない
# 酔っ払う	推定	酔っ払うらしい
# 酔っ払う	様態	酔っ払うそう
# 酔っ払う	伝聞	酔っ払うそうだ
# 酔っ払う	例示	酔っ払うようだ
# 酔っ払う	勧誘	酔っ払おう
# 酔っ払う	自分の希望	酔っ払いたい
# 酔っ払う	他人の希望	酔っ払いたがる
# 酔っ払う	て	酔っ払って
# 酔っ払う	です・ます	酔っ払います
# 母音動詞
# 呼びかける	可能	呼びかけれる
# 呼びかける	受け身	呼びかけられる
# 呼びかける	使役	呼びかけさせる
# 呼びかける	過去	呼びかけた
# 呼びかける	否定	呼びかけない
# 呼びかける	推定	呼びかけるらしい
# 呼びかける	様態	呼びかけるそう
# 呼びかける	伝聞	呼びかけるそうだ
# 呼びかける	例示	呼びかけるようだ
# 呼びかける	勧誘	呼びかけよう
# 呼びかける	自分の希望	呼びかけたい
# 呼びかける	他人の希望	呼びかけたがる
# 呼びかける	て	呼びかけて
# 呼びかける	です・ます	呼びかけます
# 子音動詞バ行
# 呼ぶ	可能	呼べる
# 呼ぶ	受け身	呼ばれる
# 呼ぶ	使役	呼ばせる
# 呼ぶ	過去	呼んだ
# 呼ぶ	否定	呼ばない
# 呼ぶ	推定	呼ぶらしい
# 呼ぶ	様態	呼ぶそう
# 呼ぶ	伝聞	呼ぶそうだ
# 呼ぶ	例示	呼ぶようだ
# 呼ぶ	勧誘	呼ぼう
# 呼ぶ	自分の希望	呼びたい
# 呼ぶ	他人の希望	呼びたがる
# 呼ぶ	て	呼んて
# 呼ぶ	です・ます	呼びます
# 子音動詞バ行
# 喜ぶ	可能	喜べる
# 喜ぶ	受け身	喜ばれる
# 喜ぶ	使役	喜ばせる
# 喜ぶ	過去	喜んだ
# 喜ぶ	否定	喜ばない
# 喜ぶ	推定	喜ぶらしい
# 喜ぶ	様態	喜ぶそう
# 喜ぶ	伝聞	喜ぶそうだ
# 喜ぶ	例示	喜ぶようだ
# 喜ぶ	勧誘	喜ぼう
# 喜ぶ	自分の希望	喜びたい
# 喜ぶ	他人の希望	喜びたがる
# 喜ぶ	て	喜んて
# 喜ぶ	です・ます	喜びます
# 子音動詞ラ行
# 弱まる	可能	弱まれる
# 弱まる	受け身	弱まられる
# 弱まる	使役	弱まらせる
# 弱まる	過去	弱まった
# 弱まる	否定	弱まらない
# 弱まる	推定	弱まるらしい
# 弱まる	様態	弱まるそう
# 弱まる	伝聞	弱まるそうだ
# 弱まる	例示	弱まるようだ
# 弱まる	勧誘	弱まろう
# 弱まる	自分の希望	弱まりたい
# 弱まる	他人の希望	弱まりたがる
# 弱まる	て	弱まって
# 弱まる	です・ます	弱まります
# 母音動詞
# 弱める	可能	弱めれる
# 弱める	受け身	弱められる
# 弱める	使役	弱めさせる
# 弱める	過去	弱めた
# 弱める	否定	弱めない
# 弱める	推定	弱めるらしい
# 弱める	様態	弱めるそう
# 弱める	伝聞	弱めるそうだ
# 弱める	例示	弱めるようだ
# 弱める	勧誘	弱めよう
# 弱める	自分の希望	弱めたい
# 弱める	他人の希望	弱めたがる
# 弱める	て	弱めて
# 弱める	です・ます	弱めます
# 母音動詞
# 分かれる	可能	分かれれる
# 分かれる	受け身	分かれられる
# 分かれる	使役	分かれさせる
# 分かれる	過去	分かれた
# 分かれる	否定	分かれない
# 分かれる	推定	分かれるらしい
# 分かれる	様態	分かれるそう
# 分かれる	伝聞	分かれるそうだ
# 分かれる	例示	分かれるようだ
# 分かれる	勧誘	分かれよう
# 分かれる	自分の希望	分かれたい
# 分かれる	他人の希望	分かれたがる
# 分かれる	て	分かれて
# 分かれる	です・ます	分かれます
# 子音動詞カ行
# 湧く	可能	湧ける
# 湧く	受け身	湧かれる
# 湧く	使役	湧かせる
# 湧く	過去	湧いた
# 湧く	否定	湧かない
# 湧く	推定	湧くらしい
# 湧く	様態	湧くそう
# 湧く	伝聞	湧くそうだ
# 湧く	例示	湧くようだ
# 湧く	勧誘	湧こう
# 湧く	自分の希望	湧きたい
# 湧く	他人の希望	湧きたがる
# 湧く	て	湧いて
# 湧く	です・ます	湧きます
# 子音動詞カ行
# 沸く	可能	沸ける
# 沸く	受け身	沸かれる
# 沸く	使役	沸かせる
# 沸く	過去	沸いた
# 沸く	否定	沸かない
# 沸く	推定	沸くらしい
# 沸く	様態	沸くそう
# 沸く	伝聞	沸くそうだ
# 沸く	例示	沸くようだ
# 沸く	勧誘	沸こう
# 沸く	自分の希望	沸きたい
# 沸く	他人の希望	沸きたがる
# 沸く	て	沸いて
# 沸く	です・ます	沸きます
# 子音動詞ラ行
# わたる	可能	わたれる
# わたる	受け身	わたられる
# わたる	使役	わたらせる
# わたる	過去	わたった
# わたる	否定	わたらない
# わたる	推定	わたるらしい
# わたる	様態	わたるそう
# わたる	伝聞	わたるそうだ
# わたる	例示	わたるようだ
# わたる	勧誘	わたろう
# わたる	自分の希望	わたりたい
# わたる	他人の希望	わたりたがる
# わたる	て	わたって
# わたる	です・ます	わたります
# 子音動詞カ行
# 割り引く	可能	割り引ける
# 割り引く	受け身	割り引かれる
# 割り引く	使役	割り引かせる
# 割り引く	過去	割り引いた
# 割り引く	否定	割り引かない
# 割り引く	推定	割り引くらしい
# 割り引く	様態	割り引くそう
# 割り引く	伝聞	割り引くそうだ
# 割り引く	例示	割り引くようだ
# 割り引く	勧誘	割り引こう
# 割り引く	自分の希望	割り引きたい
# 割り引く	他人の希望	割り引きたがる
# 割り引く	て	割り引いて
# 割り引く	です・ます	割り引きます
# 子音動詞ラ行
# 割る	可能	割れる
# 割る	受け身	割られる
# 割る	使役	割らせる
# 割る	過去	割った
# 割る	否定	割らない
# 割る	推定	割るらしい
# 割る	様態	割るそう
# 割る	伝聞	割るそうだ
# 割る	例示	割るようだ
# 割る	勧誘	割ろう
# 割る	自分の希望	割りたい
# 割る	他人の希望	割りたがる
# 割る	て	割って
# 割る	です・ます	割ります

# %%
# 2個ずつでテスト

# %%
# すべての組み合わせでテスト

# %%
# クラス化した状態でテスト
