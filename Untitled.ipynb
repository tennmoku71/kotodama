# %%
# # 動詞を抽出
# output = open("result.txt", mode='w')

# counter = 0
# with open("voc_list_kiso_kansei.csv",encoding='cp932', mode='r') as f:
#     for s_line in f:
#         linedata = s_line.split(",")
#         if "動詞" in linedata[4]:
#             verb = linedata[2].replace("\"", "")
#             if "名詞" in  linedata[4]:
#                 verb += "する"
#             output.write(verb+"\n")
# output.close()

# %%
# # 手動で添削して、ダブリがないかどうか見てみる
# with open("result.txt",encoding='utf-8', mode='r') as f:
#     lines = f.readlines()
#     for i in range(len(lines)):
#         for j in range(i):
#             if j < i and lines[i] == lines[j]:
#                 print(str(i)+" "+str(j))
#                 break

# %%
# # jumanにかけて、活用形を抽出する
# import pyknp
# juman = pyknp.Juman()

# output = open("kotodama_dic.csv",encoding="utf-8",mode="w")
# with open("result.txt",encoding='utf-8', mode='r') as f:
#     for original_verb in f:
#         original_verb = original_verb.strip()
#         output_line = ""
#         mrphs = juman.analysis(original_verb).mrph_list()
#         mrph = mrphs[-1]
#         output_line_list = [original_verb,mrph.genkei,mrph.hinsi,mrph.katuyou1]
#         output.write(",".join(output_line_list)+"\n")
    
# output.close()

# %%
# # プログラム変更前の段階でテスト
# from kotodama import kotodama
# from pyknp import Juman
# juman = Juman()
# kotodama.transformVerb(juman.analysis("する"),["過去"])

# %%
# # KNPに依存しない形に変更
# from kotodama import kotodama_no_juman
# kotodama_no_juman.transformVerb("する",["過去"])
# Out:
# 'した'

# %%
""
from kotodama import kotodama_no_juman
format_all_list = ["可能","受け身","使役","過去","否定","推定","様態","伝聞","例示","勧誘","自分の希望","他人の希望","て","です・ます"]

f = open("result.txt",encoding="utf-8",mode="r")
for verb in f:
    verb = verb.strip()
    for format_element in format_all_list:
        print(verb+"\t"+format_element+"\t"+kotodama_no_juman.transformVerb(verb,{format_element}))
# Out:
# する	可能	できれる
# する	受け身	さられる
# する	使役	させる
# する	過去	した
# する	否定	しない
# する	推定	するらしい
# する	様態	するそう
# する	伝聞	するそうだ
# する	例示	するようだ
# する	勧誘	しう
# する	自分の希望	さたい
# する	他人の希望	さたがる
# する	て	して
# する	です・ます	します
# いる	可能	いる
# いる	受け身	いられる
# いる	使役	いせる
# いる	過去	いた
# いる	否定	いない
# いる	推定	いるらしい
# いる	様態	いるそう
# いる	伝聞	いるそうだ
# いる	例示	いるようだ
# いる	勧誘	いう
# いる	自分の希望	いたい
# いる	他人の希望	いたがる
# いる	て	いて
# いる	です・ます	います
# ある	可能	あるる
# ある	受け身	あるられる
# ある	使役	あるせる
# ある	過去	あるた
# ある	否定	あるない
# ある	推定	あるらしい
# ある	様態	あるそう
# ある	伝聞	あるそうだ
# ある	例示	あるようだ
# ある	勧誘	あるう
# ある	自分の希望	あるたい
# ある	他人の希望	あるたがる
# ある	て	あるて
# ある	です・ます	ある
# 愛し合う	可能	愛し愛し合える
# 愛し合う	受け身	愛し愛し合うられる
# 愛し合う	使役	愛し愛し合うせる
# 愛し合う	過去	愛し愛し合った
# 愛し合う	否定	愛し愛し合あない
# 愛し合う	推定	愛し愛し合うらしい
# 愛し合う	様態	愛し愛し合うそう
# 愛し合う	伝聞	愛し愛し合うそうだ
# 愛し合う	例示	愛し愛し合うようだ
# 愛し合う	勧誘	愛し愛し合おう
# 愛し合う	自分の希望	愛し愛し合うたい
# 愛し合う	他人の希望	愛し愛し合うたがる
# 愛し合う	て	愛し愛し合って
# 愛し合う	です・ます	愛し愛し合います
# 合図する	可能	合図合図できれる
# 合図する	受け身	合図合図さられる
# 合図する	使役	合図合図させる
# 合図する	過去	合図合図した
# 合図する	否定	合図合図しない
# 合図する	推定	合図合図するらしい
# 合図する	様態	合図合図するそう
# 合図する	伝聞	合図合図するそうだ
# 合図する	例示	合図合図するようだ
# 合図する	勧誘	合図合図しう
# 合図する	自分の希望	合図合図さたい
# 合図する	他人の希望	合図合図さたがる
# 合図する	て	合図合図して
# 合図する	です・ます	合図合図します
# 相席する	可能	相席相席できれる
# 相席する	受け身	相席相席さられる
# 相席する	使役	相席相席させる
# 相席する	過去	相席相席した
# 相席する	否定	相席相席しない
# 相席する	推定	相席相席するらしい
# 相席する	様態	相席相席するそう
# 相席する	伝聞	相席相席するそうだ
# 相席する	例示	相席相席するようだ
# 相席する	勧誘	相席相席しう
# 相席する	自分の希望	相席相席さたい
# 相席する	他人の希望	相席相席さたがる
# 相席する	て	相席相席して
# 相席する	です・ます	相席相席します
# 合う	可能	合える
# 合う	受け身	合うられる
# 合う	使役	合うせる
# 合う	過去	合った
# 合う	否定	合あない
# 合う	推定	合うらしい
# 合う	様態	合うそう
# 合う	伝聞	合うそうだ
# 合う	例示	合うようだ
# 合う	勧誘	合おう
# 合う	自分の希望	合うたい
# 合う	他人の希望	合うたがる
# 合う	て	合って
# 合う	です・ます	合います
# 扇ぐ	可能	扇げる
# 扇ぐ	受け身	扇ぐられる
# 扇ぐ	使役	扇ぐせる
# 扇ぐ	過去	扇いた
# 扇ぐ	否定	扇がない
# 扇ぐ	推定	扇ぐらしい
# 扇ぐ	様態	扇ぐそう
# 扇ぐ	伝聞	扇ぐそうだ
# 扇ぐ	例示	扇ぐようだ
# 扇ぐ	勧誘	扇ごう
# 扇ぐ	自分の希望	扇ぐたい
# 扇ぐ	他人の希望	扇ぐたがる
# 扇ぐ	て	扇いて
# 扇ぐ	です・ます	扇ぎます
# 挙がる	可能	挙がれる
# 挙がる	受け身	挙がるられる
# 挙がる	使役	挙がるせる
# 挙がる	過去	挙がった
# 挙がる	否定	挙がらない
# 挙がる	推定	挙がるらしい
# 挙がる	様態	挙がるそう
# 挙がる	伝聞	挙がるそうだ
# 挙がる	例示	挙がるようだ
# 挙がる	勧誘	挙がろう
# 挙がる	自分の希望	挙がるたい
# 挙がる	他人の希望	挙がるたがる
# 挙がる	て	挙がって
# 挙がる	です・ます	挙がります
# 飽きる	可能	飽きる
# 飽きる	受け身	飽きられる
# 飽きる	使役	飽きせる
# 飽きる	過去	飽きた
# 飽きる	否定	飽きない
# 飽きる	推定	飽きるらしい
# 飽きる	様態	飽きるそう
# 飽きる	伝聞	飽きるそうだ
# 飽きる	例示	飽きるようだ
# 飽きる	勧誘	飽きう
# 飽きる	自分の希望	飽きたい
# 飽きる	他人の希望	飽きたがる
# 飽きる	て	飽きて
# 飽きる	です・ます	飽きます
# 空く	可能	空ける
# 空く	受け身	空くられる
# 空く	使役	空くせる
# 空く	過去	空いた
# 空く	否定	空かない
# 空く	推定	空くらしい
# 空く	様態	空くそう
# 空く	伝聞	空くそうだ
# 空く	例示	空くようだ
# 空く	勧誘	空こう
# 空く	自分の希望	空くたい
# 空く	他人の希望	空くたがる
# 空く	て	空いて
# 空く	です・ます	空きます
# 握手する	可能	握手握手できれる
# 握手する	受け身	握手握手さられる
# 握手する	使役	握手握手させる
# 握手する	過去	握手握手した
# 握手する	否定	握手握手しない
# 握手する	推定	握手握手するらしい
# 握手する	様態	握手握手するそう
# 握手する	伝聞	握手握手するそうだ
# 握手する	例示	握手握手するようだ
# 握手する	勧誘	握手握手しう
# 握手する	自分の希望	握手握手さたい
# 握手する	他人の希望	握手握手さたがる
# 握手する	て	握手握手して
# 握手する	です・ます	握手握手します
# 明ける	可能	明ける
# 明ける	受け身	明けられる
# 明ける	使役	明けせる
# 明ける	過去	明けた
# 明ける	否定	明けない
# 明ける	推定	明けるらしい
# 明ける	様態	明けるそう
# 明ける	伝聞	明けるそうだ
# 明ける	例示	明けるようだ
# 明ける	勧誘	明けう
# 明ける	自分の希望	明けたい
# 明ける	他人の希望	明けたがる
# 明ける	て	明けて
# 明ける	です・ます	明けます
# 挙げる	可能	挙げる
# 挙げる	受け身	挙げられる
# 挙げる	使役	挙げせる
# 挙げる	過去	挙げた
# 挙げる	否定	挙げない
# 挙げる	推定	挙げるらしい
# 挙げる	様態	挙げるそう
# 挙げる	伝聞	挙げるそうだ
# 挙げる	例示	挙げるようだ
# 挙げる	勧誘	挙げう
# 挙げる	自分の希望	挙げたい
# 挙げる	他人の希望	挙げたがる
# 挙げる	て	挙げて
# 挙げる	です・ます	挙げます
# 上げる	可能	上げる
# 上げる	受け身	上げられる
# 上げる	使役	上げせる
# 上げる	過去	上げた
# 上げる	否定	上げない
# 上げる	推定	上げるらしい
# 上げる	様態	上げるそう
# 上げる	伝聞	上げるそうだ
# 上げる	例示	上げるようだ
# 上げる	勧誘	上げう
# 上げる	自分の希望	上げたい
# 上げる	他人の希望	上げたがる
# 上げる	て	上げて
# 上げる	です・ます	上げます
# あこれる	可能	あこあこれる
# あこれる	受け身	あこあこれられる
# あこれる	使役	あこあこれせる
# あこれる	過去	あこあこれた
# あこれる	否定	あこあこれない
# あこれる	推定	あこあこれるらしい
# あこれる	様態	あこあこれるそう
# あこれる	伝聞	あこあこれるそうだ
# あこれる	例示	あこあこれるようだ
# あこれる	勧誘	あこあこれう
# あこれる	自分の希望	あこあこれたい
# あこれる	他人の希望	あこあこれたがる
# あこれる	て	あこあこれて
# あこれる	です・ます	あこあこれます
# 味付けする	可能	味付け味付けできれる
# 味付けする	受け身	味付け味付けさられる
# 味付けする	使役	味付け味付けさせる
# 味付けする	過去	味付け味付けした
# 味付けする	否定	味付け味付けしない
# 味付けする	推定	味付け味付けするらしい
# 味付けする	様態	味付け味付けするそう
# 味付けする	伝聞	味付け味付けするそうだ
# 味付けする	例示	味付け味付けするようだ
# 味付けする	勧誘	味付け味付けしう
# 味付けする	自分の希望	味付け味付けさたい
# 味付けする	他人の希望	味付け味付けさたがる
# 味付けする	て	味付け味付けして
# 味付けする	です・ます	味付け味付けします
# 味わう	可能	味わえる
# 味わう	受け身	味わうられる
# 味わう	使役	味わうせる
# 味わう	過去	味わった
# 味わう	否定	味わあない
# 味わう	推定	味わうらしい
# 味わう	様態	味わうそう
# 味わう	伝聞	味わうそうだ
# 味わう	例示	味わうようだ
# 味わう	勧誘	味わおう
# 味わう	自分の希望	味わうたい
# 味わう	他人の希望	味わうたがる
# 味わう	て	味わって
# 味わう	です・ます	味わいます
# 預ける	可能	預ける
# 預ける	受け身	預けられる
# 預ける	使役	預けせる
# 預ける	過去	預けた
# 預ける	否定	預けない
# 預ける	推定	預けるらしい
# 預ける	様態	預けるそう
# 預ける	伝聞	預けるそうだ
# 預ける	例示	預けるようだ
# 預ける	勧誘	預けう
# 預ける	自分の希望	預けたい
# 預ける	他人の希望	預けたがる
# 預ける	て	預けて
# 預ける	です・ます	預けます
# 与える	可能	与える
# 与える	受け身	与えられる
# 与える	使役	与えせる
# 与える	過去	与えた
# 与える	否定	与えない
# 与える	推定	与えるらしい
# 与える	様態	与えるそう
# 与える	伝聞	与えるそうだ
# 与える	例示	与えるようだ
# 与える	勧誘	与えう
# 与える	自分の希望	与えたい
# 与える	他人の希望	与えたがる
# 与える	て	与えて
# 与える	です・ます	与えます
# 当たる	可能	当たれる
# 当たる	受け身	当たるられる
# 当たる	使役	当たるせる
# 当たる	過去	当たった
# 当たる	否定	当たらない
# 当たる	推定	当たるらしい
# 当たる	様態	当たるそう
# 当たる	伝聞	当たるそうだ
# 当たる	例示	当たるようだ
# 当たる	勧誘	当たろう
# 当たる	自分の希望	当たるたい
# 当たる	他人の希望	当たるたがる
# 当たる	て	当たって
# 当たる	です・ます	当たります
# 悪化する	可能	悪化悪化できれる
# 悪化する	受け身	悪化悪化さられる
# 悪化する	使役	悪化悪化させる
# 悪化する	過去	悪化悪化した
# 悪化する	否定	悪化悪化しない
# 悪化する	推定	悪化悪化するらしい
# 悪化する	様態	悪化悪化するそう
# 悪化する	伝聞	悪化悪化するそうだ
# 悪化する	例示	悪化悪化するようだ
# 悪化する	勧誘	悪化悪化しう
# 悪化する	自分の希望	悪化悪化さたい
# 悪化する	他人の希望	悪化悪化さたがる
# 悪化する	て	悪化悪化して
# 悪化する	です・ます	悪化悪化します
# 扱う	可能	扱える
# 扱う	受け身	扱うられる
# 扱う	使役	扱うせる
# 扱う	過去	扱った
# 扱う	否定	扱あない
# 扱う	推定	扱うらしい
# 扱う	様態	扱うそう
# 扱う	伝聞	扱うそうだ
# 扱う	例示	扱うようだ
# 扱う	勧誘	扱おう
# 扱う	自分の希望	扱うたい
# 扱う	他人の希望	扱うたがる
# 扱う	て	扱って
# 扱う	です・ます	扱います
# アップする	可能	アップアップできれる
# アップする	受け身	アップアップさられる
# アップする	使役	アップアップさせる
# アップする	過去	アップアップした
# アップする	否定	アップアップしない
# アップする	推定	アップアップするらしい
# アップする	様態	アップアップするそう
# アップする	伝聞	アップアップするそうだ
# アップする	例示	アップアップするようだ
# アップする	勧誘	アップアップしう
# アップする	自分の希望	アップアップさたい
# アップする	他人の希望	アップアップさたがる
# アップする	て	アップアップして
# アップする	です・ます	アップアップします
# あてはめる	可能	あてはめる
# あてはめる	受け身	あてはめられる
# あてはめる	使役	あてはめせる
# あてはめる	過去	あてはめた
# あてはめる	否定	あてはめない
# あてはめる	推定	あてはめるらしい
# あてはめる	様態	あてはめるそう
# あてはめる	伝聞	あてはめるそうだ
# あてはめる	例示	あてはめるようだ
# あてはめる	勧誘	あてはめう
# あてはめる	自分の希望	あてはめたい
# あてはめる	他人の希望	あてはめたがる
# あてはめる	て	あてはめて
# あてはめる	です・ます	あてはめます
# 当てる	可能	当てる
# 当てる	受け身	当てられる
# 当てる	使役	当てせる
# 当てる	過去	当てた
# 当てる	否定	当てない
# 当てる	推定	当てるらしい
# 当てる	様態	当てるそう
# 当てる	伝聞	当てるそうだ
# 当てる	例示	当てるようだ
# 当てる	勧誘	当てう
# 当てる	自分の希望	当てたい
# 当てる	他人の希望	当てたがる
# 当てる	て	当てて
# 当てる	です・ます	当てます
# あてる	可能	あてる
# あてる	受け身	あてられる
# あてる	使役	あてせる
# あてる	過去	あてた
# あてる	否定	あてない
# あてる	推定	あてるらしい
# あてる	様態	あてるそう
# あてる	伝聞	あてるそうだ
# あてる	例示	あてるようだ
# あてる	勧誘	あてう
# あてる	自分の希望	あてたい
# あてる	他人の希望	あてたがる
# あてる	て	あてて
# あてる	です・ます	あてます
# 後片づけする	可能	後片づけ後片づけできれる
# 後片づけする	受け身	後片づけ後片づけさられる
# 後片づけする	使役	後片づけ後片づけさせる
# 後片づけする	過去	後片づけ後片づけした
# 後片づけする	否定	後片づけ後片づけしない
# 後片づけする	推定	後片づけ後片づけするらしい
# 後片づけする	様態	後片づけ後片づけするそう
# 後片づけする	伝聞	後片づけ後片づけするそうだ
# 後片づけする	例示	後片づけ後片づけするようだ
# 後片づけする	勧誘	後片づけ後片づけしう
# 後片づけする	自分の希望	後片づけ後片づけさたい
# 後片づけする	他人の希望	後片づけ後片づけさたがる
# 後片づけする	て	後片づけ後片づけして
# 後片づけする	です・ます	後片づけ後片づけします
# アドバイスする	可能	アドバイスアドバイスできれる
# アドバイスする	受け身	アドバイスアドバイスさられる
# アドバイスする	使役	アドバイスアドバイスさせる
# アドバイスする	過去	アドバイスアドバイスした
# アドバイスする	否定	アドバイスアドバイスしない
# アドバイスする	推定	アドバイスアドバイスするらしい
# アドバイスする	様態	アドバイスアドバイスするそう
# アドバイスする	伝聞	アドバイスアドバイスするそうだ
# アドバイスする	例示	アドバイスアドバイスするようだ
# アドバイスする	勧誘	アドバイスアドバイスしう
# アドバイスする	自分の希望	アドバイスアドバイスさたい
# アドバイスする	他人の希望	アドバイスアドバイスさたがる
# アドバイスする	て	アドバイスアドバイスして
# アドバイスする	です・ます	アドバイスアドバイスします
# アナウンスする	可能	アナウンスアナウンスできれる
# アナウンスする	受け身	アナウンスアナウンスさられる
# アナウンスする	使役	アナウンスアナウンスさせる
# アナウンスする	過去	アナウンスアナウンスした
# アナウンスする	否定	アナウンスアナウンスしない
# アナウンスする	推定	アナウンスアナウンスするらしい
# アナウンスする	様態	アナウンスアナウンスするそう
# アナウンスする	伝聞	アナウンスアナウンスするそうだ
# アナウンスする	例示	アナウンスアナウンスするようだ
# アナウンスする	勧誘	アナウンスアナウンスしう
# アナウンスする	自分の希望	アナウンスアナウンスさたい
# アナウンスする	他人の希望	アナウンスアナウンスさたがる
# アナウンスする	て	アナウンスアナウンスして
# アナウンスする	です・ます	アナウンスアナウンスします
# あふれる	可能	あふれる
# あふれる	受け身	あふれられる
# あふれる	使役	あふれせる
# あふれる	過去	あふれた
# あふれる	否定	あふれない
# あふれる	推定	あふれるらしい
# あふれる	様態	あふれるそう
# あふれる	伝聞	あふれるそうだ
# あふれる	例示	あふれるようだ
# あふれる	勧誘	あふれう
# あふれる	自分の希望	あふれたい
# あふれる	他人の希望	あふれたがる
# あふれる	て	あふれて
# あふれる	です・ます	あふれます
# 甘やかす	可能	甘やかせる
# 甘やかす	受け身	甘やかすられる
# 甘やかす	使役	甘やかすせる
# 甘やかす	過去	甘やかした
# 甘やかす	否定	甘やかさない
# 甘やかす	推定	甘やかすらしい
# 甘やかす	様態	甘やかすそう
# 甘やかす	伝聞	甘やかすそうだ
# 甘やかす	例示	甘やかすようだ
# 甘やかす	勧誘	甘やかそう
# 甘やかす	自分の希望	甘やかすたい
# 甘やかす	他人の希望	甘やかすたがる
# 甘やかす	て	甘やかして
# 甘やかす	です・ます	甘やかします
# 誤る	可能	誤れる
# 誤る	受け身	誤るられる
# 誤る	使役	誤るせる
# 誤る	過去	誤った
# 誤る	否定	誤らない
# 誤る	推定	誤るらしい
# 誤る	様態	誤るそう
# 誤る	伝聞	誤るそうだ
# 誤る	例示	誤るようだ
# 誤る	勧誘	誤ろう
# 誤る	自分の希望	誤るたい
# 誤る	他人の希望	誤るたがる
# 誤る	て	誤って
# 誤る	です・ます	誤ります
# 歩む	可能	歩める
# 歩む	受け身	歩むられる
# 歩む	使役	歩むせる
# 歩む	過去	歩んだ
# 歩む	否定	歩まない
# 歩む	推定	歩むらしい
# 歩む	様態	歩むそう
# 歩む	伝聞	歩むそうだ
# 歩む	例示	歩むようだ
# 歩む	勧誘	歩もう
# 歩む	自分の希望	歩むたい
# 歩む	他人の希望	歩むたがる
# 歩む	て	歩んて
# 歩む	です・ます	歩みます
# 争う	可能	争える
# 争う	受け身	争うられる
# 争う	使役	争うせる
# 争う	過去	争った
# 争う	否定	争あない
# 争う	推定	争うらしい
# 争う	様態	争うそう
# 争う	伝聞	争うそうだ
# 争う	例示	争うようだ
# 争う	勧誘	争おう
# 争う	自分の希望	争うたい
# 争う	他人の希望	争うたがる
# 争う	て	争って
# 争う	です・ます	争います
# 改まる	可能	改まれる
# 改まる	受け身	改まるられる
# 改まる	使役	改まるせる
# 改まる	過去	改まった
# 改まる	否定	改まらない
# 改まる	推定	改まるらしい
# 改まる	様態	改まるそう
# 改まる	伝聞	改まるそうだ
# 改まる	例示	改まるようだ
# 改まる	勧誘	改まろう
# 改まる	自分の希望	改まるたい
# 改まる	他人の希望	改まるたがる
# 改まる	て	改まって
# 改まる	です・ます	改まります
# 表す	可能	表せる
# 表す	受け身	表すられる
# 表す	使役	表すせる
# 表す	過去	表した
# 表す	否定	表さない
# 表す	推定	表すらしい
# 表す	様態	表すそう
# 表す	伝聞	表すそうだ
# 表す	例示	表すようだ
# 表す	勧誘	表そう
# 表す	自分の希望	表すたい
# 表す	他人の希望	表すたがる
# 表す	て	表して
# 表す	です・ます	表します
# 表わす	可能	表わせる
# 表わす	受け身	表わすられる
# 表わす	使役	表わすせる
# 表わす	過去	表わした
# 表わす	否定	表わさない
# 表わす	推定	表わすらしい
# 表わす	様態	表わすそう
# 表わす	伝聞	表わすそうだ
# 表わす	例示	表わすようだ
# 表わす	勧誘	表わそう
# 表わす	自分の希望	表わすたい
# 表わす	他人の希望	表わすたがる
# 表わす	て	表わして
# 表わす	です・ます	表わします
# 現れる	可能	現れる
# 現れる	受け身	現れられる
# 現れる	使役	現れせる
# 現れる	過去	現れた
# 現れる	否定	現れない
# 現れる	推定	現れるらしい
# 現れる	様態	現れるそう
# 現れる	伝聞	現れるそうだ
# 現れる	例示	現れるようだ
# 現れる	勧誘	現れう
# 現れる	自分の希望	現れたい
# 現れる	他人の希望	現れたがる
# 現れる	て	現れて
# 現れる	です・ます	現れます
# 現われる	可能	現われる
# 現われる	受け身	現われられる
# 現われる	使役	現われせる
# 現われる	過去	現われた
# 現われる	否定	現われない
# 現われる	推定	現われるらしい
# 現われる	様態	現われるそう
# 現われる	伝聞	現われるそうだ
# 現われる	例示	現われるようだ
# 現われる	勧誘	現われう
# 現われる	自分の希望	現われたい
# 現われる	他人の希望	現われたがる
# 現われる	て	現われて
# 現われる	です・ます	現われます
# 歩き回る	可能	歩き歩き回れる
# 歩き回る	受け身	歩き歩き回るられる
# 歩き回る	使役	歩き歩き回るせる
# 歩き回る	過去	歩き歩き回った
# 歩き回る	否定	歩き歩き回らない
# 歩き回る	推定	歩き歩き回るらしい
# 歩き回る	様態	歩き歩き回るそう
# 歩き回る	伝聞	歩き歩き回るそうだ
# 歩き回る	例示	歩き歩き回るようだ
# 歩き回る	勧誘	歩き歩き回ろう
# 歩き回る	自分の希望	歩き歩き回るたい
# 歩き回る	他人の希望	歩き歩き回るたがる
# 歩き回る	て	歩き歩き回って
# 歩き回る	です・ます	歩き歩き回ります
# 合わせる	可能	合わせる
# 合わせる	受け身	合わせられる
# 合わせる	使役	合わせせる
# 合わせる	過去	合わせた
# 合わせる	否定	合わせない
# 合わせる	推定	合わせるらしい
# 合わせる	様態	合わせるそう
# 合わせる	伝聞	合わせるそうだ
# 合わせる	例示	合わせるようだ
# 合わせる	勧誘	合わせう
# 合わせる	自分の希望	合わせたい
# 合わせる	他人の希望	合わせたがる
# 合わせる	て	合わせて
# 合わせる	です・ます	合わせます
# 慌てる	可能	慌てる
# 慌てる	受け身	慌てられる
# 慌てる	使役	慌てせる
# 慌てる	過去	慌てた
# 慌てる	否定	慌てない
# 慌てる	推定	慌てるらしい
# 慌てる	様態	慌てるそう
# 慌てる	伝聞	慌てるそうだ
# 慌てる	例示	慌てるようだ
# 慌てる	勧誘	慌てう
# 慌てる	自分の希望	慌てたい
# 慌てる	他人の希望	慌てたがる
# 慌てる	て	慌てて
# 慌てる	です・ます	慌てます
# 安定する	可能	安定安定できれる
# 安定する	受け身	安定安定さられる
# 安定する	使役	安定安定させる
# 安定する	過去	安定安定した
# 安定する	否定	安定安定しない
# 安定する	推定	安定安定するらしい
# 安定する	様態	安定安定するそう
# 安定する	伝聞	安定安定するそうだ
# 安定する	例示	安定安定するようだ
# 安定する	勧誘	安定安定しう
# 安定する	自分の希望	安定安定さたい
# 安定する	他人の希望	安定安定さたがる
# 安定する	て	安定安定して
# 安定する	です・ます	安定安定します
# 言い合う	可能	言い言い合える
# 言い合う	受け身	言い言い合うられる
# 言い合う	使役	言い言い合うせる
# 言い合う	過去	言い言い合った
# 言い合う	否定	言い言い合あない
# 言い合う	推定	言い言い合うらしい
# 言い合う	様態	言い言い合うそう
# 言い合う	伝聞	言い言い合うそうだ
# 言い合う	例示	言い言い合うようだ
# 言い合う	勧誘	言い言い合おう
# 言い合う	自分の希望	言い言い合うたい
# 言い合う	他人の希望	言い言い合うたがる
# 言い合う	て	言い言い合って
# 言い合う	です・ます	言い言い合います
# 言い表す	可能	言い表せる
# 言い表す	受け身	言い表すられる
# 言い表す	使役	言い表すせる
# 言い表す	過去	言い表した
# 言い表す	否定	言い表さない
# 言い表す	推定	言い表すらしい
# 言い表す	様態	言い表すそう
# 言い表す	伝聞	言い表すそうだ
# 言い表す	例示	言い表すようだ
# 言い表す	勧誘	言い表そう
# 言い表す	自分の希望	言い表すたい
# 言い表す	他人の希望	言い表すたがる
# 言い表す	て	言い表して
# 言い表す	です・ます	言い表します
# 言い返す	可能	言い言い返せる
# 言い返す	受け身	言い言い返すられる
# 言い返す	使役	言い言い返すせる
# 言い返す	過去	言い言い返した
# 言い返す	否定	言い言い返さない
# 言い返す	推定	言い言い返すらしい
# 言い返す	様態	言い言い返すそう
# 言い返す	伝聞	言い言い返すそうだ
# 言い返す	例示	言い言い返すようだ
# 言い返す	勧誘	言い言い返そう
# 言い返す	自分の希望	言い言い返すたい
# 言い返す	他人の希望	言い言い返すたがる
# 言い返す	て	言い言い返して
# 言い返す	です・ます	言い言い返します
# 言い換える	可能	言い言い換える
# 言い換える	受け身	言い言い換えられる
# 言い換える	使役	言い言い換えせる
# 言い換える	過去	言い言い換えた
# 言い換える	否定	言い言い換えない
# 言い換える	推定	言い言い換えるらしい
# 言い換える	様態	言い言い換えるそう
# 言い換える	伝聞	言い言い換えるそうだ
# 言い換える	例示	言い言い換えるようだ
# 言い換える	勧誘	言い言い換えう
# 言い換える	自分の希望	言い言い換えたい
# 言い換える	他人の希望	言い言い換えたがる
# 言い換える	て	言い言い換えて
# 言い換える	です・ます	言い言い換えます
# 言い訳する	可能	言い訳言い訳できれる
# 言い訳する	受け身	言い訳言い訳さられる
# 言い訳する	使役	言い訳言い訳させる
# 言い訳する	過去	言い訳言い訳した
# 言い訳する	否定	言い訳言い訳しない
# 言い訳する	推定	言い訳言い訳するらしい
# 言い訳する	様態	言い訳言い訳するそう
# 言い訳する	伝聞	言い訳言い訳するそうだ
# 言い訳する	例示	言い訳言い訳するようだ
# 言い訳する	勧誘	言い訳言い訳しう
# 言い訳する	自分の希望	言い訳言い訳さたい
# 言い訳する	他人の希望	言い訳言い訳さたがる
# 言い訳する	て	言い訳言い訳して
# 言い訳する	です・ます	言い訳言い訳します
# 生かす	可能	生かせる
# 生かす	受け身	生かすられる
# 生かす	使役	生かすせる
# 生かす	過去	生かした
# 生かす	否定	生かさない
# 生かす	推定	生かすらしい
# 生かす	様態	生かすそう
# 生かす	伝聞	生かすそうだ
# 生かす	例示	生かすようだ
# 生かす	勧誘	生かそう
# 生かす	自分の希望	生かすたい
# 生かす	他人の希望	生かすたがる
# 生かす	て	生かして
# 生かす	です・ます	生かします
# 生き生きする	可能	生き生き生き生きすれる
# 生き生きする	受け身	生き生き生き生きするられる
# 生き生きする	使役	生き生き生き生きするせる
# 生き生きする	過去	生き生き生き生きすった
# 生き生きする	否定	生き生き生き生きすらない
# 生き生きする	推定	生き生き生き生きするらしい
# 生き生きする	様態	生き生き生き生きするそう
# 生き生きする	伝聞	生き生き生き生きするそうだ
# 生き生きする	例示	生き生き生き生きするようだ
# 生き生きする	勧誘	生き生き生き生きすろう
# 生き生きする	自分の希望	生き生き生き生きするたい
# 生き生きする	他人の希望	生き生き生き生きするたがる
# 生き生きする	て	生き生き生き生きすって
# 生き生きする	です・ます	生き生き生き生きすります
# 生きる	可能	生きる
# 生きる	受け身	生きられる
# 生きる	使役	生きせる
# 生きる	過去	生きた
# 生きる	否定	生きない
# 生きる	推定	生きるらしい
# 生きる	様態	生きるそう
# 生きる	伝聞	生きるそうだ
# 生きる	例示	生きるようだ
# 生きる	勧誘	生きう
# 生きる	自分の希望	生きたい
# 生きる	他人の希望	生きたがる
# 生きる	て	生きて
# 生きる	です・ます	生きます
# 行く	可能	行ける
# 行く	受け身	行くられる
# 行く	使役	行くせる
# 行く	過去	行った
# 行く	否定	行かない
# 行く	推定	行くらしい
# 行く	様態	行くそう
# 行く	伝聞	行くそうだ
# 行く	例示	行くようだ
# 行く	勧誘	行こう
# 行く	自分の希望	行くたい
# 行く	他人の希望	行くたがる
# 行く	て	行って
# 行く	です・ます	行きます
# 維持する	可能	維持維持できれる
# 維持する	受け身	維持維持さられる
# 維持する	使役	維持維持させる
# 維持する	過去	維持維持した
# 維持する	否定	維持維持しない
# 維持する	推定	維持維持するらしい
# 維持する	様態	維持維持するそう
# 維持する	伝聞	維持維持するそうだ
# 維持する	例示	維持維持するようだ
# 維持する	勧誘	維持維持しう
# 維持する	自分の希望	維持維持さたい
# 維持する	他人の希望	維持維持さたがる
# 維持する	て	維持維持して
# 維持する	です・ます	維持維持します
# 意識する	可能	意識意識できれる
# 意識する	受け身	意識意識さられる
# 意識する	使役	意識意識させる
# 意識する	過去	意識意識した
# 意識する	否定	意識意識しない
# 意識する	推定	意識意識するらしい
# 意識する	様態	意識意識するそう
# 意識する	伝聞	意識意識するそうだ
# 意識する	例示	意識意識するようだ
# 意識する	勧誘	意識意識しう
# 意識する	自分の希望	意識意識さたい
# 意識する	他人の希望	意識意識さたがる
# 意識する	て	意識意識して
# 意識する	です・ます	意識意識します
# いじめる	可能	いじめる
# いじめる	受け身	いじめられる
# いじめる	使役	いじめせる
# いじめる	過去	いじめた
# いじめる	否定	いじめない
# いじめる	推定	いじめるらしい
# いじめる	様態	いじめるそう
# いじめる	伝聞	いじめるそうだ
# いじめる	例示	いじめるようだ
# いじめる	勧誘	いじめう
# いじめる	自分の希望	いじめたい
# いじめる	他人の希望	いじめたがる
# いじめる	て	いじめて
# いじめる	です・ます	いじめます
# 抱く	可能	抱ける
# 抱く	受け身	抱くられる
# 抱く	使役	抱くせる
# 抱く	過去	抱いた
# 抱く	否定	抱かない
# 抱く	推定	抱くらしい
# 抱く	様態	抱くそう
# 抱く	伝聞	抱くそうだ
# 抱く	例示	抱くようだ
# 抱く	勧誘	抱こう
# 抱く	自分の希望	抱くたい
# 抱く	他人の希望	抱くたがる
# 抱く	て	抱いて
# 抱く	です・ます	抱きます
# 痛む	可能	痛める
# 痛む	受け身	痛むられる
# 痛む	使役	痛むせる
# 痛む	過去	痛んだ
# 痛む	否定	痛まない
# 痛む	推定	痛むらしい
# 痛む	様態	痛むそう
# 痛む	伝聞	痛むそうだ
# 痛む	例示	痛むようだ
# 痛む	勧誘	痛もう
# 痛む	自分の希望	痛むたい
# 痛む	他人の希望	痛むたがる
# 痛む	て	痛んて
# 痛む	です・ます	痛みます
# いためる	可能	いためる
# いためる	受け身	いためられる
# いためる	使役	いためせる
# いためる	過去	いためた
# いためる	否定	いためない
# いためる	推定	いためるらしい
# いためる	様態	いためるそう
# いためる	伝聞	いためるそうだ
# いためる	例示	いためるようだ
# いためる	勧誘	いためう
# いためる	自分の希望	いためたい
# いためる	他人の希望	いためたがる
# いためる	て	いためて
# いためる	です・ます	いためます
# 痛める	可能	痛める
# 痛める	受け身	痛められる
# 痛める	使役	痛めせる
# 痛める	過去	痛めた
# 痛める	否定	痛めない
# 痛める	推定	痛めるらしい
# 痛める	様態	痛めるそう
# 痛める	伝聞	痛めるそうだ
# 痛める	例示	痛めるようだ
# 痛める	勧誘	痛めう
# 痛める	自分の希望	痛めたい
# 痛める	他人の希望	痛めたがる
# 痛める	て	痛めて
# 痛める	です・ます	痛めます
# 至る	可能	至れる
# 至る	受け身	至るられる
# 至る	使役	至るせる
# 至る	過去	至った
# 至る	否定	至らない
# 至る	推定	至るらしい
# 至る	様態	至るそう
# 至る	伝聞	至るそうだ
# 至る	例示	至るようだ
# 至る	勧誘	至ろう
# 至る	自分の希望	至るたい
# 至る	他人の希望	至るたがる
# 至る	て	至って
# 至る	です・ます	至ります
# 一致する	可能	一致一致できれる
# 一致する	受け身	一致一致さられる
# 一致する	使役	一致一致させる
# 一致する	過去	一致一致した
# 一致する	否定	一致一致しない
# 一致する	推定	一致一致するらしい
# 一致する	様態	一致一致するそう
# 一致する	伝聞	一致一致するそうだ
# 一致する	例示	一致一致するようだ
# 一致する	勧誘	一致一致しう
# 一致する	自分の希望	一致一致さたい
# 一致する	他人の希望	一致一致さたがる
# 一致する	て	一致一致して
# 一致する	です・ます	一致一致します
# 一服する	可能	一服一服できれる
# 一服する	受け身	一服一服さられる
# 一服する	使役	一服一服させる
# 一服する	過去	一服一服した
# 一服する	否定	一服一服しない
# 一服する	推定	一服一服するらしい
# 一服する	様態	一服一服するそう
# 一服する	伝聞	一服一服するそうだ
# 一服する	例示	一服一服するようだ
# 一服する	勧誘	一服一服しう
# 一服する	自分の希望	一服一服さたい
# 一服する	他人の希望	一服一服さたがる
# 一服する	て	一服一服して
# 一服する	です・ます	一服一服します
# 意図する	可能	意図意図できれる
# 意図する	受け身	意図意図さられる
# 意図する	使役	意図意図させる
# 意図する	過去	意図意図した
# 意図する	否定	意図意図しない
# 意図する	推定	意図意図するらしい
# 意図する	様態	意図意図するそう
# 意図する	伝聞	意図意図するそうだ
# 意図する	例示	意図意図するようだ
# 意図する	勧誘	意図意図しう
# 意図する	自分の希望	意図意図さたい
# 意図する	他人の希望	意図意図さたがる
# 意図する	て	意図意図して
# 意図する	です・ます	意図意図します
# 営む	可能	営める
# 営む	受け身	営むられる
# 営む	使役	営むせる
# 営む	過去	営んだ
# 営む	否定	営まない
# 営む	推定	営むらしい
# 営む	様態	営むそう
# 営む	伝聞	営むそうだ
# 営む	例示	営むようだ
# 営む	勧誘	営もう
# 営む	自分の希望	営むたい
# 営む	他人の希望	営むたがる
# 営む	て	営んて
# 営む	です・ます	営みます
# 威張る	可能	威張れる
# 威張る	受け身	威張るられる
# 威張る	使役	威張るせる
# 威張る	過去	威張った
# 威張る	否定	威張らない
# 威張る	推定	威張るらしい
# 威張る	様態	威張るそう
# 威張る	伝聞	威張るそうだ
# 威張る	例示	威張るようだ
# 威張る	勧誘	威張ろう
# 威張る	自分の希望	威張るたい
# 威張る	他人の希望	威張るたがる
# 威張る	て	威張って
# 威張る	です・ます	威張ります
# イメージする	可能	イメージイメージできれる
# イメージする	受け身	イメージイメージさられる
# イメージする	使役	イメージイメージさせる
# イメージする	過去	イメージイメージした
# イメージする	否定	イメージイメージしない
# イメージする	推定	イメージイメージするらしい
# イメージする	様態	イメージイメージするそう
# イメージする	伝聞	イメージイメージするそうだ
# イメージする	例示	イメージイメージするようだ
# イメージする	勧誘	イメージイメージしう
# イメージする	自分の希望	イメージイメージさたい
# イメージする	他人の希望	イメージイメージさたがる
# イメージする	て	イメージイメージして
# イメージする	です・ます	イメージイメージします
# 嫌がらせする	可能	嫌がらせ嫌がらせできれる
# 嫌がらせする	受け身	嫌がらせ嫌がらせさられる
# 嫌がらせする	使役	嫌がらせ嫌がらせさせる
# 嫌がらせする	過去	嫌がらせ嫌がらせした
# 嫌がらせする	否定	嫌がらせ嫌がらせしない
# 嫌がらせする	推定	嫌がらせ嫌がらせするらしい
# 嫌がらせする	様態	嫌がらせ嫌がらせするそう
# 嫌がらせする	伝聞	嫌がらせ嫌がらせするそうだ
# 嫌がらせする	例示	嫌がらせ嫌がらせするようだ
# 嫌がらせする	勧誘	嫌がらせ嫌がらせしう
# 嫌がらせする	自分の希望	嫌がらせ嫌がらせさたい
# 嫌がらせする	他人の希望	嫌がらせ嫌がらせさたがる
# 嫌がらせする	て	嫌がらせ嫌がらせして
# 嫌がらせする	です・ます	嫌がらせ嫌がらせします
# 癒す	可能	癒せる
# 癒す	受け身	癒すられる
# 癒す	使役	癒すせる
# 癒す	過去	癒した
# 癒す	否定	癒さない
# 癒す	推定	癒すらしい
# 癒す	様態	癒すそう
# 癒す	伝聞	癒すそうだ
# 癒す	例示	癒すようだ
# 癒す	勧誘	癒そう
# 癒す	自分の希望	癒すたい
# 癒す	他人の希望	癒すたがる
# 癒す	て	癒して
# 癒す	です・ます	癒します
# 印刷する	可能	印刷印刷できれる
# 印刷する	受け身	印刷印刷さられる
# 印刷する	使役	印刷印刷させる
# 印刷する	過去	印刷印刷した
# 印刷する	否定	印刷印刷しない
# 印刷する	推定	印刷印刷するらしい
# 印刷する	様態	印刷印刷するそう
# 印刷する	伝聞	印刷印刷するそうだ
# 印刷する	例示	印刷印刷するようだ
# 印刷する	勧誘	印刷印刷しう
# 印刷する	自分の希望	印刷印刷さたい
# 印刷する	他人の希望	印刷印刷さたがる
# 印刷する	て	印刷印刷して
# 印刷する	です・ます	印刷印刷します
# 引退する	可能	引退引退できれる
# 引退する	受け身	引退引退さられる
# 引退する	使役	引退引退させる
# 引退する	過去	引退引退した
# 引退する	否定	引退引退しない
# 引退する	推定	引退引退するらしい
# 引退する	様態	引退引退するそう
# 引退する	伝聞	引退引退するそうだ
# 引退する	例示	引退引退するようだ
# 引退する	勧誘	引退引退しう
# 引退する	自分の希望	引退引退さたい
# 引退する	他人の希望	引退引退さたがる
# 引退する	て	引退引退して
# 引退する	です・ます	引退引退します
# ウインクする	可能	ウインクウインクできれる
# ウインクする	受け身	ウインクウインクさられる
# ウインクする	使役	ウインクウインクさせる
# ウインクする	過去	ウインクウインクした
# ウインクする	否定	ウインクウインクしない
# ウインクする	推定	ウインクウインクするらしい
# ウインクする	様態	ウインクウインクするそう
# ウインクする	伝聞	ウインクウインクするそうだ
# ウインクする	例示	ウインクウインクするようだ
# ウインクする	勧誘	ウインクウインクしう
# ウインクする	自分の希望	ウインクウインクさたい
# ウインクする	他人の希望	ウインクウインクさたがる
# ウインクする	て	ウインクウインクして
# ウインクする	です・ます	ウインクウインクします
# ウインドーショッピングする	可能	ウインドーショッピングウインドーショッピングできれる
# ウインドーショッピングする	受け身	ウインドーショッピングウインドーショッピングさられる
# ウインドーショッピングする	使役	ウインドーショッピングウインドーショッピングさせる
# ウインドーショッピングする	過去	ウインドーショッピングウインドーショッピングした
# ウインドーショッピングする	否定	ウインドーショッピングウインドーショッピングしない
# ウインドーショッピングする	推定	ウインドーショッピングウインドーショッピングするらしい
# ウインドーショッピングする	様態	ウインドーショッピングウインドーショッピングするそう
# ウインドーショッピングする	伝聞	ウインドーショッピングウインドーショッピングするそうだ
# ウインドーショッピングする	例示	ウインドーショッピングウインドーショッピングするようだ
# ウインドーショッピングする	勧誘	ウインドーショッピングウインドーショッピングしう
# ウインドーショッピングする	自分の希望	ウインドーショッピングウインドーショッピングさたい
# ウインドーショッピングする	他人の希望	ウインドーショッピングウインドーショッピングさたがる
# ウインドーショッピングする	て	ウインドーショッピングウインドーショッピングして
# ウインドーショッピングする	です・ます	ウインドーショッピングウインドーショッピングします
# うかがう	可能	うかがえる
# うかがう	受け身	うかがうられる
# うかがう	使役	うかがうせる
# うかがう	過去	うかがった
# うかがう	否定	うかがあない
# うかがう	推定	うかがうらしい
# うかがう	様態	うかがうそう
# うかがう	伝聞	うかがうそうだ
# うかがう	例示	うかがうようだ
# うかがう	勧誘	うかがおう
# うかがう	自分の希望	うかがうたい
# うかがう	他人の希望	うかがうたがる
# うかがう	て	うかがって
# うかがう	です・ます	うかがいます
# 浮かぶ	可能	浮かべる
# 浮かぶ	受け身	浮かぶられる
# 浮かぶ	使役	浮かぶせる
# 浮かぶ	過去	浮かんだ
# 浮かぶ	否定	浮かばない
# 浮かぶ	推定	浮かぶらしい
# 浮かぶ	様態	浮かぶそう
# 浮かぶ	伝聞	浮かぶそうだ
# 浮かぶ	例示	浮かぶようだ
# 浮かぶ	勧誘	浮かぼう
# 浮かぶ	自分の希望	浮かぶたい
# 浮かぶ	他人の希望	浮かぶたがる
# 浮かぶ	て	浮かんて
# 浮かぶ	です・ます	浮かびます
# 浮き上がる	可能	浮き浮き上がれる
# 浮き上がる	受け身	浮き浮き上がるられる
# 浮き上がる	使役	浮き浮き上がるせる
# 浮き上がる	過去	浮き浮き上がった
# 浮き上がる	否定	浮き浮き上がらない
# 浮き上がる	推定	浮き浮き上がるらしい
# 浮き上がる	様態	浮き浮き上がるそう
# 浮き上がる	伝聞	浮き浮き上がるそうだ
# 浮き上がる	例示	浮き浮き上がるようだ
# 浮き上がる	勧誘	浮き浮き上がろう
# 浮き上がる	自分の希望	浮き浮き上がるたい
# 浮き上がる	他人の希望	浮き浮き上がるたがる
# 浮き上がる	て	浮き浮き上がって
# 浮き上がる	です・ます	浮き浮き上がります
# 浮く	可能	浮ける
# 浮く	受け身	浮くられる
# 浮く	使役	浮くせる
# 浮く	過去	浮いた
# 浮く	否定	浮かない
# 浮く	推定	浮くらしい
# 浮く	様態	浮くそう
# 浮く	伝聞	浮くそうだ
# 浮く	例示	浮くようだ
# 浮く	勧誘	浮こう
# 浮く	自分の希望	浮くたい
# 浮く	他人の希望	浮くたがる
# 浮く	て	浮いて
# 浮く	です・ます	浮きます
# 承る	可能	承れる
# 承る	受け身	承るられる
# 承る	使役	承るせる
# 承る	過去	承った
# 承る	否定	承らない
# 承る	推定	承るらしい
# 承る	様態	承るそう
# 承る	伝聞	承るそうだ
# 承る	例示	承るようだ
# 承る	勧誘	承ろう
# 承る	自分の希望	承るたい
# 承る	他人の希望	承るたがる
# 承る	て	承って
# 承る	です・ます	承ります
# 受け付ける	可能	受け付ける
# 受け付ける	受け身	受け付けられる
# 受け付ける	使役	受け付けせる
# 受け付ける	過去	受け付けた
# 受け付ける	否定	受け付けない
# 受け付ける	推定	受け付けるらしい
# 受け付ける	様態	受け付けるそう
# 受け付ける	伝聞	受け付けるそうだ
# 受け付ける	例示	受け付けるようだ
# 受け付ける	勧誘	受け付けう
# 受け付ける	自分の希望	受け付けたい
# 受け付ける	他人の希望	受け付けたがる
# 受け付ける	て	受け付けて
# 受け付ける	です・ます	受け付けます
# 受け取る	可能	受け取れる
# 受け取る	受け身	受け取るられる
# 受け取る	使役	受け取るせる
# 受け取る	過去	受け取った
# 受け取る	否定	受け取らない
# 受け取る	推定	受け取るらしい
# 受け取る	様態	受け取るそう
# 受け取る	伝聞	受け取るそうだ
# 受け取る	例示	受け取るようだ
# 受け取る	勧誘	受け取ろう
# 受け取る	自分の希望	受け取るたい
# 受け取る	他人の希望	受け取るたがる
# 受け取る	て	受け取って
# 受け取る	です・ます	受け取ります
# 失う	可能	失える
# 失う	受け身	失うられる
# 失う	使役	失うせる
# 失う	過去	失った
# 失う	否定	失あない
# 失う	推定	失うらしい
# 失う	様態	失うそう
# 失う	伝聞	失うそうだ
# 失う	例示	失うようだ
# 失う	勧誘	失おう
# 失う	自分の希望	失うたい
# 失う	他人の希望	失うたがる
# 失う	て	失って
# 失う	です・ます	失います
# 疑う	可能	疑える
# 疑う	受け身	疑うられる
# 疑う	使役	疑うせる
# 疑う	過去	疑った
# 疑う	否定	疑あない
# 疑う	推定	疑うらしい
# 疑う	様態	疑うそう
# 疑う	伝聞	疑うそうだ
# 疑う	例示	疑うようだ
# 疑う	勧誘	疑おう
# 疑う	自分の希望	疑うたい
# 疑う	他人の希望	疑うたがる
# 疑う	て	疑って
# 疑う	です・ます	疑います
# 打ち上げる	可能	打ち上げる
# 打ち上げる	受け身	打ち上げられる
# 打ち上げる	使役	打ち上げせる
# 打ち上げる	過去	打ち上げた
# 打ち上げる	否定	打ち上げない
# 打ち上げる	推定	打ち上げるらしい
# 打ち上げる	様態	打ち上げるそう
# 打ち上げる	伝聞	打ち上げるそうだ
# 打ち上げる	例示	打ち上げるようだ
# 打ち上げる	勧誘	打ち上げう
# 打ち上げる	自分の希望	打ち上げたい
# 打ち上げる	他人の希望	打ち上げたがる
# 打ち上げる	て	打ち上げて
# 打ち上げる	です・ます	打ち上げます
# 打ち合わせる	可能	打ち合わせる
# 打ち合わせる	受け身	打ち合わせられる
# 打ち合わせる	使役	打ち合わせせる
# 打ち合わせる	過去	打ち合わせた
# 打ち合わせる	否定	打ち合わせない
# 打ち合わせる	推定	打ち合わせるらしい
# 打ち合わせる	様態	打ち合わせるそう
# 打ち合わせる	伝聞	打ち合わせるそうだ
# 打ち合わせる	例示	打ち合わせるようだ
# 打ち合わせる	勧誘	打ち合わせう
# 打ち合わせる	自分の希望	打ち合わせたい
# 打ち合わせる	他人の希望	打ち合わせたがる
# 打ち合わせる	て	打ち合わせて
# 打ち合わせる	です・ます	打ち合わせます
# 映す	可能	映せる
# 映す	受け身	映すられる
# 映す	使役	映すせる
# 映す	過去	映した
# 映す	否定	映さない
# 映す	推定	映すらしい
# 映す	様態	映すそう
# 映す	伝聞	映すそうだ
# 映す	例示	映すようだ
# 映す	勧誘	映そう
# 映す	自分の希望	映すたい
# 映す	他人の希望	映すたがる
# 映す	て	映して
# 映す	です・ます	映します
# 訴える	可能	訴える
# 訴える	受け身	訴えられる
# 訴える	使役	訴えせる
# 訴える	過去	訴えた
# 訴える	否定	訴えない
# 訴える	推定	訴えるらしい
# 訴える	様態	訴えるそう
# 訴える	伝聞	訴えるそうだ
# 訴える	例示	訴えるようだ
# 訴える	勧誘	訴えう
# 訴える	自分の希望	訴えたい
# 訴える	他人の希望	訴えたがる
# 訴える	て	訴えて
# 訴える	です・ます	訴えます
# 映る	可能	映れる
# 映る	受け身	映るられる
# 映る	使役	映るせる
# 映る	過去	映った
# 映る	否定	映らない
# 映る	推定	映るらしい
# 映る	様態	映るそう
# 映る	伝聞	映るそうだ
# 映る	例示	映るようだ
# 映る	勧誘	映ろう
# 映る	自分の希望	映るたい
# 映る	他人の希望	映るたがる
# 映る	て	映って
# 映る	です・ます	映ります
# 写る	可能	写れる
# 写る	受け身	写るられる
# 写る	使役	写るせる
# 写る	過去	写った
# 写る	否定	写らない
# 写る	推定	写るらしい
# 写る	様態	写るそう
# 写る	伝聞	写るそうだ
# 写る	例示	写るようだ
# 写る	勧誘	写ろう
# 写る	自分の希望	写るたい
# 写る	他人の希望	写るたがる
# 写る	て	写って
# 写る	です・ます	写ります
# 移る	可能	移れる
# 移る	受け身	移るられる
# 移る	使役	移るせる
# 移る	過去	移った
# 移る	否定	移らない
# 移る	推定	移るらしい
# 移る	様態	移るそう
# 移る	伝聞	移るそうだ
# 移る	例示	移るようだ
# 移る	勧誘	移ろう
# 移る	自分の希望	移るたい
# 移る	他人の希望	移るたがる
# 移る	て	移って
# 移る	です・ます	移ります
# うなずく	可能	うなずける
# うなずく	受け身	うなずくられる
# うなずく	使役	うなずくせる
# うなずく	過去	うなずいた
# うなずく	否定	うなずかない
# うなずく	推定	うなずくらしい
# うなずく	様態	うなずくそう
# うなずく	伝聞	うなずくそうだ
# うなずく	例示	うなずくようだ
# うなずく	勧誘	うなずこう
# うなずく	自分の希望	うなずくたい
# うなずく	他人の希望	うなずくたがる
# うなずく	て	うなずいて
# うなずく	です・ます	うなずきます
# 奪い取る	可能	奪い取れる
# 奪い取る	受け身	奪い取るられる
# 奪い取る	使役	奪い取るせる
# 奪い取る	過去	奪い取った
# 奪い取る	否定	奪い取らない
# 奪い取る	推定	奪い取るらしい
# 奪い取る	様態	奪い取るそう
# 奪い取る	伝聞	奪い取るそうだ
# 奪い取る	例示	奪い取るようだ
# 奪い取る	勧誘	奪い取ろう
# 奪い取る	自分の希望	奪い取るたい
# 奪い取る	他人の希望	奪い取るたがる
# 奪い取る	て	奪い取って
# 奪い取る	です・ます	奪い取ります
# 奪う	可能	奪える
# 奪う	受け身	奪うられる
# 奪う	使役	奪うせる
# 奪う	過去	奪った
# 奪う	否定	奪あない
# 奪う	推定	奪うらしい
# 奪う	様態	奪うそう
# 奪う	伝聞	奪うそうだ
# 奪う	例示	奪うようだ
# 奪う	勧誘	奪おう
# 奪う	自分の希望	奪うたい
# 奪う	他人の希望	奪うたがる
# 奪う	て	奪って
# 奪う	です・ます	奪います
# 埋め立てる	可能	埋め埋め立てる
# 埋め立てる	受け身	埋め埋め立てられる
# 埋め立てる	使役	埋め埋め立てせる
# 埋め立てる	過去	埋め埋め立てた
# 埋め立てる	否定	埋め埋め立てない
# 埋め立てる	推定	埋め埋め立てるらしい
# 埋め立てる	様態	埋め埋め立てるそう
# 埋め立てる	伝聞	埋め埋め立てるそうだ
# 埋め立てる	例示	埋め埋め立てるようだ
# 埋め立てる	勧誘	埋め埋め立てう
# 埋め立てる	自分の希望	埋め埋め立てたい
# 埋め立てる	他人の希望	埋め埋め立てたがる
# 埋め立てる	て	埋め埋め立てて
# 埋め立てる	です・ます	埋め埋め立てます
# 埋める	可能	埋める
# 埋める	受け身	埋められる
# 埋める	使役	埋めせる
# 埋める	過去	埋めた
# 埋める	否定	埋めない
# 埋める	推定	埋めるらしい
# 埋める	様態	埋めるそう
# 埋める	伝聞	埋めるそうだ
# 埋める	例示	埋めるようだ
# 埋める	勧誘	埋めう
# 埋める	自分の希望	埋めたい
# 埋める	他人の希望	埋めたがる
# 埋める	て	埋めて
# 埋める	です・ます	埋めます
# 裏切る	可能	裏切れる
# 裏切る	受け身	裏切るられる
# 裏切る	使役	裏切るせる
# 裏切る	過去	裏切った
# 裏切る	否定	裏切らない
# 裏切る	推定	裏切るらしい
# 裏切る	様態	裏切るそう
# 裏切る	伝聞	裏切るそうだ
# 裏切る	例示	裏切るようだ
# 裏切る	勧誘	裏切ろう
# 裏切る	自分の希望	裏切るたい
# 裏切る	他人の希望	裏切るたがる
# 裏切る	て	裏切って
# 裏切る	です・ます	裏切ります
# 占う	可能	占える
# 占う	受け身	占うられる
# 占う	使役	占うせる
# 占う	過去	占った
# 占う	否定	占あない
# 占う	推定	占うらしい
# 占う	様態	占うそう
# 占う	伝聞	占うそうだ
# 占う	例示	占うようだ
# 占う	勧誘	占おう
# 占う	自分の希望	占うたい
# 占う	他人の希望	占うたがる
# 占う	て	占って
# 占う	です・ます	占います
# うらやむ	可能	うらやめる
# うらやむ	受け身	うらやむられる
# うらやむ	使役	うらやむせる
# うらやむ	過去	うらやんだ
# うらやむ	否定	うらやまない
# うらやむ	推定	うらやむらしい
# うらやむ	様態	うらやむそう
# うらやむ	伝聞	うらやむそうだ
# うらやむ	例示	うらやむようだ
# うらやむ	勧誘	うらやもう
# うらやむ	自分の希望	うらやむたい
# うらやむ	他人の希望	うらやむたがる
# うらやむ	て	うらやんて
# うらやむ	です・ます	うらやみます
# 売り上げる	可能	売り売り上げる
# 売り上げる	受け身	売り売り上げられる
# 売り上げる	使役	売り売り上げせる
# 売り上げる	過去	売り売り上げた
# 売り上げる	否定	売り売り上げない
# 売り上げる	推定	売り売り上げるらしい
# 売り上げる	様態	売り売り上げるそう
# 売り上げる	伝聞	売り売り上げるそうだ
# 売り上げる	例示	売り売り上げるようだ
# 売り上げる	勧誘	売り売り上げう
# 売り上げる	自分の希望	売り売り上げたい
# 売り上げる	他人の希望	売り売り上げたがる
# 売り上げる	て	売り売り上げて
# 売り上げる	です・ます	売り売り上げます
# 浮気する	可能	浮気浮気できれる
# 浮気する	受け身	浮気浮気さられる
# 浮気する	使役	浮気浮気させる
# 浮気する	過去	浮気浮気した
# 浮気する	否定	浮気浮気しない
# 浮気する	推定	浮気浮気するらしい
# 浮気する	様態	浮気浮気するそう
# 浮気する	伝聞	浮気浮気するそうだ
# 浮気する	例示	浮気浮気するようだ
# 浮気する	勧誘	浮気浮気しう
# 浮気する	自分の希望	浮気浮気さたい
# 浮気する	他人の希望	浮気浮気さたがる
# 浮気する	て	浮気浮気して
# 浮気する	です・ます	浮気浮気する
# 上回る	可能	上回れる
# 上回る	受け身	上回るられる
# 上回る	使役	上回るせる
# 上回る	過去	上回った
# 上回る	否定	上回らない
# 上回る	推定	上回るらしい
# 上回る	様態	上回るそう
# 上回る	伝聞	上回るそうだ
# 上回る	例示	上回るようだ
# 上回る	勧誘	上回ろう
# 上回る	自分の希望	上回るたい
# 上回る	他人の希望	上回るたがる
# 上回る	て	上回って
# 上回る	です・ます	上回ります
# 運営する	可能	運営運営できれる
# 運営する	受け身	運営運営さられる
# 運営する	使役	運営運営させる
# 運営する	過去	運営運営した
# 運営する	否定	運営運営しない
# 運営する	推定	運営運営するらしい
# 運営する	様態	運営運営するそう
# 運営する	伝聞	運営運営するそうだ
# 運営する	例示	運営運営するようだ
# 運営する	勧誘	運営運営しう
# 運営する	自分の希望	運営運営さたい
# 運営する	他人の希望	運営運営さたがる
# 運営する	て	運営運営して
# 運営する	です・ます	運営運営します
# 運搬する	可能	運搬運搬できれる
# 運搬する	受け身	運搬運搬さられる
# 運搬する	使役	運搬運搬させる
# 運搬する	過去	運搬運搬した
# 運搬する	否定	運搬運搬しない
# 運搬する	推定	運搬運搬するらしい
# 運搬する	様態	運搬運搬するそう
# 運搬する	伝聞	運搬運搬するそうだ
# 運搬する	例示	運搬運搬するようだ
# 運搬する	勧誘	運搬運搬しう
# 運搬する	自分の希望	運搬運搬さたい
# 運搬する	他人の希望	運搬運搬さたがる
# 運搬する	て	運搬運搬して
# 運搬する	です・ます	運搬運搬します
# 影響する	可能	影響影響できれる
# 影響する	受け身	影響影響さられる
# 影響する	使役	影響影響させる
# 影響する	過去	影響影響した
# 影響する	否定	影響影響しない
# 影響する	推定	影響影響するらしい
# 影響する	様態	影響影響するそう
# 影響する	伝聞	影響影響するそうだ
# 影響する	例示	影響影響するようだ
# 影響する	勧誘	影響影響しう
# 影響する	自分の希望	影響影響さたい
# 影響する	他人の希望	影響影響さたがる
# 影響する	て	影響影響して
# 影響する	です・ます	影響影響します
# 描く	可能	描ける
# 描く	受け身	描くられる
# 描く	使役	描くせる
# 描く	過去	描いた
# 描く	否定	描かない
# 描く	推定	描くらしい
# 描く	様態	描くそう
# 描く	伝聞	描くそうだ
# 描く	例示	描くようだ
# 描く	勧誘	描こう
# 描く	自分の希望	描くたい
# 描く	他人の希望	描くたがる
# 描く	て	描いて
# 描く	です・ます	描きます
# 得る	可能	得る
# 得る	受け身	得られる
# 得る	使役	得せる
# 得る	過去	得た
# 得る	否定	得ない
# 得る	推定	得るらしい
# 得る	様態	得るそう
# 得る	伝聞	得るそうだ
# 得る	例示	得るようだ
# 得る	勧誘	得う
# 得る	自分の希望	得たい
# 得る	他人の希望	得たがる
# 得る	て	得て
# 得る	です・ます	得ます
# 延期する	可能	延期延期できれる
# 延期する	受け身	延期延期さられる
# 延期する	使役	延期延期させる
# 延期する	過去	延期延期した
# 延期する	否定	延期延期しない
# 延期する	推定	延期延期するらしい
# 延期する	様態	延期延期するそう
# 延期する	伝聞	延期延期するそうだ
# 延期する	例示	延期延期するようだ
# 延期する	勧誘	延期延期しう
# 延期する	自分の希望	延期延期さたい
# 延期する	他人の希望	延期延期さたがる
# 延期する	て	延期延期して
# 延期する	です・ます	延期延期します
# 演技する	可能	演技演技できれる
# 演技する	受け身	演技演技さられる
# 演技する	使役	演技演技させる
# 演技する	過去	演技演技した
# 演技する	否定	演技演技しない
# 演技する	推定	演技演技するらしい
# 演技する	様態	演技演技するそう
# 演技する	伝聞	演技演技するそうだ
# 演技する	例示	演技演技するようだ
# 演技する	勧誘	演技演技しう
# 演技する	自分の希望	演技演技さたい
# 演技する	他人の希望	演技演技さたがる
# 演技する	て	演技演技して
# 演技する	です・ます	演技演技します
# エンストする	可能	エンストエンストできれる
# エンストする	受け身	エンストエンストさられる
# エンストする	使役	エンストエンストさせる
# エンストする	過去	エンストエンストした
# エンストする	否定	エンストエンストしない
# エンストする	推定	エンストエンストするらしい
# エンストする	様態	エンストエンストするそう
# エンストする	伝聞	エンストエンストするそうだ
# エンストする	例示	エンストエンストするようだ
# エンストする	勧誘	エンストエンストしう
# エンストする	自分の希望	エンストエンストさたい
# エンストする	他人の希望	エンストエンストさたがる
# エンストする	て	エンストエンストして
# エンストする	です・ます	エンストエンストします
# 演奏する	可能	演奏演奏できれる
# 演奏する	受け身	演奏演奏さられる
# 演奏する	使役	演奏演奏させる
# 演奏する	過去	演奏演奏した
# 演奏する	否定	演奏演奏しない
# 演奏する	推定	演奏演奏するらしい
# 演奏する	様態	演奏演奏するそう
# 演奏する	伝聞	演奏演奏するそうだ
# 演奏する	例示	演奏演奏するようだ
# 演奏する	勧誘	演奏演奏しう
# 演奏する	自分の希望	演奏演奏さたい
# 演奏する	他人の希望	演奏演奏さたがる
# 演奏する	て	演奏演奏して
# 演奏する	です・ます	演奏演奏します
# 延長する	可能	延長延長できれる
# 延長する	受け身	延長延長さられる
# 延長する	使役	延長延長させる
# 延長する	過去	延長延長した
# 延長する	否定	延長延長しない
# 延長する	推定	延長延長するらしい
# 延長する	様態	延長延長するそう
# 延長する	伝聞	延長延長するそうだ
# 延長する	例示	延長延長するようだ
# 延長する	勧誘	延長延長しう
# 延長する	自分の希望	延長延長さたい
# 延長する	他人の希望	延長延長さたがる
# 延長する	て	延長延長して
# 延長する	です・ます	延長延長します
# 追いかける	可能	追い追いかける
# 追いかける	受け身	追い追いかけられる
# 追いかける	使役	追い追いかけせる
# 追いかける	過去	追い追いかけた
# 追いかける	否定	追い追いかけない
# 追いかける	推定	追い追いかけるらしい
# 追いかける	様態	追い追いかけるそう
# 追いかける	伝聞	追い追いかけるそうだ
# 追いかける	例示	追い追いかけるようだ
# 追いかける	勧誘	追い追いかけう
# 追いかける	自分の希望	追い追いかけたい
# 追いかける	他人の希望	追い追いかけたがる
# 追いかける	て	追い追いかけて
# 追いかける	です・ます	追い追いかけます
# 追いつく	可能	追いつける
# 追いつく	受け身	追いつくられる
# 追いつく	使役	追いつくせる
# 追いつく	過去	追いついた
# 追いつく	否定	追いつかない
# 追いつく	推定	追いつくらしい
# 追いつく	様態	追いつくそう
# 追いつく	伝聞	追いつくそうだ
# 追いつく	例示	追いつくようだ
# 追いつく	勧誘	追いつこう
# 追いつく	自分の希望	追いつくたい
# 追いつく	他人の希望	追いつくたがる
# 追いつく	て	追いついて
# 追いつく	です・ます	追いつきます
# 追い抜く	可能	追い抜ける
# 追い抜く	受け身	追い抜くられる
# 追い抜く	使役	追い抜くせる
# 追い抜く	過去	追い抜いた
# 追い抜く	否定	追い抜かない
# 追い抜く	推定	追い抜くらしい
# 追い抜く	様態	追い抜くそう
# 追い抜く	伝聞	追い抜くそうだ
# 追い抜く	例示	追い抜くようだ
# 追い抜く	勧誘	追い抜こう
# 追い抜く	自分の希望	追い抜くたい
# 追い抜く	他人の希望	追い抜くたがる
# 追い抜く	て	追い抜いて
# 追い抜く	です・ます	追い抜きます
# 追いやる	可能	追いやれる
# 追いやる	受け身	追いやるられる
# 追いやる	使役	追いやるせる
# 追いやる	過去	追いやった
# 追いやる	否定	追いやらない
# 追いやる	推定	追いやるらしい
# 追いやる	様態	追いやるそう
# 追いやる	伝聞	追いやるそうだ
# 追いやる	例示	追いやるようだ
# 追いやる	勧誘	追いやろう
# 追いやる	自分の希望	追いやるたい
# 追いやる	他人の希望	追いやるたがる
# 追いやる	て	追いやって
# 追いやる	です・ます	追いやります
# 追う	可能	追える
# 追う	受け身	追うられる
# 追う	使役	追うせる
# 追う	過去	追った
# 追う	否定	追あない
# 追う	推定	追うらしい
# 追う	様態	追うそう
# 追う	伝聞	追うそうだ
# 追う	例示	追うようだ
# 追う	勧誘	追おう
# 追う	自分の希望	追うたい
# 追う	他人の希望	追うたがる
# 追う	て	追って
# 追う	です・ます	追います
# 負う	可能	負える
# 負う	受け身	負うられる
# 負う	使役	負うせる
# 負う	過去	負った
# 負う	否定	負あない
# 負う	推定	負うらしい
# 負う	様態	負うそう
# 負う	伝聞	負うそうだ
# 負う	例示	負うようだ
# 負う	勧誘	負おう
# 負う	自分の希望	負うたい
# 負う	他人の希望	負うたがる
# 負う	て	負って
# 負う	です・ます	負います
# 応援する	可能	応援応援できれる
# 応援する	受け身	応援応援さられる
# 応援する	使役	応援応援させる
# 応援する	過去	応援応援した
# 応援する	否定	応援応援しない
# 応援する	推定	応援応援するらしい
# 応援する	様態	応援応援するそう
# 応援する	伝聞	応援応援するそうだ
# 応援する	例示	応援応援するようだ
# 応援する	勧誘	応援応援しう
# 応援する	自分の希望	応援応援さたい
# 応援する	他人の希望	応援応援さたがる
# 応援する	て	応援応援して
# 応援する	です・ます	応援応援します
# 応じる	可能	応じる
# 応じる	受け身	応じられる
# 応じる	使役	応じせる
# 応じる	過去	応じた
# 応じる	否定	応じない
# 応じる	推定	応じるらしい
# 応じる	様態	応じるそう
# 応じる	伝聞	応じるそうだ
# 応じる	例示	応じるようだ
# 応じる	勧誘	応じう
# 応じる	自分の希望	応じたい
# 応じる	他人の希望	応じたがる
# 応じる	て	応じて
# 応じる	です・ます	応じます
# 往復する	可能	往復往復できれる
# 往復する	受け身	往復往復さられる
# 往復する	使役	往復往復させる
# 往復する	過去	往復往復した
# 往復する	否定	往復往復しない
# 往復する	推定	往復往復するらしい
# 往復する	様態	往復往復するそう
# 往復する	伝聞	往復往復するそうだ
# 往復する	例示	往復往復するようだ
# 往復する	勧誘	往復往復しう
# 往復する	自分の希望	往復往復さたい
# 往復する	他人の希望	往復往復さたがる
# 往復する	て	往復往復して
# 往復する	です・ます	往復往復します
# 応募する	可能	応募応募できれる
# 応募する	受け身	応募応募さられる
# 応募する	使役	応募応募させる
# 応募する	過去	応募応募した
# 応募する	否定	応募応募しない
# 応募する	推定	応募応募するらしい
# 応募する	様態	応募応募するそう
# 応募する	伝聞	応募応募するそうだ
# 応募する	例示	応募応募するようだ
# 応募する	勧誘	応募応募しう
# 応募する	自分の希望	応募応募さたい
# 応募する	他人の希望	応募応募さたがる
# 応募する	て	応募応募して
# 応募する	です・ます	応募応募します
# 覆う	可能	覆える
# 覆う	受け身	覆うられる
# 覆う	使役	覆うせる
# 覆う	過去	覆った
# 覆う	否定	覆あない
# 覆う	推定	覆うらしい
# 覆う	様態	覆うそう
# 覆う	伝聞	覆うそうだ
# 覆う	例示	覆うようだ
# 覆う	勧誘	覆おう
# 覆う	自分の希望	覆うたい
# 覆う	他人の希望	覆うたがる
# 覆う	て	覆って
# 覆う	です・ます	覆います
# オーバーする	可能	オーバーオーバーできれる
# オーバーする	受け身	オーバーオーバーさられる
# オーバーする	使役	オーバーオーバーさせる
# オーバーする	過去	オーバーオーバーした
# オーバーする	否定	オーバーオーバーしない
# オーバーする	推定	オーバーオーバーするらしい
# オーバーする	様態	オーバーオーバーするそう
# オーバーする	伝聞	オーバーオーバーするそうだ
# オーバーする	例示	オーバーオーバーするようだ
# オーバーする	勧誘	オーバーオーバーしう
# オーバーする	自分の希望	オーバーオーバーさたい
# オーバーする	他人の希望	オーバーオーバーさたがる
# オーバーする	て	オーバーオーバーして
# オーバーする	です・ます	オーバーオーバーします
# 犯す	可能	犯せる
# 犯す	受け身	犯すられる
# 犯す	使役	犯すせる
# 犯す	過去	犯した
# 犯す	否定	犯さない
# 犯す	推定	犯すらしい
# 犯す	様態	犯すそう
# 犯す	伝聞	犯すそうだ
# 犯す	例示	犯すようだ
# 犯す	勧誘	犯そう
# 犯す	自分の希望	犯すたい
# 犯す	他人の希望	犯すたがる
# 犯す	て	犯して
# 犯す	です・ます	犯します
# おかわりする	可能	おかわりおかわりできれる
# おかわりする	受け身	おかわりおかわりさられる
# おかわりする	使役	おかわりおかわりさせる
# おかわりする	過去	おかわりおかわりした
# おかわりする	否定	おかわりおかわりしない
# おかわりする	推定	おかわりおかわりするらしい
# おかわりする	様態	おかわりおかわりするそう
# おかわりする	伝聞	おかわりおかわりするそうだ
# おかわりする	例示	おかわりおかわりするようだ
# おかわりする	勧誘	おかわりおかわりしう
# おかわりする	自分の希望	おかわりおかわりさたい
# おかわりする	他人の希望	おかわりおかわりさたがる
# おかわりする	て	おかわりおかわりして
# おかわりする	です・ます	おかわりおかわりします
# 置き換える	可能	置き換える
# 置き換える	受け身	置き換えられる
# 置き換える	使役	置き換えせる
# 置き換える	過去	置き換えた
# 置き換える	否定	置き換えない
# 置き換える	推定	置き換えるらしい
# 置き換える	様態	置き換えるそう
# 置き換える	伝聞	置き換えるそうだ
# 置き換える	例示	置き換えるようだ
# 置き換える	勧誘	置き換えう
# 置き換える	自分の希望	置き換えたい
# 置き換える	他人の希望	置き換えたがる
# 置き換える	て	置き換えて
# 置き換える	です・ます	置き換えます
# 補う	可能	補える
# 補う	受け身	補うられる
# 補う	使役	補うせる
# 補う	過去	補った
# 補う	否定	補あない
# 補う	推定	補うらしい
# 補う	様態	補うそう
# 補う	伝聞	補うそうだ
# 補う	例示	補うようだ
# 補う	勧誘	補おう
# 補う	自分の希望	補うたい
# 補う	他人の希望	補うたがる
# 補う	て	補って
# 補う	です・ます	補います
# 起こる	可能	起これる
# 起こる	受け身	起こるられる
# 起こる	使役	起こるせる
# 起こる	過去	起こった
# 起こる	否定	起こらない
# 起こる	推定	起こるらしい
# 起こる	様態	起こるそう
# 起こる	伝聞	起こるそうだ
# 起こる	例示	起こるようだ
# 起こる	勧誘	起ころう
# 起こる	自分の希望	起こるたい
# 起こる	他人の希望	起こるたがる
# 起こる	て	起こって
# 起こる	です・ます	起こります
# 怒る	可能	怒れる
# 怒る	受け身	怒るられる
# 怒る	使役	怒るせる
# 怒る	過去	怒った
# 怒る	否定	怒らない
# 怒る	推定	怒るらしい
# 怒る	様態	怒るそう
# 怒る	伝聞	怒るそうだ
# 怒る	例示	怒るようだ
# 怒る	勧誘	怒ろう
# 怒る	自分の希望	怒るたい
# 怒る	他人の希望	怒るたがる
# 怒る	て	怒って
# 怒る	です・ます	怒ります
# おごる	可能	おごれる
# おごる	受け身	おごるられる
# おごる	使役	おごるせる
# おごる	過去	おごった
# おごる	否定	おごらない
# おごる	推定	おごるらしい
# おごる	様態	おごるそう
# おごる	伝聞	おごるそうだ
# おごる	例示	おごるようだ
# おごる	勧誘	おごろう
# おごる	自分の希望	おごるたい
# おごる	他人の希望	おごるたがる
# おごる	て	おごって
# おごる	です・ます	おごります
# 抑える	可能	抑える
# 抑える	受け身	抑えられる
# 抑える	使役	抑えせる
# 抑える	過去	抑えた
# 抑える	否定	抑えない
# 抑える	推定	抑えるらしい
# 抑える	様態	抑えるそう
# 抑える	伝聞	抑えるそうだ
# 抑える	例示	抑えるようだ
# 抑える	勧誘	抑えう
# 抑える	自分の希望	抑えたい
# 抑える	他人の希望	抑えたがる
# 抑える	て	抑えて
# 抑える	です・ます	抑えます
# 治まる	可能	治まれる
# 治まる	受け身	治まるられる
# 治まる	使役	治まるせる
# 治まる	過去	治まった
# 治まる	否定	治まらない
# 治まる	推定	治まるらしい
# 治まる	様態	治まるそう
# 治まる	伝聞	治まるそうだ
# 治まる	例示	治まるようだ
# 治まる	勧誘	治まろう
# 治まる	自分の希望	治まるたい
# 治まる	他人の希望	治まるたがる
# 治まる	て	治まって
# 治まる	です・ます	治まります
# 納める	可能	納める
# 納める	受け身	納められる
# 納める	使役	納めせる
# 納める	過去	納めた
# 納める	否定	納めない
# 納める	推定	納めるらしい
# 納める	様態	納めるそう
# 納める	伝聞	納めるそうだ
# 納める	例示	納めるようだ
# 納める	勧誘	納めう
# 納める	自分の希望	納めたい
# 納める	他人の希望	納めたがる
# 納める	て	納めて
# 納める	です・ます	納めます
# 治める	可能	治める
# 治める	受け身	治められる
# 治める	使役	治めせる
# 治める	過去	治めた
# 治める	否定	治めない
# 治める	推定	治めるらしい
# 治める	様態	治めるそう
# 治める	伝聞	治めるそうだ
# 治める	例示	治めるようだ
# 治める	勧誘	治めう
# 治める	自分の希望	治めたい
# 治める	他人の希望	治めたがる
# 治める	て	治めて
# 治める	です・ます	治めます
# おじぎする	可能	おじぎおじぎできれる
# おじぎする	受け身	おじぎおじぎさられる
# おじぎする	使役	おじぎおじぎさせる
# おじぎする	過去	おじぎおじぎした
# おじぎする	否定	おじぎおじぎしない
# おじぎする	推定	おじぎおじぎするらしい
# おじぎする	様態	おじぎおじぎするそう
# おじぎする	伝聞	おじぎおじぎするそうだ
# おじぎする	例示	おじぎおじぎするようだ
# おじぎする	勧誘	おじぎおじぎしう
# おじぎする	自分の希望	おじぎおじぎさたい
# おじぎする	他人の希望	おじぎおじぎさたがる
# おじぎする	て	おじぎおじぎして
# おじぎする	です・ます	おじぎおじぎします
# 押し倒す	可能	押し倒せる
# 押し倒す	受け身	押し倒すられる
# 押し倒す	使役	押し倒すせる
# 押し倒す	過去	押し倒した
# 押し倒す	否定	押し倒さない
# 押し倒す	推定	押し倒すらしい
# 押し倒す	様態	押し倒すそう
# 押し倒す	伝聞	押し倒すそうだ
# 押し倒す	例示	押し倒すようだ
# 押し倒す	勧誘	押し倒そう
# 押し倒す	自分の希望	押し倒すたい
# 押し倒す	他人の希望	押し倒すたがる
# 押し倒す	て	押し倒して
# 押し倒す	です・ます	押し倒します
# 惜しむ	可能	惜しめる
# 惜しむ	受け身	惜しむられる
# 惜しむ	使役	惜しむせる
# 惜しむ	過去	惜しんだ
# 惜しむ	否定	惜しまない
# 惜しむ	推定	惜しむらしい
# 惜しむ	様態	惜しむそう
# 惜しむ	伝聞	惜しむそうだ
# 惜しむ	例示	惜しむようだ
# 惜しむ	勧誘	惜しもう
# 惜しむ	自分の希望	惜しむたい
# 惜しむ	他人の希望	惜しむたがる
# 惜しむ	て	惜しんて
# 惜しむ	です・ます	惜しみます
# おしゃべりする	可能	おしゃべりおしゃべりできれる
# おしゃべりする	受け身	おしゃべりおしゃべりさられる
# おしゃべりする	使役	おしゃべりおしゃべりさせる
# おしゃべりする	過去	おしゃべりおしゃべりした
# おしゃべりする	否定	おしゃべりおしゃべりしない
# おしゃべりする	推定	おしゃべりおしゃべりするらしい
# おしゃべりする	様態	おしゃべりおしゃべりするそう
# おしゃべりする	伝聞	おしゃべりおしゃべりするそうだ
# おしゃべりする	例示	おしゃべりおしゃべりするようだ
# おしゃべりする	勧誘	おしゃべりおしゃべりしう
# おしゃべりする	自分の希望	おしゃべりおしゃべりさたい
# おしゃべりする	他人の希望	おしゃべりおしゃべりさたがる
# おしゃべりする	て	おしゃべりおしゃべりして
# おしゃべりする	です・ます	おしゃべりおしゃべりします
# 押し寄せる	可能	押し寄せる
# 押し寄せる	受け身	押し寄せられる
# 押し寄せる	使役	押し寄せせる
# 押し寄せる	過去	押し寄せた
# 押し寄せる	否定	押し寄せない
# 押し寄せる	推定	押し寄せるらしい
# 押し寄せる	様態	押し寄せるそう
# 押し寄せる	伝聞	押し寄せるそうだ
# 押し寄せる	例示	押し寄せるようだ
# 押し寄せる	勧誘	押し寄せう
# 押し寄せる	自分の希望	押し寄せたい
# 押し寄せる	他人の希望	押し寄せたがる
# 押し寄せる	て	押し寄せて
# 押し寄せる	です・ます	押し寄せます
# 汚染する	可能	汚染汚染できれる
# 汚染する	受け身	汚染汚染さられる
# 汚染する	使役	汚染汚染させる
# 汚染する	過去	汚染汚染した
# 汚染する	否定	汚染汚染しない
# 汚染する	推定	汚染汚染するらしい
# 汚染する	様態	汚染汚染するそう
# 汚染する	伝聞	汚染汚染するそうだ
# 汚染する	例示	汚染汚染するようだ
# 汚染する	勧誘	汚染汚染しう
# 汚染する	自分の希望	汚染汚染さたい
# 汚染する	他人の希望	汚染汚染さたがる
# 汚染する	て	汚染汚染して
# 汚染する	です・ます	汚染汚染します
# 恐れ入る	可能	恐れ入れる
# 恐れ入る	受け身	恐れ入るられる
# 恐れ入る	使役	恐れ入るせる
# 恐れ入る	過去	恐れ入った
# 恐れ入る	否定	恐れ入らない
# 恐れ入る	推定	恐れ入るらしい
# 恐れ入る	様態	恐れ入るそう
# 恐れ入る	伝聞	恐れ入るそうだ
# 恐れ入る	例示	恐れ入るようだ
# 恐れ入る	勧誘	恐れ入ろう
# 恐れ入る	自分の希望	恐れ入るたい
# 恐れ入る	他人の希望	恐れ入るたがる
# 恐れ入る	て	恐れ入って
# 恐れ入る	です・ます	恐れ入ります
# 恐れる	可能	恐れる
# 恐れる	受け身	恐れられる
# 恐れる	使役	恐れせる
# 恐れる	過去	恐れた
# 恐れる	否定	恐れない
# 恐れる	推定	恐れるらしい
# 恐れる	様態	恐れるそう
# 恐れる	伝聞	恐れるそうだ
# 恐れる	例示	恐れるようだ
# 恐れる	勧誘	恐れう
# 恐れる	自分の希望	恐れたい
# 恐れる	他人の希望	恐れたがる
# 恐れる	て	恐れて
# 恐れる	です・ます	恐れます
# 教わる	可能	教われる
# 教わる	受け身	教わるられる
# 教わる	使役	教わるせる
# 教わる	過去	教わった
# 教わる	否定	教わらない
# 教わる	推定	教わるらしい
# 教わる	様態	教わるそう
# 教わる	伝聞	教わるそうだ
# 教わる	例示	教わるようだ
# 教わる	勧誘	教わろう
# 教わる	自分の希望	教わるたい
# 教わる	他人の希望	教わるたがる
# 教わる	て	教わって
# 教わる	です・ます	教わります
# 落ち込む	可能	落ち落ち込める
# 落ち込む	受け身	落ち落ち込むられる
# 落ち込む	使役	落ち落ち込むせる
# 落ち込む	過去	落ち落ち込んだ
# 落ち込む	否定	落ち落ち込まない
# 落ち込む	推定	落ち落ち込むらしい
# 落ち込む	様態	落ち落ち込むそう
# 落ち込む	伝聞	落ち落ち込むそうだ
# 落ち込む	例示	落ち落ち込むようだ
# 落ち込む	勧誘	落ち落ち込もう
# 落ち込む	自分の希望	落ち落ち込むたい
# 落ち込む	他人の希望	落ち落ち込むたがる
# 落ち込む	て	落ち落ち込んて
# 落ち込む	です・ます	落ち落ち込みます
# 落ち着く	可能	落ち着ける
# 落ち着く	受け身	落ち着くられる
# 落ち着く	使役	落ち着くせる
# 落ち着く	過去	落ち着いた
# 落ち着く	否定	落ち着かない
# 落ち着く	推定	落ち着くらしい
# 落ち着く	様態	落ち着くそう
# 落ち着く	伝聞	落ち着くそうだ
# 落ち着く	例示	落ち着くようだ
# 落ち着く	勧誘	落ち着こう
# 落ち着く	自分の希望	落ち着くたい
# 落ち着く	他人の希望	落ち着くたがる
# 落ち着く	て	落ち着いて
# 落ち着く	です・ます	落ち着きます
# 訪れる	可能	訪れる
# 訪れる	受け身	訪れられる
# 訪れる	使役	訪れせる
# 訪れる	過去	訪れた
# 訪れる	否定	訪れない
# 訪れる	推定	訪れるらしい
# 訪れる	様態	訪れるそう
# 訪れる	伝聞	訪れるそうだ
# 訪れる	例示	訪れるようだ
# 訪れる	勧誘	訪れう
# 訪れる	自分の希望	訪れたい
# 訪れる	他人の希望	訪れたがる
# 訪れる	て	訪れて
# 訪れる	です・ます	訪れます
# 衰える	可能	衰える
# 衰える	受け身	衰えられる
# 衰える	使役	衰えせる
# 衰える	過去	衰えた
# 衰える	否定	衰えない
# 衰える	推定	衰えるらしい
# 衰える	様態	衰えるそう
# 衰える	伝聞	衰えるそうだ
# 衰える	例示	衰えるようだ
# 衰える	勧誘	衰えう
# 衰える	自分の希望	衰えたい
# 衰える	他人の希望	衰えたがる
# 衰える	て	衰えて
# 衰える	です・ます	衰えます
# 驚く	可能	驚ける
# 驚く	受け身	驚くられる
# 驚く	使役	驚くせる
# 驚く	過去	驚いた
# 驚く	否定	驚かない
# 驚く	推定	驚くらしい
# 驚く	様態	驚くそう
# 驚く	伝聞	驚くそうだ
# 驚く	例示	驚くようだ
# 驚く	勧誘	驚こう
# 驚く	自分の希望	驚くたい
# 驚く	他人の希望	驚くたがる
# 驚く	て	驚いて
# 驚く	です・ます	驚きます
# 脅かす	可能	脅かせる
# 脅かす	受け身	脅かすられる
# 脅かす	使役	脅かすせる
# 脅かす	過去	脅かした
# 脅かす	否定	脅かさない
# 脅かす	推定	脅かすらしい
# 脅かす	様態	脅かすそう
# 脅かす	伝聞	脅かすそうだ
# 脅かす	例示	脅かすようだ
# 脅かす	勧誘	脅かそう
# 脅かす	自分の希望	脅かすたい
# 脅かす	他人の希望	脅かすたがる
# 脅かす	て	脅かして
# 脅かす	です・ます	脅かします
# 帯びる	可能	帯びる
# 帯びる	受け身	帯びられる
# 帯びる	使役	帯びせる
# 帯びる	過去	帯びた
# 帯びる	否定	帯びない
# 帯びる	推定	帯びるらしい
# 帯びる	様態	帯びるそう
# 帯びる	伝聞	帯びるそうだ
# 帯びる	例示	帯びるようだ
# 帯びる	勧誘	帯びう
# 帯びる	自分の希望	帯びたい
# 帯びる	他人の希望	帯びたがる
# 帯びる	て	帯びて
# 帯びる	です・ます	帯びます
# 覚える	可能	覚える
# 覚える	受け身	覚えられる
# 覚える	使役	覚えせる
# 覚える	過去	覚えた
# 覚える	否定	覚えない
# 覚える	推定	覚えるらしい
# 覚える	様態	覚えるそう
# 覚える	伝聞	覚えるそうだ
# 覚える	例示	覚えるようだ
# 覚える	勧誘	覚えう
# 覚える	自分の希望	覚えたい
# 覚える	他人の希望	覚えたがる
# 覚える	て	覚えて
# 覚える	です・ます	覚えます
# おぼれる	可能	おぼれる
# おぼれる	受け身	おぼれられる
# おぼれる	使役	おぼれせる
# おぼれる	過去	おぼれた
# おぼれる	否定	おぼれない
# おぼれる	推定	おぼれるらしい
# おぼれる	様態	おぼれるそう
# おぼれる	伝聞	おぼれるそうだ
# おぼれる	例示	おぼれるようだ
# おぼれる	勧誘	おぼれう
# おぼれる	自分の希望	おぼれたい
# おぼれる	他人の希望	おぼれたがる
# おぼれる	て	おぼれて
# おぼれる	です・ます	おぼれます
# 思い浮かぶ	可能	思い浮かべる
# 思い浮かぶ	受け身	思い浮かぶられる
# 思い浮かぶ	使役	思い浮かぶせる
# 思い浮かぶ	過去	思い浮かんだ
# 思い浮かぶ	否定	思い浮かばない
# 思い浮かぶ	推定	思い浮かぶらしい
# 思い浮かぶ	様態	思い浮かぶそう
# 思い浮かぶ	伝聞	思い浮かぶそうだ
# 思い浮かぶ	例示	思い浮かぶようだ
# 思い浮かぶ	勧誘	思い浮かぼう
# 思い浮かぶ	自分の希望	思い浮かぶたい
# 思い浮かぶ	他人の希望	思い浮かぶたがる
# 思い浮かぶ	て	思い浮かんて
# 思い浮かぶ	です・ます	思い浮かびます
# 思い込む	可能	思い思い込める
# 思い込む	受け身	思い思い込むられる
# 思い込む	使役	思い思い込むせる
# 思い込む	過去	思い思い込んだ
# 思い込む	否定	思い思い込まない
# 思い込む	推定	思い思い込むらしい
# 思い込む	様態	思い思い込むそう
# 思い込む	伝聞	思い思い込むそうだ
# 思い込む	例示	思い思い込むようだ
# 思い込む	勧誘	思い思い込もう
# 思い込む	自分の希望	思い思い込むたい
# 思い込む	他人の希望	思い思い込むたがる
# 思い込む	て	思い思い込んて
# 思い込む	です・ます	思い思い込みます
# 思いつく	可能	思い思いつける
# 思いつく	受け身	思い思いつくられる
# 思いつく	使役	思い思いつくせる
# 思いつく	過去	思い思いついた
# 思いつく	否定	思い思いつかない
# 思いつく	推定	思い思いつくらしい
# 思いつく	様態	思い思いつくそう
# 思いつく	伝聞	思い思いつくそうだ
# 思いつく	例示	思い思いつくようだ
# 思いつく	勧誘	思い思いつこう
# 思いつく	自分の希望	思い思いつくたい
# 思いつく	他人の希望	思い思いつくたがる
# 思いつく	て	思い思いついて
# 思いつく	です・ます	思い思いつきます
# 及ぶ	可能	及べる
# 及ぶ	受け身	及ぶられる
# 及ぶ	使役	及ぶせる
# 及ぶ	過去	及んだ
# 及ぶ	否定	及ばない
# 及ぶ	推定	及ぶらしい
# 及ぶ	様態	及ぶそう
# 及ぶ	伝聞	及ぶそうだ
# 及ぶ	例示	及ぶようだ
# 及ぶ	勧誘	及ぼう
# 及ぶ	自分の希望	及ぶたい
# 及ぶ	他人の希望	及ぶたがる
# 及ぶ	て	及んて
# 及ぶ	です・ます	及びます
# 及ぼす	可能	及ぼせる
# 及ぼす	受け身	及ぼすられる
# 及ぼす	使役	及ぼすせる
# 及ぼす	過去	及ぼした
# 及ぼす	否定	及ぼさない
# 及ぼす	推定	及ぼすらしい
# 及ぼす	様態	及ぼすそう
# 及ぼす	伝聞	及ぼすそうだ
# 及ぼす	例示	及ぼすようだ
# 及ぼす	勧誘	及ぼそう
# 及ぼす	自分の希望	及ぼすたい
# 及ぼす	他人の希望	及ぼすたがる
# 及ぼす	て	及ぼして
# 及ぼす	です・ます	及ぼします
# 終わる	可能	終われる
# 終わる	受け身	終わるられる
# 終わる	使役	終わるせる
# 終わる	過去	終わった
# 終わる	否定	終わらない
# 終わる	推定	終わるらしい
# 終わる	様態	終わるそう
# 終わる	伝聞	終わるそうだ
# 終わる	例示	終わるようだ
# 終わる	勧誘	終わろう
# 終わる	自分の希望	終わるたい
# 終わる	他人の希望	終わるたがる
# 終わる	て	終わって
# 終わる	です・ます	終わります
# 買い上げる	可能	買い買い上げる
# 買い上げる	受け身	買い買い上げられる
# 買い上げる	使役	買い買い上げせる
# 買い上げる	過去	買い買い上げた
# 買い上げる	否定	買い買い上げない
# 買い上げる	推定	買い買い上げるらしい
# 買い上げる	様態	買い買い上げるそう
# 買い上げる	伝聞	買い買い上げるそうだ
# 買い上げる	例示	買い買い上げるようだ
# 買い上げる	勧誘	買い買い上げう
# 買い上げる	自分の希望	買い買い上げたい
# 買い上げる	他人の希望	買い買い上げたがる
# 買い上げる	て	買い買い上げて
# 買い上げる	です・ます	買い買い上げます
# 買い換える	可能	買い買い換える
# 買い換える	受け身	買い買い換えられる
# 買い換える	使役	買い買い換えせる
# 買い換える	過去	買い買い換えた
# 買い換える	否定	買い買い換えない
# 買い換える	推定	買い買い換えるらしい
# 買い換える	様態	買い買い換えるそう
# 買い換える	伝聞	買い買い換えるそうだ
# 買い換える	例示	買い買い換えるようだ
# 買い換える	勧誘	買い買い換えう
# 買い換える	自分の希望	買い買い換えたい
# 買い換える	他人の希望	買い買い換えたがる
# 買い換える	て	買い買い換えて
# 買い換える	です・ます	買い買い換えます
# 解決する	可能	解決解決できれる
# 解決する	受け身	解決解決さられる
# 解決する	使役	解決解決させる
# 解決する	過去	解決解決した
# 解決する	否定	解決解決しない
# 解決する	推定	解決解決するらしい
# 解決する	様態	解決解決するそう
# 解決する	伝聞	解決解決するそうだ
# 解決する	例示	解決解決するようだ
# 解決する	勧誘	解決解決しう
# 解決する	自分の希望	解決解決さたい
# 解決する	他人の希望	解決解決さたがる
# 解決する	て	解決解決して
# 解決する	です・ます	解決解決します
# 介護する	可能	介護介護できれる
# 介護する	受け身	介護介護さられる
# 介護する	使役	介護介護させる
# 介護する	過去	介護介護した
# 介護する	否定	介護介護しない
# 介護する	推定	介護介護するらしい
# 介護する	様態	介護介護するそう
# 介護する	伝聞	介護介護するそうだ
# 介護する	例示	介護介護するようだ
# 介護する	勧誘	介護介護しう
# 介護する	自分の希望	介護介護さたい
# 介護する	他人の希望	介護介護さたがる
# 介護する	て	介護介護して
# 介護する	です・ます	介護介護します
# 開催する	可能	開催開催できれる
# 開催する	受け身	開催開催さられる
# 開催する	使役	開催開催させる
# 開催する	過去	開催開催した
# 開催する	否定	開催開催しない
# 開催する	推定	開催開催するらしい
# 開催する	様態	開催開催するそう
# 開催する	伝聞	開催開催するそうだ
# 開催する	例示	開催開催するようだ
# 開催する	勧誘	開催開催しう
# 開催する	自分の希望	開催開催さたい
# 開催する	他人の希望	開催開催さたがる
# 開催する	て	開催開催して
# 開催する	です・ます	開催開催します
# 開示する	可能	開示開示できれる
# 開示する	受け身	開示開示さられる
# 開示する	使役	開示開示させる
# 開示する	過去	開示開示した
# 開示する	否定	開示開示しない
# 開示する	推定	開示開示するらしい
# 開示する	様態	開示開示するそう
# 開示する	伝聞	開示開示するそうだ
# 開示する	例示	開示開示するようだ
# 開示する	勧誘	開示開示しう
# 開示する	自分の希望	開示開示さたい
# 開示する	他人の希望	開示開示さたがる
# 開示する	て	開示開示して
# 開示する	です・ます	開示開示します
# 回収する	可能	回収回収できれる
# 回収する	受け身	回収回収さられる
# 回収する	使役	回収回収させる
# 回収する	過去	回収回収した
# 回収する	否定	回収回収しない
# 回収する	推定	回収回収するらしい
# 回収する	様態	回収回収するそう
# 回収する	伝聞	回収回収するそうだ
# 回収する	例示	回収回収するようだ
# 回収する	勧誘	回収回収しう
# 回収する	自分の希望	回収回収さたい
# 回収する	他人の希望	回収回収さたがる
# 回収する	て	回収回収して
# 回収する	です・ます	回収回収します
# 外出する	可能	外出外出できれる
# 外出する	受け身	外出外出さられる
# 外出する	使役	外出外出させる
# 外出する	過去	外出外出した
# 外出する	否定	外出外出しない
# 外出する	推定	外出外出するらしい
# 外出する	様態	外出外出するそう
# 外出する	伝聞	外出外出するそうだ
# 外出する	例示	外出外出するようだ
# 外出する	勧誘	外出外出しう
# 外出する	自分の希望	外出外出さたい
# 外出する	他人の希望	外出外出さたがる
# 外出する	て	外出外出して
# 外出する	です・ます	外出外出します
# 外食する	可能	外食外食できれる
# 外食する	受け身	外食外食さられる
# 外食する	使役	外食外食させる
# 外食する	過去	外食外食した
# 外食する	否定	外食外食しない
# 外食する	推定	外食外食するらしい
# 外食する	様態	外食外食するそう
# 外食する	伝聞	外食外食するそうだ
# 外食する	例示	外食外食するようだ
# 外食する	勧誘	外食外食しう
# 外食する	自分の希望	外食外食さたい
# 外食する	他人の希望	外食外食さたがる
# 外食する	て	外食外食して
# 外食する	です・ます	外食外食します
# 改正する	可能	改正改正できれる
# 改正する	受け身	改正改正さられる
# 改正する	使役	改正改正させる
# 改正する	過去	改正改正した
# 改正する	否定	改正改正しない
# 改正する	推定	改正改正するらしい
# 改正する	様態	改正改正するそう
# 改正する	伝聞	改正改正するそうだ
# 改正する	例示	改正改正するようだ
# 改正する	勧誘	改正改正しう
# 改正する	自分の希望	改正改正さたい
# 改正する	他人の希望	改正改正さたがる
# 改正する	て	改正改正して
# 改正する	です・ます	改正改正します
# 解説する	可能	解説解説できれる
# 解説する	受け身	解説解説さられる
# 解説する	使役	解説解説させる
# 解説する	過去	解説解説した
# 解説する	否定	解説解説しない
# 解説する	推定	解説解説するらしい
# 解説する	様態	解説解説するそう
# 解説する	伝聞	解説解説するそうだ
# 解説する	例示	解説解説するようだ
# 解説する	勧誘	解説解説しう
# 解説する	自分の希望	解説解説さたい
# 解説する	他人の希望	解説解説さたがる
# 解説する	て	解説解説して
# 解説する	です・ます	解説解説します
# 改善する	可能	改善改善できれる
# 改善する	受け身	改善改善さられる
# 改善する	使役	改善改善させる
# 改善する	過去	改善改善した
# 改善する	否定	改善改善しない
# 改善する	推定	改善改善するらしい
# 改善する	様態	改善改善するそう
# 改善する	伝聞	改善改善するそうだ
# 改善する	例示	改善改善するようだ
# 改善する	勧誘	改善改善しう
# 改善する	自分の希望	改善改善さたい
# 改善する	他人の希望	改善改善さたがる
# 改善する	て	改善改善して
# 改善する	です・ます	改善改善します
# 開発する	可能	開発開発できれる
# 開発する	受け身	開発開発さられる
# 開発する	使役	開発開発させる
# 開発する	過去	開発開発した
# 開発する	否定	開発開発しない
# 開発する	推定	開発開発するらしい
# 開発する	様態	開発開発するそう
# 開発する	伝聞	開発開発するそうだ
# 開発する	例示	開発開発するようだ
# 開発する	勧誘	開発開発しう
# 開発する	自分の希望	開発開発さたい
# 開発する	他人の希望	開発開発さたがる
# 開発する	て	開発開発して
# 開発する	です・ます	開発開発します
# 回復する	可能	回復回復できれる
# 回復する	受け身	回復回復さられる
# 回復する	使役	回復回復させる
# 回復する	過去	回復回復した
# 回復する	否定	回復回復しない
# 回復する	推定	回復回復するらしい
# 回復する	様態	回復回復するそう
# 回復する	伝聞	回復回復するそうだ
# 回復する	例示	回復回復するようだ
# 回復する	勧誘	回復回復しう
# 回復する	自分の希望	回復回復さたい
# 回復する	他人の希望	回復回復さたがる
# 回復する	て	回復回復して
# 回復する	です・ます	回復回復します
# 開放する	可能	開放開放できれる
# 開放する	受け身	開放開放さられる
# 開放する	使役	開放開放させる
# 開放する	過去	開放開放した
# 開放する	否定	開放開放しない
# 開放する	推定	開放開放するらしい
# 開放する	様態	開放開放するそう
# 開放する	伝聞	開放開放するそうだ
# 開放する	例示	開放開放するようだ
# 開放する	勧誘	開放開放しう
# 開放する	自分の希望	開放開放さたい
# 開放する	他人の希望	開放開放さたがる
# 開放する	て	開放開放して
# 開放する	です・ます	開放開放します
# 解明する	可能	解明解明できれる
# 解明する	受け身	解明解明さられる
# 解明する	使役	解明解明させる
# 解明する	過去	解明解明した
# 解明する	否定	解明解明しない
# 解明する	推定	解明解明するらしい
# 解明する	様態	解明解明するそう
# 解明する	伝聞	解明解明するそうだ
# 解明する	例示	解明解明するようだ
# 解明する	勧誘	解明解明しう
# 解明する	自分の希望	解明解明さたい
# 解明する	他人の希望	解明解明さたがる
# 解明する	て	解明解明して
# 解明する	です・ます	解明解明します
# 改良する	可能	改良改良できれる
# 改良する	受け身	改良改良さられる
# 改良する	使役	改良改良させる
# 改良する	過去	改良改良した
# 改良する	否定	改良改良しない
# 改良する	推定	改良改良するらしい
# 改良する	様態	改良改良するそう
# 改良する	伝聞	改良改良するそうだ
# 改良する	例示	改良改良するようだ
# 改良する	勧誘	改良改良しう
# 改良する	自分の希望	改良改良さたい
# 改良する	他人の希望	改良改良さたがる
# 改良する	て	改良改良して
# 改良する	です・ます	改良改良します
# 代える	可能	代える
# 代える	受け身	代えられる
# 代える	使役	代えせる
# 代える	過去	代えた
# 代える	否定	代えない
# 代える	推定	代えるらしい
# 代える	様態	代えるそう
# 代える	伝聞	代えるそうだ
# 代える	例示	代えるようだ
# 代える	勧誘	代えう
# 代える	自分の希望	代えたい
# 代える	他人の希望	代えたがる
# 代える	て	代えて
# 代える	です・ます	代えます
# 抱える	可能	抱える
# 抱える	受け身	抱えられる
# 抱える	使役	抱えせる
# 抱える	過去	抱えた
# 抱える	否定	抱えない
# 抱える	推定	抱えるらしい
# 抱える	様態	抱えるそう
# 抱える	伝聞	抱えるそうだ
# 抱える	例示	抱えるようだ
# 抱える	勧誘	抱えう
# 抱える	自分の希望	抱えたい
# 抱える	他人の希望	抱えたがる
# 抱える	て	抱えて
# 抱える	です・ます	抱えます
# 輝く	可能	輝ける
# 輝く	受け身	輝くられる
# 輝く	使役	輝くせる
# 輝く	過去	輝いた
# 輝く	否定	輝かない
# 輝く	推定	輝くらしい
# 輝く	様態	輝くそう
# 輝く	伝聞	輝くそうだ
# 輝く	例示	輝くようだ
# 輝く	勧誘	輝こう
# 輝く	自分の希望	輝くたい
# 輝く	他人の希望	輝くたがる
# 輝く	て	輝いて
# 輝く	です・ます	輝きます
# かかわる	可能	かかわれる
# かかわる	受け身	かかわるられる
# かかわる	使役	かかわるせる
# かかわる	過去	かかわった
# かかわる	否定	かかわらない
# かかわる	推定	かかわるらしい
# かかわる	様態	かかわるそう
# かかわる	伝聞	かかわるそうだ
# かかわる	例示	かかわるようだ
# かかわる	勧誘	かかわろう
# かかわる	自分の希望	かかわるたい
# かかわる	他人の希望	かかわるたがる
# かかわる	て	かかわって
# かかわる	です・ます	かかわります
# 書き上げる	可能	書き書き上げる
# 書き上げる	受け身	書き書き上げられる
# 書き上げる	使役	書き書き上げせる
# 書き上げる	過去	書き書き上げた
# 書き上げる	否定	書き書き上げない
# 書き上げる	推定	書き書き上げるらしい
# 書き上げる	様態	書き書き上げるそう
# 書き上げる	伝聞	書き書き上げるそうだ
# 書き上げる	例示	書き書き上げるようだ
# 書き上げる	勧誘	書き書き上げう
# 書き上げる	自分の希望	書き書き上げたい
# 書き上げる	他人の希望	書き書き上げたがる
# 書き上げる	て	書き書き上げて
# 書き上げる	です・ます	書き書き上げます
# 限る	可能	限れる
# 限る	受け身	限るられる
# 限る	使役	限るせる
# 限る	過去	限った
# 限る	否定	限らない
# 限る	推定	限るらしい
# 限る	様態	限るそう
# 限る	伝聞	限るそうだ
# 限る	例示	限るようだ
# 限る	勧誘	限ろう
# 限る	自分の希望	限るたい
# 限る	他人の希望	限るたがる
# 限る	て	限って
# 限る	です・ます	限ります
# 学習する	可能	学習学習できれる
# 学習する	受け身	学習学習さられる
# 学習する	使役	学習学習させる
# 学習する	過去	学習学習した
# 学習する	否定	学習学習しない
# 学習する	推定	学習学習するらしい
# 学習する	様態	学習学習するそう
# 学習する	伝聞	学習学習するそうだ
# 学習する	例示	学習学習するようだ
# 学習する	勧誘	学習学習しう
# 学習する	自分の希望	学習学習さたい
# 学習する	他人の希望	学習学習さたがる
# 学習する	て	学習学習して
# 学習する	です・ます	学習学習します
# 隠す	可能	隠せる
# 隠す	受け身	隠すられる
# 隠す	使役	隠すせる
# 隠す	過去	隠した
# 隠す	否定	隠さない
# 隠す	推定	隠すらしい
# 隠す	様態	隠すそう
# 隠す	伝聞	隠すそうだ
# 隠す	例示	隠すようだ
# 隠す	勧誘	隠そう
# 隠す	自分の希望	隠すたい
# 隠す	他人の希望	隠すたがる
# 隠す	て	隠して
# 隠す	です・ます	隠します
# 拡大する	可能	拡大拡大できれる
# 拡大する	受け身	拡大拡大さられる
# 拡大する	使役	拡大拡大させる
# 拡大する	過去	拡大拡大した
# 拡大する	否定	拡大拡大しない
# 拡大する	推定	拡大拡大するらしい
# 拡大する	様態	拡大拡大するそう
# 拡大する	伝聞	拡大拡大するそうだ
# 拡大する	例示	拡大拡大するようだ
# 拡大する	勧誘	拡大拡大しう
# 拡大する	自分の希望	拡大拡大さたい
# 拡大する	他人の希望	拡大拡大さたがる
# 拡大する	て	拡大拡大して
# 拡大する	です・ます	拡大拡大します
# 確定する	可能	確定確定できれる
# 確定する	受け身	確定確定さられる
# 確定する	使役	確定確定させる
# 確定する	過去	確定確定した
# 確定する	否定	確定確定しない
# 確定する	推定	確定確定するらしい
# 確定する	様態	確定確定するそう
# 確定する	伝聞	確定確定するそうだ
# 確定する	例示	確定確定するようだ
# 確定する	勧誘	確定確定しう
# 確定する	自分の希望	確定確定さたい
# 確定する	他人の希望	確定確定さたがる
# 確定する	て	確定確定して
# 確定する	です・ます	確定確定します
# 確定申告する	可能	確定申告確定申告できれる
# 確定申告する	受け身	確定申告確定申告さられる
# 確定申告する	使役	確定申告確定申告させる
# 確定申告する	過去	確定申告確定申告した
# 確定申告する	否定	確定申告確定申告しない
# 確定申告する	推定	確定申告確定申告するらしい
# 確定申告する	様態	確定申告確定申告するそう
# 確定申告する	伝聞	確定申告確定申告するそうだ
# 確定申告する	例示	確定申告確定申告するようだ
# 確定申告する	勧誘	確定申告確定申告しう
# 確定申告する	自分の希望	確定申告確定申告さたい
# 確定申告する	他人の希望	確定申告確定申告さたがる
# 確定申告する	て	確定申告確定申告して
# 確定申告する	です・ます	確定申告確定申告します
# 獲得する	可能	獲得獲得できれる
# 獲得する	受け身	獲得獲得さられる
# 獲得する	使役	獲得獲得させる
# 獲得する	過去	獲得獲得した
# 獲得する	否定	獲得獲得しない
# 獲得する	推定	獲得獲得するらしい
# 獲得する	様態	獲得獲得するそう
# 獲得する	伝聞	獲得獲得するそうだ
# 獲得する	例示	獲得獲得するようだ
# 獲得する	勧誘	獲得獲得しう
# 獲得する	自分の希望	獲得獲得さたい
# 獲得する	他人の希望	獲得獲得さたがる
# 獲得する	て	獲得獲得して
# 獲得する	です・ます	獲得獲得します
# 確保する	可能	確保確保できれる
# 確保する	受け身	確保確保さられる
# 確保する	使役	確保確保させる
# 確保する	過去	確保確保した
# 確保する	否定	確保確保しない
# 確保する	推定	確保確保するらしい
# 確保する	様態	確保確保するそう
# 確保する	伝聞	確保確保するそうだ
# 確保する	例示	確保確保するようだ
# 確保する	勧誘	確保確保しう
# 確保する	自分の希望	確保確保さたい
# 確保する	他人の希望	確保確保さたがる
# 確保する	て	確保確保して
# 確保する	です・ます	確保確保します
# 確立する	可能	確立確立できれる
# 確立する	受け身	確立確立さられる
# 確立する	使役	確立確立させる
# 確立する	過去	確立確立した
# 確立する	否定	確立確立しない
# 確立する	推定	確立確立するらしい
# 確立する	様態	確立確立するそう
# 確立する	伝聞	確立確立するそうだ
# 確立する	例示	確立確立するようだ
# 確立する	勧誘	確立確立しう
# 確立する	自分の希望	確立確立さたい
# 確立する	他人の希望	確立確立さたがる
# 確立する	て	確立確立して
# 確立する	です・ます	確立確立します
# 隠れる	可能	隠れる
# 隠れる	受け身	隠れられる
# 隠れる	使役	隠れせる
# 隠れる	過去	隠れた
# 隠れる	否定	隠れない
# 隠れる	推定	隠れるらしい
# 隠れる	様態	隠れるそう
# 隠れる	伝聞	隠れるそうだ
# 隠れる	例示	隠れるようだ
# 隠れる	勧誘	隠れう
# 隠れる	自分の希望	隠れたい
# 隠れる	他人の希望	隠れたがる
# 隠れる	て	隠れて
# 隠れる	です・ます	隠れます
# 可決する	可能	可決可決できれる
# 可決する	受け身	可決可決さられる
# 可決する	使役	可決可決させる
# 可決する	過去	可決可決した
# 可決する	否定	可決可決しない
# 可決する	推定	可決可決するらしい
# 可決する	様態	可決可決するそう
# 可決する	伝聞	可決可決するそうだ
# 可決する	例示	可決可決するようだ
# 可決する	勧誘	可決可決しう
# 可決する	自分の希望	可決可決さたい
# 可決する	他人の希望	可決可決さたがる
# 可決する	て	可決可決して
# 可決する	です・ます	可決可決します
# かけ離れる	可能	かけ離れる
# かけ離れる	受け身	かけ離れられる
# かけ離れる	使役	かけ離れせる
# かけ離れる	過去	かけ離れた
# かけ離れる	否定	かけ離れない
# かけ離れる	推定	かけ離れるらしい
# かけ離れる	様態	かけ離れるそう
# かけ離れる	伝聞	かけ離れるそうだ
# かけ離れる	例示	かけ離れるようだ
# かけ離れる	勧誘	かけ離れう
# かけ離れる	自分の希望	かけ離れたい
# かけ離れる	他人の希望	かけ離れたがる
# かけ離れる	て	かけ離れて
# かけ離れる	です・ます	かけ離れます
# かける	可能	かける
# かける	受け身	かけられる
# かける	使役	かけせる
# かける	過去	かけた
# かける	否定	かけない
# かける	推定	かけるらしい
# かける	様態	かけるそう
# かける	伝聞	かけるそうだ
# かける	例示	かけるようだ
# かける	勧誘	かけう
# かける	自分の希望	かけたい
# かける	他人の希望	かけたがる
# かける	て	かけて
# かける	です・ます	かけます
# 掛ける	可能	掛ける
# 掛ける	受け身	掛けられる
# 掛ける	使役	掛けせる
# 掛ける	過去	掛けた
# 掛ける	否定	掛けない
# 掛ける	推定	掛けるらしい
# 掛ける	様態	掛けるそう
# 掛ける	伝聞	掛けるそうだ
# 掛ける	例示	掛けるようだ
# 掛ける	勧誘	掛けう
# 掛ける	自分の希望	掛けたい
# 掛ける	他人の希望	掛けたがる
# 掛ける	て	掛けて
# 掛ける	です・ます	掛けます
# 加工する	可能	加工加工できれる
# 加工する	受け身	加工加工さられる
# 加工する	使役	加工加工させる
# 加工する	過去	加工加工した
# 加工する	否定	加工加工しない
# 加工する	推定	加工加工するらしい
# 加工する	様態	加工加工するそう
# 加工する	伝聞	加工加工するそうだ
# 加工する	例示	加工加工するようだ
# 加工する	勧誘	加工加工しう
# 加工する	自分の希望	加工加工さたい
# 加工する	他人の希望	加工加工さたがる
# 加工する	て	加工加工して
# 加工する	です・ます	加工加工します
# 下降する	可能	下降下降できれる
# 下降する	受け身	下降下降さられる
# 下降する	使役	下降下降させる
# 下降する	過去	下降下降した
# 下降する	否定	下降下降しない
# 下降する	推定	下降下降するらしい
# 下降する	様態	下降下降するそう
# 下降する	伝聞	下降下降するそうだ
# 下降する	例示	下降下降するようだ
# 下降する	勧誘	下降下降しう
# 下降する	自分の希望	下降下降さたい
# 下降する	他人の希望	下降下降さたがる
# 下降する	て	下降下降して
# 下降する	です・ます	下降下降します
# 囲む	可能	囲める
# 囲む	受け身	囲むられる
# 囲む	使役	囲むせる
# 囲む	過去	囲んだ
# 囲む	否定	囲まない
# 囲む	推定	囲むらしい
# 囲む	様態	囲むそう
# 囲む	伝聞	囲むそうだ
# 囲む	例示	囲むようだ
# 囲む	勧誘	囲もう
# 囲む	自分の希望	囲むたい
# 囲む	他人の希望	囲むたがる
# 囲む	て	囲んて
# 囲む	です・ます	囲みます
# 重なる	可能	重なれる
# 重なる	受け身	重なるられる
# 重なる	使役	重なるせる
# 重なる	過去	重なった
# 重なる	否定	重ならない
# 重なる	推定	重なるらしい
# 重なる	様態	重なるそう
# 重なる	伝聞	重なるそうだ
# 重なる	例示	重なるようだ
# 重なる	勧誘	重なろう
# 重なる	自分の希望	重なるたい
# 重なる	他人の希望	重なるたがる
# 重なる	て	重なって
# 重なる	です・ます	重なります
# 重ねる	可能	重ねる
# 重ねる	受け身	重ねられる
# 重ねる	使役	重ねせる
# 重ねる	過去	重ねた
# 重ねる	否定	重ねない
# 重ねる	推定	重ねるらしい
# 重ねる	様態	重ねるそう
# 重ねる	伝聞	重ねるそうだ
# 重ねる	例示	重ねるようだ
# 重ねる	勧誘	重ねう
# 重ねる	自分の希望	重ねたい
# 重ねる	他人の希望	重ねたがる
# 重ねる	て	重ねて
# 重ねる	です・ます	重ねます
# 課する	可能	課できれる
# 課する	受け身	課さられる
# 課する	使役	課させる
# 課する	過去	課した
# 課する	否定	課しない
# 課する	推定	課するらしい
# 課する	様態	課するそう
# 課する	伝聞	課するそうだ
# 課する	例示	課するようだ
# 課する	勧誘	課しう
# 課する	自分の希望	課さたい
# 課する	他人の希望	課さたがる
# 課する	て	課して
# 課する	です・ます	課します
# 稼ぐ	可能	稼げる
# 稼ぐ	受け身	稼ぐられる
# 稼ぐ	使役	稼ぐせる
# 稼ぐ	過去	稼いた
# 稼ぐ	否定	稼がない
# 稼ぐ	推定	稼ぐらしい
# 稼ぐ	様態	稼ぐそう
# 稼ぐ	伝聞	稼ぐそうだ
# 稼ぐ	例示	稼ぐようだ
# 稼ぐ	勧誘	稼ごう
# 稼ぐ	自分の希望	稼ぐたい
# 稼ぐ	他人の希望	稼ぐたがる
# 稼ぐ	て	稼いて
# 稼ぐ	です・ます	稼ぎます
# 片思いする	可能	片思い片思いできれる
# 片思いする	受け身	片思い片思いさられる
# 片思いする	使役	片思い片思いさせる
# 片思いする	過去	片思い片思いした
# 片思いする	否定	片思い片思いしない
# 片思いする	推定	片思い片思いするらしい
# 片思いする	様態	片思い片思いするそう
# 片思いする	伝聞	片思い片思いするそうだ
# 片思いする	例示	片思い片思いするようだ
# 片思いする	勧誘	片思い片思いしう
# 片思いする	自分の希望	片思い片思いさたい
# 片思いする	他人の希望	片思い片思いさたがる
# 片思いする	て	片思い片思いして
# 片思いする	です・ます	片思い片思いします
# 傾ける	可能	傾ける
# 傾ける	受け身	傾けられる
# 傾ける	使役	傾けせる
# 傾ける	過去	傾けた
# 傾ける	否定	傾けない
# 傾ける	推定	傾けるらしい
# 傾ける	様態	傾けるそう
# 傾ける	伝聞	傾けるそうだ
# 傾ける	例示	傾けるようだ
# 傾ける	勧誘	傾けう
# 傾ける	自分の希望	傾けたい
# 傾ける	他人の希望	傾けたがる
# 傾ける	て	傾けて
# 傾ける	です・ます	傾けます
# 偏る	可能	偏れる
# 偏る	受け身	偏るられる
# 偏る	使役	偏るせる
# 偏る	過去	偏った
# 偏る	否定	偏らない
# 偏る	推定	偏るらしい
# 偏る	様態	偏るそう
# 偏る	伝聞	偏るそうだ
# 偏る	例示	偏るようだ
# 偏る	勧誘	偏ろう
# 偏る	自分の希望	偏るたい
# 偏る	他人の希望	偏るたがる
# 偏る	て	偏って
# 偏る	です・ます	偏ります
# 語り合う	可能	語り語り合える
# 語り合う	受け身	語り語り合うられる
# 語り合う	使役	語り語り合うせる
# 語り合う	過去	語り語り合った
# 語り合う	否定	語り語り合あない
# 語り合う	推定	語り語り合うらしい
# 語り合う	様態	語り語り合うそう
# 語り合う	伝聞	語り語り合うそうだ
# 語り合う	例示	語り語り合うようだ
# 語り合う	勧誘	語り語り合おう
# 語り合う	自分の希望	語り語り合うたい
# 語り合う	他人の希望	語り語り合うたがる
# 語り合う	て	語り語り合って
# 語り合う	です・ます	語り語り合います
# 語る	可能	語れる
# 語る	受け身	語るられる
# 語る	使役	語るせる
# 語る	過去	語った
# 語る	否定	語らない
# 語る	推定	語るらしい
# 語る	様態	語るそう
# 語る	伝聞	語るそうだ
# 語る	例示	語るようだ
# 語る	勧誘	語ろう
# 語る	自分の希望	語るたい
# 語る	他人の希望	語るたがる
# 語る	て	語って
# 語る	です・ます	語ります
# 合宿する	可能	合宿合宿できれる
# 合宿する	受け身	合宿合宿さられる
# 合宿する	使役	合宿合宿させる
# 合宿する	過去	合宿合宿した
# 合宿する	否定	合宿合宿しない
# 合宿する	推定	合宿合宿するらしい
# 合宿する	様態	合宿合宿するそう
# 合宿する	伝聞	合宿合宿するそうだ
# 合宿する	例示	合宿合宿するようだ
# 合宿する	勧誘	合宿合宿しう
# 合宿する	自分の希望	合宿合宿さたい
# 合宿する	他人の希望	合宿合宿さたがる
# 合宿する	て	合宿合宿して
# 合宿する	です・ます	合宿合宿します
# 活動する	可能	活動活動できれる
# 活動する	受け身	活動活動さられる
# 活動する	使役	活動活動させる
# 活動する	過去	活動活動した
# 活動する	否定	活動活動しない
# 活動する	推定	活動活動するらしい
# 活動する	様態	活動活動するそう
# 活動する	伝聞	活動活動するそうだ
# 活動する	例示	活動活動するようだ
# 活動する	勧誘	活動活動しう
# 活動する	自分の希望	活動活動さたい
# 活動する	他人の希望	活動活動さたがる
# 活動する	て	活動活動して
# 活動する	です・ます	活動活動します
# 活躍する	可能	活躍活躍できれる
# 活躍する	受け身	活躍活躍さられる
# 活躍する	使役	活躍活躍させる
# 活躍する	過去	活躍活躍した
# 活躍する	否定	活躍活躍しない
# 活躍する	推定	活躍活躍するらしい
# 活躍する	様態	活躍活躍するそう
# 活躍する	伝聞	活躍活躍するそうだ
# 活躍する	例示	活躍活躍するようだ
# 活躍する	勧誘	活躍活躍しう
# 活躍する	自分の希望	活躍活躍さたい
# 活躍する	他人の希望	活躍活躍さたがる
# 活躍する	て	活躍活躍して
# 活躍する	です・ます	活躍活躍します
# 悲しむ	可能	悲しめる
# 悲しむ	受け身	悲しむられる
# 悲しむ	使役	悲しむせる
# 悲しむ	過去	悲しんだ
# 悲しむ	否定	悲しまない
# 悲しむ	推定	悲しむらしい
# 悲しむ	様態	悲しむそう
# 悲しむ	伝聞	悲しむそうだ
# 悲しむ	例示	悲しむようだ
# 悲しむ	勧誘	悲しもう
# 悲しむ	自分の希望	悲しむたい
# 悲しむ	他人の希望	悲しむたがる
# 悲しむ	て	悲しんて
# 悲しむ	です・ます	悲しみます
# 加入する	可能	加入加入できれる
# 加入する	受け身	加入加入さられる
# 加入する	使役	加入加入させる
# 加入する	過去	加入加入した
# 加入する	否定	加入加入しない
# 加入する	推定	加入加入するらしい
# 加入する	様態	加入加入するそう
# 加入する	伝聞	加入加入するそうだ
# 加入する	例示	加入加入するようだ
# 加入する	勧誘	加入加入しう
# 加入する	自分の希望	加入加入さたい
# 加入する	他人の希望	加入加入さたがる
# 加入する	て	加入加入して
# 加入する	です・ます	加入加入します
# 我慢する	可能	我慢我慢できれる
# 我慢する	受け身	我慢我慢さられる
# 我慢する	使役	我慢我慢させる
# 我慢する	過去	我慢我慢した
# 我慢する	否定	我慢我慢しない
# 我慢する	推定	我慢我慢するらしい
# 我慢する	様態	我慢我慢するそう
# 我慢する	伝聞	我慢我慢するそうだ
# 我慢する	例示	我慢我慢するようだ
# 我慢する	勧誘	我慢我慢しう
# 我慢する	自分の希望	我慢我慢さたい
# 我慢する	他人の希望	我慢我慢さたがる
# 我慢する	て	我慢我慢して
# 我慢する	です・ます	我慢我慢します
# かみつく	可能	かみつける
# かみつく	受け身	かみつくられる
# かみつく	使役	かみつくせる
# かみつく	過去	かみついた
# かみつく	否定	かみつかない
# かみつく	推定	かみつくらしい
# かみつく	様態	かみつくそう
# かみつく	伝聞	かみつくそうだ
# かみつく	例示	かみつくようだ
# かみつく	勧誘	かみつこう
# かみつく	自分の希望	かみつくたい
# かみつく	他人の希望	かみつくたがる
# かみつく	て	かみついて
# かみつく	です・ます	かみつきます
# からむ	可能	からめる
# からむ	受け身	からむられる
# からむ	使役	からむせる
# からむ	過去	からんだ
# からむ	否定	からまない
# からむ	推定	からむらしい
# からむ	様態	からむそう
# からむ	伝聞	からむそうだ
# からむ	例示	からむようだ
# からむ	勧誘	からもう
# からむ	自分の希望	からむたい
# からむ	他人の希望	からむたがる
# からむ	て	からんて
# からむ	です・ます	からみます
# 乾かす	可能	乾かせる
# 乾かす	受け身	乾かすられる
# 乾かす	使役	乾かすせる
# 乾かす	過去	乾かした
# 乾かす	否定	乾かさない
# 乾かす	推定	乾かすらしい
# 乾かす	様態	乾かすそう
# 乾かす	伝聞	乾かすそうだ
# 乾かす	例示	乾かすようだ
# 乾かす	勧誘	乾かそう
# 乾かす	自分の希望	乾かすたい
# 乾かす	他人の希望	乾かすたがる
# 乾かす	て	乾かして
# 乾かす	です・ます	乾かします
# 交す	可能	交す交すできれる
# 交す	受け身	交す交すさられる
# 交す	使役	交す交すさせる
# 交す	過去	交す交すした
# 交す	否定	交す交すしない
# 交す	推定	交す交すするらしい
# 交す	様態	交す交すするそう
# 交す	伝聞	交す交すするそうだ
# 交す	例示	交す交すするようだ
# 交す	勧誘	交す交すしう
# 交す	自分の希望	交す交すさたい
# 交す	他人の希望	交す交すさたがる
# 交す	て	交す交すして
# 交す	です・ます	交す交すします
# 代わる	可能	代われる
# 代わる	受け身	代わるられる
# 代わる	使役	代わるせる
# 代わる	過去	代わった
# 代わる	否定	代わらない
# 代わる	推定	代わるらしい
# 代わる	様態	代わるそう
# 代わる	伝聞	代わるそうだ
# 代わる	例示	代わるようだ
# 代わる	勧誘	代わろう
# 代わる	自分の希望	代わるたい
# 代わる	他人の希望	代わるたがる
# 代わる	て	代わって
# 代わる	です・ます	代わります
# 歓迎する	可能	歓迎歓迎できれる
# 歓迎する	受け身	歓迎歓迎さられる
# 歓迎する	使役	歓迎歓迎させる
# 歓迎する	過去	歓迎歓迎した
# 歓迎する	否定	歓迎歓迎しない
# 歓迎する	推定	歓迎歓迎するらしい
# 歓迎する	様態	歓迎歓迎するそう
# 歓迎する	伝聞	歓迎歓迎するそうだ
# 歓迎する	例示	歓迎歓迎するようだ
# 歓迎する	勧誘	歓迎歓迎しう
# 歓迎する	自分の希望	歓迎歓迎さたい
# 歓迎する	他人の希望	歓迎歓迎さたがる
# 歓迎する	て	歓迎歓迎して
# 歓迎する	です・ます	歓迎歓迎します
# 観察する	可能	観察観察できれる
# 観察する	受け身	観察観察さられる
# 観察する	使役	観察観察させる
# 観察する	過去	観察観察した
# 観察する	否定	観察観察しない
# 観察する	推定	観察観察するらしい
# 観察する	様態	観察観察するそう
# 観察する	伝聞	観察観察するそうだ
# 観察する	例示	観察観察するようだ
# 観察する	勧誘	観察観察しう
# 観察する	自分の希望	観察観察さたい
# 観察する	他人の希望	観察観察さたがる
# 観察する	て	観察観察して
# 観察する	です・ます	観察観察します
# 換算する	可能	換算換算できれる
# 換算する	受け身	換算換算さられる
# 換算する	使役	換算換算させる
# 換算する	過去	換算換算した
# 換算する	否定	換算換算しない
# 換算する	推定	換算換算するらしい
# 換算する	様態	換算換算するそう
# 換算する	伝聞	換算換算するそうだ
# 換算する	例示	換算換算するようだ
# 換算する	勧誘	換算換算しう
# 換算する	自分の希望	換算換算さたい
# 換算する	他人の希望	換算換算さたがる
# 換算する	て	換算換算して
# 換算する	です・ます	換算換算します
# 感じ取る	可能	感じ感じ取れる
# 感じ取る	受け身	感じ感じ取るられる
# 感じ取る	使役	感じ感じ取るせる
# 感じ取る	過去	感じ感じ取った
# 感じ取る	否定	感じ感じ取らない
# 感じ取る	推定	感じ感じ取るらしい
# 感じ取る	様態	感じ感じ取るそう
# 感じ取る	伝聞	感じ感じ取るそうだ
# 感じ取る	例示	感じ感じ取るようだ
# 感じ取る	勧誘	感じ感じ取ろう
# ...
# 面接する	伝聞	面接面接するそうだ
# 面接する	例示	面接面接するようだ
# 面接する	勧誘	面接面接しう
# 面接する	自分の希望	面接面接さたい
# 面接する	他人の希望	面接面接さたがる
# 面接する	て	面接面接して
# 面接する	です・ます	面接面接します
# 面談する	可能	面談面談できれる
# 面談する	受け身	面談面談さられる
# 面談する	使役	面談面談させる
# 面談する	過去	面談面談した
# 面談する	否定	面談面談しない
# 面談する	推定	面談面談するらしい
# 面談する	様態	面談面談するそう
# 面談する	伝聞	面談面談するそうだ
# 面談する	例示	面談面談するようだ
# 面談する	勧誘	面談面談しう
# 面談する	自分の希望	面談面談さたい
# 面談する	他人の希望	面談面談さたがる
# 面談する	て	面談面談して
# 面談する	です・ます	面談面談します
# もうかる	可能	もうかれる
# もうかる	受け身	もうかるられる
# もうかる	使役	もうかるせる
# もうかる	過去	もうかった
# もうかる	否定	もうからない
# もうかる	推定	もうかるらしい
# もうかる	様態	もうかるそう
# もうかる	伝聞	もうかるそうだ
# もうかる	例示	もうかるようだ
# もうかる	勧誘	もうかろう
# もうかる	自分の希望	もうかるたい
# もうかる	他人の希望	もうかるたがる
# もうかる	て	もうかって
# もうかる	です・ます	もうかります
# もうける	可能	もうける
# もうける	受け身	もうけられる
# もうける	使役	もうけせる
# もうける	過去	もうけた
# もうける	否定	もうけない
# もうける	推定	もうけるらしい
# もうける	様態	もうけるそう
# もうける	伝聞	もうけるそうだ
# もうける	例示	もうけるようだ
# もうける	勧誘	もうけう
# もうける	自分の希望	もうけたい
# もうける	他人の希望	もうけたがる
# もうける	て	もうけて
# もうける	です・ます	もうけます
# 設ける	可能	設ける
# 設ける	受け身	設けられる
# 設ける	使役	設けせる
# 設ける	過去	設けた
# 設ける	否定	設けない
# 設ける	推定	設けるらしい
# 設ける	様態	設けるそう
# 設ける	伝聞	設けるそうだ
# 設ける	例示	設けるようだ
# 設ける	勧誘	設けう
# 設ける	自分の希望	設けたい
# 設ける	他人の希望	設けたがる
# 設ける	て	設けて
# 設ける	です・ます	設けます
# 申し出る	可能	申し出る
# 申し出る	受け身	申し出られる
# 申し出る	使役	申し出せる
# 申し出る	過去	申し出た
# 申し出る	否定	申し出ない
# 申し出る	推定	申し出るらしい
# 申し出る	様態	申し出るそう
# 申し出る	伝聞	申し出るそうだ
# 申し出る	例示	申し出るようだ
# 申し出る	勧誘	申し出う
# 申し出る	自分の希望	申し出たい
# 申し出る	他人の希望	申し出たがる
# 申し出る	て	申し出て
# 申し出る	です・ます	申し出ます
# 目撃する	可能	目撃目撃できれる
# 目撃する	受け身	目撃目撃さられる
# 目撃する	使役	目撃目撃させる
# 目撃する	過去	目撃目撃した
# 目撃する	否定	目撃目撃しない
# 目撃する	推定	目撃目撃するらしい
# 目撃する	様態	目撃目撃するそう
# 目撃する	伝聞	目撃目撃するそうだ
# 目撃する	例示	目撃目撃するようだ
# 目撃する	勧誘	目撃目撃しう
# 目撃する	自分の希望	目撃目撃さたい
# 目撃する	他人の希望	目撃目撃さたがる
# 目撃する	て	目撃目撃して
# 目撃する	です・ます	目撃目撃します
# 潜る	可能	潜れる
# 潜る	受け身	潜るられる
# 潜る	使役	潜るせる
# 潜る	過去	潜った
# 潜る	否定	潜らない
# 潜る	推定	潜るらしい
# 潜る	様態	潜るそう
# 潜る	伝聞	潜るそうだ
# 潜る	例示	潜るようだ
# 潜る	勧誘	潜ろう
# 潜る	自分の希望	潜るたい
# 潜る	他人の希望	潜るたがる
# 潜る	て	潜って
# 潜る	です・ます	潜ります
# もたらす	可能	もたらせる
# もたらす	受け身	もたらすられる
# もたらす	使役	もたらすせる
# もたらす	過去	もたらした
# もたらす	否定	もたらさない
# もたらす	推定	もたらすらしい
# もたらす	様態	もたらすそう
# もたらす	伝聞	もたらすそうだ
# もたらす	例示	もたらすようだ
# もたらす	勧誘	もたらそう
# もたらす	自分の希望	もたらすたい
# もたらす	他人の希望	もたらすたがる
# もたらす	て	もたらして
# もたらす	です・ます	もたらします
# もたれる	可能	もたもたれる
# もたれる	受け身	もたもたれられる
# もたれる	使役	もたもたれせる
# もたれる	過去	もたもたれた
# もたれる	否定	もたもたれない
# もたれる	推定	もたもたれるらしい
# もたれる	様態	もたもたれるそう
# もたれる	伝聞	もたもたれるそうだ
# もたれる	例示	もたもたれるようだ
# もたれる	勧誘	もたもたれう
# もたれる	自分の希望	もたもたれたい
# もたれる	他人の希望	もたもたれたがる
# もたれる	て	もたもたれて
# もたれる	です・ます	もたもたれます
# 持ち上げる	可能	持ち持ち上げる
# 持ち上げる	受け身	持ち持ち上げられる
# 持ち上げる	使役	持ち持ち上げせる
# 持ち上げる	過去	持ち持ち上げた
# 持ち上げる	否定	持ち持ち上げない
# 持ち上げる	推定	持ち持ち上げるらしい
# 持ち上げる	様態	持ち持ち上げるそう
# 持ち上げる	伝聞	持ち持ち上げるそうだ
# 持ち上げる	例示	持ち持ち上げるようだ
# 持ち上げる	勧誘	持ち持ち上げう
# 持ち上げる	自分の希望	持ち持ち上げたい
# 持ち上げる	他人の希望	持ち持ち上げたがる
# 持ち上げる	て	持ち持ち上げて
# 持ち上げる	です・ます	持ち持ち上げます
# 持ち込む	可能	持ち持ち込める
# 持ち込む	受け身	持ち持ち込むられる
# 持ち込む	使役	持ち持ち込むせる
# 持ち込む	過去	持ち持ち込んだ
# 持ち込む	否定	持ち持ち込まない
# 持ち込む	推定	持ち持ち込むらしい
# 持ち込む	様態	持ち持ち込むそう
# 持ち込む	伝聞	持ち持ち込むそうだ
# 持ち込む	例示	持ち持ち込むようだ
# 持ち込む	勧誘	持ち持ち込もう
# 持ち込む	自分の希望	持ち持ち込むたい
# 持ち込む	他人の希望	持ち持ち込むたがる
# 持ち込む	て	持ち持ち込んて
# 持ち込む	です・ます	持ち持ち込みます
# 持ち寄る	可能	持ち寄れる
# 持ち寄る	受け身	持ち寄るられる
# 持ち寄る	使役	持ち寄るせる
# 持ち寄る	過去	持ち寄った
# 持ち寄る	否定	持ち寄らない
# 持ち寄る	推定	持ち寄るらしい
# 持ち寄る	様態	持ち寄るそう
# 持ち寄る	伝聞	持ち寄るそうだ
# 持ち寄る	例示	持ち寄るようだ
# 持ち寄る	勧誘	持ち寄ろう
# 持ち寄る	自分の希望	持ち寄るたい
# 持ち寄る	他人の希望	持ち寄るたがる
# 持ち寄る	て	持ち寄って
# 持ち寄る	です・ます	持ち寄ります
# 基づく	可能	基づける
# 基づく	受け身	基づくられる
# 基づく	使役	基づくせる
# 基づく	過去	基づいた
# 基づく	否定	基づかない
# 基づく	推定	基づくらしい
# 基づく	様態	基づくそう
# 基づく	伝聞	基づくそうだ
# 基づく	例示	基づくようだ
# 基づく	勧誘	基づこう
# 基づく	自分の希望	基づくたい
# 基づく	他人の希望	基づくたがる
# 基づく	て	基づいて
# 基づく	です・ます	基づきます
# 求める	可能	求める
# 求める	受け身	求められる
# 求める	使役	求めせる
# 求める	過去	求めた
# 求める	否定	求めない
# 求める	推定	求めるらしい
# 求める	様態	求めるそう
# 求める	伝聞	求めるそうだ
# 求める	例示	求めるようだ
# 求める	勧誘	求めう
# 求める	自分の希望	求めたい
# 求める	他人の希望	求めたがる
# 求める	て	求めて
# 求める	です・ます	求めます
# もむ	可能	もめる
# もむ	受け身	もむられる
# もむ	使役	もむせる
# もむ	過去	もんだ
# もむ	否定	もまない
# もむ	推定	もむらしい
# もむ	様態	もむそう
# もむ	伝聞	もむそうだ
# もむ	例示	もむようだ
# もむ	勧誘	ももう
# もむ	自分の希望	もむたい
# もむ	他人の希望	もむたがる
# もむ	て	もんて
# もむ	です・ます	もみます
# 燃やす	可能	燃やせる
# 燃やす	受け身	燃やすられる
# 燃やす	使役	燃やすせる
# 燃やす	過去	燃やした
# 燃やす	否定	燃やさない
# 燃やす	推定	燃やすらしい
# 燃やす	様態	燃やすそう
# 燃やす	伝聞	燃やすそうだ
# 燃やす	例示	燃やすようだ
# 燃やす	勧誘	燃やそう
# 燃やす	自分の希望	燃やすたい
# 燃やす	他人の希望	燃やすたがる
# 燃やす	て	燃やして
# 燃やす	です・ます	燃やします
# 催す	可能	催せる
# 催す	受け身	催すられる
# 催す	使役	催すせる
# 催す	過去	催した
# 催す	否定	催さない
# 催す	推定	催すらしい
# 催す	様態	催すそう
# 催す	伝聞	催すそうだ
# 催す	例示	催すようだ
# 催す	勧誘	催そう
# 催す	自分の希望	催すたい
# 催す	他人の希望	催すたがる
# 催す	て	催して
# 催す	です・ます	催します
# 盛り上がる	可能	盛り上がれる
# 盛り上がる	受け身	盛り上がるられる
# 盛り上がる	使役	盛り上がるせる
# 盛り上がる	過去	盛り上がった
# 盛り上がる	否定	盛り上がらない
# 盛り上がる	推定	盛り上がるらしい
# 盛り上がる	様態	盛り上がるそう
# 盛り上がる	伝聞	盛り上がるそうだ
# 盛り上がる	例示	盛り上がるようだ
# 盛り上がる	勧誘	盛り上がろう
# 盛り上がる	自分の希望	盛り上がるたい
# 盛り上がる	他人の希望	盛り上がるたがる
# 盛り上がる	て	盛り上がって
# 盛り上がる	です・ます	盛り上がります
# 盛り上げる	可能	盛り上げる
# 盛り上げる	受け身	盛り上げられる
# 盛り上げる	使役	盛り上げせる
# 盛り上げる	過去	盛り上げた
# 盛り上げる	否定	盛り上げない
# 盛り上げる	推定	盛り上げるらしい
# 盛り上げる	様態	盛り上げるそう
# 盛り上げる	伝聞	盛り上げるそうだ
# 盛り上げる	例示	盛り上げるようだ
# 盛り上げる	勧誘	盛り上げう
# 盛り上げる	自分の希望	盛り上げたい
# 盛り上げる	他人の希望	盛り上げたがる
# 盛り上げる	て	盛り上げて
# 盛り上げる	です・ます	盛り上げます
# 盛りつける	可能	盛り盛りつける
# 盛りつける	受け身	盛り盛りつけられる
# 盛りつける	使役	盛り盛りつけせる
# 盛りつける	過去	盛り盛りつけた
# 盛りつける	否定	盛り盛りつけない
# 盛りつける	推定	盛り盛りつけるらしい
# 盛りつける	様態	盛り盛りつけるそう
# 盛りつける	伝聞	盛り盛りつけるそうだ
# 盛りつける	例示	盛り盛りつけるようだ
# 盛りつける	勧誘	盛り盛りつけう
# 盛りつける	自分の希望	盛り盛りつけたい
# 盛りつける	他人の希望	盛り盛りつけたがる
# 盛りつける	て	盛り盛りつけて
# 盛りつける	です・ます	盛り盛りつけます
# 盛る	可能	盛れる
# 盛る	受け身	盛るられる
# 盛る	使役	盛るせる
# 盛る	過去	盛った
# 盛る	否定	盛らない
# 盛る	推定	盛るらしい
# 盛る	様態	盛るそう
# 盛る	伝聞	盛るそうだ
# 盛る	例示	盛るようだ
# 盛る	勧誘	盛ろう
# 盛る	自分の希望	盛るたい
# 盛る	他人の希望	盛るたがる
# 盛る	て	盛って
# 盛る	です・ます	盛ります
# 訳す	可能	訳せる
# 訳す	受け身	訳すられる
# 訳す	使役	訳すせる
# 訳す	過去	訳した
# 訳す	否定	訳さない
# 訳す	推定	訳すらしい
# 訳す	様態	訳すそう
# 訳す	伝聞	訳すそうだ
# 訳す	例示	訳すようだ
# 訳す	勧誘	訳そう
# 訳す	自分の希望	訳すたい
# 訳す	他人の希望	訳すたがる
# 訳す	て	訳して
# 訳す	です・ます	訳します
# やってくる	可能	やってくるこる
# やってくる	受け身	やってくるこられる
# やってくる	使役	やってくるこせる
# やってくる	過去	やってくるきた
# やってくる	否定	やってくるこない
# やってくる	推定	やってくるくるらしい
# やってくる	様態	やってくるくるそう
# やってくる	伝聞	やってくるくるそうだ
# やってくる	例示	やってくるくるようだ
# やってくる	勧誘	やってくるこう
# やってくる	自分の希望	やってくるこたい
# やってくる	他人の希望	やってくるこたがる
# やってくる	て	やってくるきて
# やってくる	です・ます	やってくるきます
# 雇う	可能	雇える
# 雇う	受け身	雇うられる
# 雇う	使役	雇うせる
# 雇う	過去	雇った
# 雇う	否定	雇あない
# 雇う	推定	雇うらしい
# 雇う	様態	雇うそう
# 雇う	伝聞	雇うそうだ
# 雇う	例示	雇うようだ
# 雇う	勧誘	雇おう
# 雇う	自分の希望	雇うたい
# 雇う	他人の希望	雇うたがる
# 雇う	て	雇って
# 雇う	です・ます	雇います
# 破る	可能	破れる
# 破る	受け身	破るられる
# 破る	使役	破るせる
# 破る	過去	破った
# 破る	否定	破らない
# 破る	推定	破るらしい
# 破る	様態	破るそう
# 破る	伝聞	破るそうだ
# 破る	例示	破るようだ
# 破る	勧誘	破ろう
# 破る	自分の希望	破るたい
# 破る	他人の希望	破るたがる
# 破る	て	破って
# 破る	です・ます	破ります
# 敗れる	可能	敗れる
# 敗れる	受け身	敗れられる
# 敗れる	使役	敗れせる
# 敗れる	過去	敗れた
# 敗れる	否定	敗れない
# 敗れる	推定	敗れるらしい
# 敗れる	様態	敗れるそう
# 敗れる	伝聞	敗れるそうだ
# 敗れる	例示	敗れるようだ
# 敗れる	勧誘	敗れう
# 敗れる	自分の希望	敗れたい
# 敗れる	他人の希望	敗れたがる
# 敗れる	て	敗れて
# 敗れる	です・ます	敗れます
# やり遂げる	可能	やりやり遂げる
# やり遂げる	受け身	やりやり遂げられる
# やり遂げる	使役	やりやり遂げせる
# やり遂げる	過去	やりやり遂げた
# やり遂げる	否定	やりやり遂げない
# やり遂げる	推定	やりやり遂げるらしい
# やり遂げる	様態	やりやり遂げるそう
# やり遂げる	伝聞	やりやり遂げるそうだ
# やり遂げる	例示	やりやり遂げるようだ
# やり遂げる	勧誘	やりやり遂げう
# やり遂げる	自分の希望	やりやり遂げたい
# やり遂げる	他人の希望	やりやり遂げたがる
# やり遂げる	て	やりやり遂げて
# やり遂げる	です・ます	やりやり遂げます
# 輸血する	可能	輸血輸血できれる
# 輸血する	受け身	輸血輸血さられる
# 輸血する	使役	輸血輸血させる
# 輸血する	過去	輸血輸血した
# 輸血する	否定	輸血輸血しない
# 輸血する	推定	輸血輸血するらしい
# 輸血する	様態	輸血輸血するそう
# 輸血する	伝聞	輸血輸血するそうだ
# 輸血する	例示	輸血輸血するようだ
# 輸血する	勧誘	輸血輸血しう
# 輸血する	自分の希望	輸血輸血さたい
# 輸血する	他人の希望	輸血輸血さたがる
# 輸血する	て	輸血輸血して
# 輸血する	です・ます	輸血輸血します
# 譲る	可能	譲れる
# 譲る	受け身	譲るられる
# 譲る	使役	譲るせる
# 譲る	過去	譲った
# 譲る	否定	譲らない
# 譲る	推定	譲るらしい
# 譲る	様態	譲るそう
# 譲る	伝聞	譲るそうだ
# 譲る	例示	譲るようだ
# 譲る	勧誘	譲ろう
# 譲る	自分の希望	譲るたい
# 譲る	他人の希望	譲るたがる
# 譲る	て	譲って
# 譲る	です・ます	譲ります
# 油断する	可能	油断油断できれる
# 油断する	受け身	油断油断さられる
# 油断する	使役	油断油断させる
# 油断する	過去	油断油断した
# 油断する	否定	油断油断しない
# 油断する	推定	油断油断するらしい
# 油断する	様態	油断油断するそう
# 油断する	伝聞	油断油断するそうだ
# 油断する	例示	油断油断するようだ
# 油断する	勧誘	油断油断しう
# 油断する	自分の希望	油断油断さたい
# 油断する	他人の希望	油断油断さたがる
# 油断する	て	油断油断して
# 油断する	です・ます	油断油断します
# ゆでる	可能	ゆでる
# ゆでる	受け身	ゆでられる
# ゆでる	使役	ゆでせる
# ゆでる	過去	ゆでた
# ゆでる	否定	ゆでない
# ゆでる	推定	ゆでるらしい
# ゆでる	様態	ゆでるそう
# ゆでる	伝聞	ゆでるそうだ
# ゆでる	例示	ゆでるようだ
# ゆでる	勧誘	ゆでう
# ゆでる	自分の希望	ゆでたい
# ゆでる	他人の希望	ゆでたがる
# ゆでる	て	ゆでて
# ゆでる	です・ます	ゆでます
# 許す	可能	許せる
# 許す	受け身	許すられる
# 許す	使役	許すせる
# 許す	過去	許した
# 許す	否定	許さない
# 許す	推定	許すらしい
# 許す	様態	許すそう
# 許す	伝聞	許すそうだ
# 許す	例示	許すようだ
# 許す	勧誘	許そう
# 許す	自分の希望	許すたい
# 許す	他人の希望	許すたがる
# 許す	て	許して
# 許す	です・ます	許します
# 揺れる	可能	揺れる
# 揺れる	受け身	揺れられる
# 揺れる	使役	揺れせる
# 揺れる	過去	揺れた
# 揺れる	否定	揺れない
# 揺れる	推定	揺れるらしい
# 揺れる	様態	揺れるそう
# 揺れる	伝聞	揺れるそうだ
# 揺れる	例示	揺れるようだ
# 揺れる	勧誘	揺れう
# 揺れる	自分の希望	揺れたい
# 揺れる	他人の希望	揺れたがる
# 揺れる	て	揺れて
# 揺れる	です・ます	揺れます
# 養殖する	可能	養殖養殖できれる
# 養殖する	受け身	養殖養殖さられる
# 養殖する	使役	養殖養殖させる
# 養殖する	過去	養殖養殖した
# 養殖する	否定	養殖養殖しない
# 養殖する	推定	養殖養殖するらしい
# 養殖する	様態	養殖養殖するそう
# 養殖する	伝聞	養殖養殖するそうだ
# 養殖する	例示	養殖養殖するようだ
# 養殖する	勧誘	養殖養殖しう
# 養殖する	自分の希望	養殖養殖さたい
# 養殖する	他人の希望	養殖養殖さたがる
# 養殖する	て	養殖養殖して
# 養殖する	です・ます	養殖養殖します
# 用心する	可能	用心用心できれる
# 用心する	受け身	用心用心さられる
# 用心する	使役	用心用心させる
# 用心する	過去	用心用心した
# 用心する	否定	用心用心しない
# 用心する	推定	用心用心するらしい
# 用心する	様態	用心用心するそう
# 用心する	伝聞	用心用心するそうだ
# 用心する	例示	用心用心するようだ
# 用心する	勧誘	用心用心しう
# 用心する	自分の希望	用心用心さたい
# 用心する	他人の希望	用心用心さたがる
# 用心する	て	用心用心して
# 用心する	です・ます	用心用心します
# 予感する	可能	予感予感できれる
# 予感する	受け身	予感予感さられる
# 予感する	使役	予感予感させる
# 予感する	過去	予感予感した
# 予感する	否定	予感予感しない
# 予感する	推定	予感予感するらしい
# 予感する	様態	予感予感するそう
# 予感する	伝聞	予感予感するそうだ
# 予感する	例示	予感予感するようだ
# 予感する	勧誘	予感予感しう
# 予感する	自分の希望	予感予感さたい
# 予感する	他人の希望	予感予感さたがる
# 予感する	て	予感予感して
# 予感する	です・ます	予感予感します
# 予言する	可能	予言予言できれる
# 予言する	受け身	予言予言さられる
# 予言する	使役	予言予言させる
# 予言する	過去	予言予言した
# 予言する	否定	予言予言しない
# 予言する	推定	予言予言するらしい
# 予言する	様態	予言予言するそう
# 予言する	伝聞	予言予言するそうだ
# 予言する	例示	予言予言するようだ
# 予言する	勧誘	予言予言しう
# 予言する	自分の希望	予言予言さたい
# 予言する	他人の希望	予言予言さたがる
# 予言する	て	予言予言して
# 予言する	です・ます	予言予言します
# 予告する	可能	予告予告できれる
# 予告する	受け身	予告予告さられる
# 予告する	使役	予告予告させる
# 予告する	過去	予告予告した
# 予告する	否定	予告予告しない
# 予告する	推定	予告予告するらしい
# 予告する	様態	予告予告するそう
# 予告する	伝聞	予告予告するそうだ
# 予告する	例示	予告予告するようだ
# 予告する	勧誘	予告予告しう
# 予告する	自分の希望	予告予告さたい
# 予告する	他人の希望	予告予告さたがる
# 予告する	て	予告予告して
# 予告する	です・ます	予告予告します
# よす	可能	よせる
# よす	受け身	よすられる
# よす	使役	よすせる
# よす	過去	よした
# よす	否定	よさない
# よす	推定	よすらしい
# よす	様態	よすそう
# よす	伝聞	よすそうだ
# よす	例示	よすようだ
# よす	勧誘	よそう
# よす	自分の希望	よすたい
# よす	他人の希望	よすたがる
# よす	て	よして
# よす	です・ます	よします
# 寄せる	可能	寄せる
# 寄せる	受け身	寄せられる
# 寄せる	使役	寄せせる
# 寄せる	過去	寄せた
# 寄せる	否定	寄せない
# 寄せる	推定	寄せるらしい
# 寄せる	様態	寄せるそう
# 寄せる	伝聞	寄せるそうだ
# 寄せる	例示	寄せるようだ
# 寄せる	勧誘	寄せう
# 寄せる	自分の希望	寄せたい
# 寄せる	他人の希望	寄せたがる
# 寄せる	て	寄せて
# 寄せる	です・ます	寄せます
# 予想する	可能	予想予想できれる
# 予想する	受け身	予想予想さられる
# 予想する	使役	予想予想させる
# 予想する	過去	予想予想した
# 予想する	否定	予想予想しない
# 予想する	推定	予想予想するらしい
# 予想する	様態	予想予想するそう
# 予想する	伝聞	予想予想するそうだ
# 予想する	例示	予想予想するようだ
# 予想する	勧誘	予想予想しう
# 予想する	自分の希望	予想予想さたい
# 予想する	他人の希望	予想予想さたがる
# 予想する	て	予想予想して
# 予想する	です・ます	予想予想します
# 予測する	可能	予測予測できれる
# 予測する	受け身	予測予測さられる
# 予測する	使役	予測予測させる
# 予測する	過去	予測予測した
# 予測する	否定	予測予測しない
# 予測する	推定	予測予測するらしい
# 予測する	様態	予測予測するそう
# 予測する	伝聞	予測予測するそうだ
# 予測する	例示	予測予測するようだ
# 予測する	勧誘	予測予測しう
# 予測する	自分の希望	予測予測さたい
# 予測する	他人の希望	予測予測さたがる
# 予測する	て	予測予測して
# 予測する	です・ます	予測予測します
# 予知する	可能	予知予知できれる
# 予知する	受け身	予知予知さられる
# 予知する	使役	予知予知させる
# 予知する	過去	予知予知した
# 予知する	否定	予知予知しない
# 予知する	推定	予知予知するらしい
# 予知する	様態	予知予知するそう
# 予知する	伝聞	予知予知するそうだ
# 予知する	例示	予知予知するようだ
# 予知する	勧誘	予知予知しう
# 予知する	自分の希望	予知予知さたい
# 予知する	他人の希望	予知予知さたがる
# 予知する	て	予知予知して
# 予知する	です・ます	予知予知します
# 酔っ払う	可能	酔っ払える
# 酔っ払う	受け身	酔っ払うられる
# 酔っ払う	使役	酔っ払うせる
# 酔っ払う	過去	酔っ払った
# 酔っ払う	否定	酔っ払あない
# 酔っ払う	推定	酔っ払うらしい
# 酔っ払う	様態	酔っ払うそう
# 酔っ払う	伝聞	酔っ払うそうだ
# 酔っ払う	例示	酔っ払うようだ
# 酔っ払う	勧誘	酔っ払おう
# 酔っ払う	自分の希望	酔っ払うたい
# 酔っ払う	他人の希望	酔っ払うたがる
# 酔っ払う	て	酔っ払って
# 酔っ払う	です・ます	酔っ払います
# 呼びかける	可能	呼びかける
# 呼びかける	受け身	呼びかけられる
# 呼びかける	使役	呼びかけせる
# 呼びかける	過去	呼びかけた
# 呼びかける	否定	呼びかけない
# 呼びかける	推定	呼びかけるらしい
# 呼びかける	様態	呼びかけるそう
# 呼びかける	伝聞	呼びかけるそうだ
# 呼びかける	例示	呼びかけるようだ
# 呼びかける	勧誘	呼びかけう
# 呼びかける	自分の希望	呼びかけたい
# 呼びかける	他人の希望	呼びかけたがる
# 呼びかける	て	呼びかけて
# 呼びかける	です・ます	呼びかけます
# 呼びつける	可能	呼び呼びつける
# 呼びつける	受け身	呼び呼びつけられる
# 呼びつける	使役	呼び呼びつけせる
# 呼びつける	過去	呼び呼びつけた
# 呼びつける	否定	呼び呼びつけない
# 呼びつける	推定	呼び呼びつけるらしい
# 呼びつける	様態	呼び呼びつけるそう
# 呼びつける	伝聞	呼び呼びつけるそうだ
# 呼びつける	例示	呼び呼びつけるようだ
# 呼びつける	勧誘	呼び呼びつけう
# 呼びつける	自分の希望	呼び呼びつけたい
# 呼びつける	他人の希望	呼び呼びつけたがる
# 呼びつける	て	呼び呼びつけて
# 呼びつける	です・ます	呼び呼びつけます
# 呼ぶ	可能	呼べる
# 呼ぶ	受け身	呼ぶられる
# 呼ぶ	使役	呼ぶせる
# 呼ぶ	過去	呼んだ
# 呼ぶ	否定	呼ばない
# 呼ぶ	推定	呼ぶらしい
# 呼ぶ	様態	呼ぶそう
# 呼ぶ	伝聞	呼ぶそうだ
# 呼ぶ	例示	呼ぶようだ
# 呼ぶ	勧誘	呼ぼう
# 呼ぶ	自分の希望	呼ぶたい
# 呼ぶ	他人の希望	呼ぶたがる
# 呼ぶ	て	呼んて
# 呼ぶ	です・ます	呼びます
# 予防する	可能	予防予防できれる
# 予防する	受け身	予防予防さられる
# 予防する	使役	予防予防させる
# 予防する	過去	予防予防した
# 予防する	否定	予防予防しない
# 予防する	推定	予防予防するらしい
# 予防する	様態	予防予防するそう
# 予防する	伝聞	予防予防するそうだ
# 予防する	例示	予防予防するようだ
# 予防する	勧誘	予防予防しう
# 予防する	自分の希望	予防予防さたい
# 予防する	他人の希望	予防予防さたがる
# 予防する	て	予防予防して
# 予防する	です・ます	予防予防します
# 読み取る	可能	読み読み取れる
# 読み取る	受け身	読み読み取るられる
# 読み取る	使役	読み読み取るせる
# 読み取る	過去	読み読み取った
# 読み取る	否定	読み読み取らない
# 読み取る	推定	読み読み取るらしい
# 読み取る	様態	読み読み取るそう
# 読み取る	伝聞	読み読み取るそうだ
# 読み取る	例示	読み読み取るようだ
# 読み取る	勧誘	読み読み取ろう
# 読み取る	自分の希望	読み読み取るたい
# 読み取る	他人の希望	読み読み取るたがる
# 読み取る	て	読み読み取って
# 読み取る	です・ます	読み読み取ります
# 読み間違う	可能	読み読み間違える
# 読み間違う	受け身	読み読み間違うられる
# 読み間違う	使役	読み読み間違うせる
# 読み間違う	過去	読み読み間違った
# 読み間違う	否定	読み読み間違あない
# 読み間違う	推定	読み読み間違うらしい
# 読み間違う	様態	読み読み間違うそう
# 読み間違う	伝聞	読み読み間違うそうだ
# 読み間違う	例示	読み読み間違うようだ
# 読み間違う	勧誘	読み読み間違おう
# 読み間違う	自分の希望	読み読み間違うたい
# 読み間違う	他人の希望	読み読み間違うたがる
# 読み間違う	て	読み読み間違って
# 読み間違う	です・ます	読み読み間違います
# 喜ぶ	可能	喜べる
# 喜ぶ	受け身	喜ぶられる
# 喜ぶ	使役	喜ぶせる
# 喜ぶ	過去	喜んだ
# 喜ぶ	否定	喜ばない
# 喜ぶ	推定	喜ぶらしい
# 喜ぶ	様態	喜ぶそう
# 喜ぶ	伝聞	喜ぶそうだ
# 喜ぶ	例示	喜ぶようだ
# 喜ぶ	勧誘	喜ぼう
# 喜ぶ	自分の希望	喜ぶたい
# 喜ぶ	他人の希望	喜ぶたがる
# 喜ぶ	て	喜んて
# 喜ぶ	です・ます	喜びます
# 弱まる	可能	弱まれる
# 弱まる	受け身	弱まるられる
# 弱まる	使役	弱まるせる
# 弱まる	過去	弱まった
# 弱まる	否定	弱まらない
# 弱まる	推定	弱まるらしい
# 弱まる	様態	弱まるそう
# 弱まる	伝聞	弱まるそうだ
# 弱まる	例示	弱まるようだ
# 弱まる	勧誘	弱まろう
# 弱まる	自分の希望	弱まるたい
# 弱まる	他人の希望	弱まるたがる
# 弱まる	て	弱まって
# 弱まる	です・ます	弱まります
# 弱める	可能	弱める
# 弱める	受け身	弱められる
# 弱める	使役	弱めせる
# 弱める	過去	弱めた
# 弱める	否定	弱めない
# 弱める	推定	弱めるらしい
# 弱める	様態	弱めるそう
# 弱める	伝聞	弱めるそうだ
# 弱める	例示	弱めるようだ
# 弱める	勧誘	弱めう
# 弱める	自分の希望	弱めたい
# 弱める	他人の希望	弱めたがる
# 弱める	て	弱めて
# 弱める	です・ます	弱めます
# 来日する	可能	来日来日できれる
# 来日する	受け身	来日来日さられる
# 来日する	使役	来日来日させる
# 来日する	過去	来日来日した
# 来日する	否定	来日来日しない
# 来日する	推定	来日来日するらしい
# 来日する	様態	来日来日するそう
# 来日する	伝聞	来日来日するそうだ
# 来日する	例示	来日来日するようだ
# 来日する	勧誘	来日来日しう
# 来日する	自分の希望	来日来日さたい
# 来日する	他人の希望	来日来日さたがる
# 来日する	て	来日来日して
# 来日する	です・ます	来日来日します
# ランクする	可能	ランクランクできれる
# ランクする	受け身	ランクランクさられる
# ランクする	使役	ランクランクさせる
# ランクする	過去	ランクランクした
# ランクする	否定	ランクランクしない
# ランクする	推定	ランクランクするらしい
# ランクする	様態	ランクランクするそう
# ランクする	伝聞	ランクランクするそうだ
# ランクする	例示	ランクランクするようだ
# ランクする	勧誘	ランクランクしう
# ランクする	自分の希望	ランクランクさたい
# ランクする	他人の希望	ランクランクさたがる
# ランクする	て	ランクランクして
# ランクする	です・ます	ランクランクします
# 乱暴する	可能	乱暴乱暴できれる
# 乱暴する	受け身	乱暴乱暴さられる
# 乱暴する	使役	乱暴乱暴させる
# 乱暴する	過去	乱暴乱暴した
# 乱暴する	否定	乱暴乱暴しない
# 乱暴する	推定	乱暴乱暴するらしい
# 乱暴する	様態	乱暴乱暴するそう
# 乱暴する	伝聞	乱暴乱暴するそうだ
# 乱暴する	例示	乱暴乱暴するようだ
# 乱暴する	勧誘	乱暴乱暴しう
# 乱暴する	自分の希望	乱暴乱暴さたい
# 乱暴する	他人の希望	乱暴乱暴さたがる
# 乱暴する	て	乱暴乱暴して
# 乱暴する	です・ます	乱暴乱暴します
# 理解する	可能	理解理解できれる
# 理解する	受け身	理解理解さられる
# 理解する	使役	理解理解させる
# 理解する	過去	理解理解した
# 理解する	否定	理解理解しない
# 理解する	推定	理解理解するらしい
# 理解する	様態	理解理解するそう
# 理解する	伝聞	理解理解するそうだ
# 理解する	例示	理解理解するようだ
# 理解する	勧誘	理解理解しう
# 理解する	自分の希望	理解理解さたい
# 理解する	他人の希望	理解理解さたがる
# 理解する	て	理解理解して
# 理解する	です・ます	理解理解します
# 履修する	可能	履修履修できれる
# 履修する	受け身	履修履修さられる
# 履修する	使役	履修履修させる
# 履修する	過去	履修履修した
# 履修する	否定	履修履修しない
# 履修する	推定	履修履修するらしい
# 履修する	様態	履修履修するそう
# 履修する	伝聞	履修履修するそうだ
# 履修する	例示	履修履修するようだ
# 履修する	勧誘	履修履修しう
# 履修する	自分の希望	履修履修さたい
# 履修する	他人の希望	履修履修さたがる
# 履修する	て	履修履修して
# 履修する	です・ます	履修履修します
# 流行する	可能	流行流行できれる
# 流行する	受け身	流行流行さられる
# 流行する	使役	流行流行させる
# 流行する	過去	流行流行した
# 流行する	否定	流行流行しない
# 流行する	推定	流行流行するらしい
# 流行する	様態	流行流行するそう
# 流行する	伝聞	流行流行するそうだ
# 流行する	例示	流行流行するようだ
# 流行する	勧誘	流行流行しう
# 流行する	自分の希望	流行流行さたい
# 流行する	他人の希望	流行流行さたがる
# 流行する	て	流行流行して
# 流行する	です・ます	流行流行します
# 流通する	可能	流通流通できれる
# 流通する	受け身	流通流通さられる
# 流通する	使役	流通流通させる
# 流通する	過去	流通流通した
# 流通する	否定	流通流通しない
# 流通する	推定	流通流通するらしい
# 流通する	様態	流通流通するそう
# 流通する	伝聞	流通流通するそうだ
# 流通する	例示	流通流通するようだ
# 流通する	勧誘	流通流通しう
# 流通する	自分の希望	流通流通さたい
# 流通する	他人の希望	流通流通さたがる
# 流通する	て	流通流通して
# 流通する	です・ます	流通流通します
# 了承する	可能	了承了承できれる
# 了承する	受け身	了承了承さられる
# 了承する	使役	了承了承させる
# 了承する	過去	了承了承した
# 了承する	否定	了承了承しない
# 了承する	推定	了承了承するらしい
# 了承する	様態	了承了承するそう
# 了承する	伝聞	了承了承するそうだ
# 了承する	例示	了承了承するようだ
# 了承する	勧誘	了承了承しう
# 了承する	自分の希望	了承了承さたい
# 了承する	他人の希望	了承了承さたがる
# 了承する	て	了承了承して
# 了承する	です・ます	了承了承します
# 冷凍する	可能	冷凍冷凍できれる
# 冷凍する	受け身	冷凍冷凍さられる
# 冷凍する	使役	冷凍冷凍させる
# 冷凍する	過去	冷凍冷凍した
# 冷凍する	否定	冷凍冷凍しない
# 冷凍する	推定	冷凍冷凍するらしい
# 冷凍する	様態	冷凍冷凍するそう
# 冷凍する	伝聞	冷凍冷凍するそうだ
# 冷凍する	例示	冷凍冷凍するようだ
# 冷凍する	勧誘	冷凍冷凍しう
# 冷凍する	自分の希望	冷凍冷凍さたい
# 冷凍する	他人の希望	冷凍冷凍さたがる
# 冷凍する	て	冷凍冷凍して
# 冷凍する	です・ます	冷凍冷凍します
# 恋愛する	可能	恋愛恋愛できれる
# 恋愛する	受け身	恋愛恋愛さられる
# 恋愛する	使役	恋愛恋愛させる
# 恋愛する	過去	恋愛恋愛した
# 恋愛する	否定	恋愛恋愛しない
# 恋愛する	推定	恋愛恋愛するらしい
# 恋愛する	様態	恋愛恋愛するそう
# 恋愛する	伝聞	恋愛恋愛するそうだ
# 恋愛する	例示	恋愛恋愛するようだ
# 恋愛する	勧誘	恋愛恋愛しう
# 恋愛する	自分の希望	恋愛恋愛さたい
# 恋愛する	他人の希望	恋愛恋愛さたがる
# 恋愛する	て	恋愛恋愛して
# 恋愛する	です・ます	恋愛恋愛します
# 連想する	可能	連想連想できれる
# 連想する	受け身	連想連想さられる
# 連想する	使役	連想連想させる
# 連想する	過去	連想連想した
# 連想する	否定	連想連想しない
# 連想する	推定	連想連想するらしい
# 連想する	様態	連想連想するそう
# 連想する	伝聞	連想連想するそうだ
# 連想する	例示	連想連想するようだ
# 連想する	勧誘	連想連想しう
# 連想する	自分の希望	連想連想さたい
# 連想する	他人の希望	連想連想さたがる
# 連想する	て	連想連想して
# 連想する	です・ます	連想連想します
# 労働する	可能	労働労働できれる
# 労働する	受け身	労働労働さられる
# 労働する	使役	労働労働させる
# 労働する	過去	労働労働した
# 労働する	否定	労働労働しない
# 労働する	推定	労働労働するらしい
# 労働する	様態	労働労働するそう
# 労働する	伝聞	労働労働するそうだ
# 労働する	例示	労働労働するようだ
# 労働する	勧誘	労働労働しう
# 労働する	自分の希望	労働労働さたい
# 労働する	他人の希望	労働労働さたがる
# 労働する	て	労働労働して
# 労働する	です・ます	労働労働します
# 分かれる	可能	分かれる
# 分かれる	受け身	分かれられる
# 分かれる	使役	分かれせる
# 分かれる	過去	分かれた
# 分かれる	否定	分かれない
# 分かれる	推定	分かれるらしい
# 分かれる	様態	分かれるそう
# 分かれる	伝聞	分かれるそうだ
# 分かれる	例示	分かれるようだ
# 分かれる	勧誘	分かれう
# 分かれる	自分の希望	分かれたい
# 分かれる	他人の希望	分かれたがる
# 分かれる	て	分かれて
# 分かれる	です・ます	分かれます
# 湧く	可能	湧ける
# 湧く	受け身	湧くられる
# 湧く	使役	湧くせる
# 湧く	過去	湧いた
# 湧く	否定	湧かない
# 湧く	推定	湧くらしい
# 湧く	様態	湧くそう
# 湧く	伝聞	湧くそうだ
# 湧く	例示	湧くようだ
# 湧く	勧誘	湧こう
# 湧く	自分の希望	湧くたい
# 湧く	他人の希望	湧くたがる
# 湧く	て	湧いて
# 湧く	です・ます	湧きます
# 沸く	可能	沸ける
# 沸く	受け身	沸くられる
# 沸く	使役	沸くせる
# 沸く	過去	沸いた
# 沸く	否定	沸かない
# 沸く	推定	沸くらしい
# 沸く	様態	沸くそう
# 沸く	伝聞	沸くそうだ
# 沸く	例示	沸くようだ
# 沸く	勧誘	沸こう
# 沸く	自分の希望	沸くたい
# 沸く	他人の希望	沸くたがる
# 沸く	て	沸いて
# 沸く	です・ます	沸きます
# わたる	可能	わたれる
# わたる	受け身	わたるられる
# わたる	使役	わたるせる
# わたる	過去	わたった
# わたる	否定	わたらない
# わたる	推定	わたるらしい
# わたる	様態	わたるそう
# わたる	伝聞	わたるそうだ
# わたる	例示	わたるようだ
# わたる	勧誘	わたろう
# わたる	自分の希望	わたるたい
# わたる	他人の希望	わたるたがる
# わたる	て	わたって
# わたる	です・ます	わたります
# 笑い飛ばす	可能	笑い笑い飛ばせる
# 笑い飛ばす	受け身	笑い笑い飛ばすられる
# 笑い飛ばす	使役	笑い笑い飛ばすせる
# 笑い飛ばす	過去	笑い笑い飛ばした
# 笑い飛ばす	否定	笑い笑い飛ばさない
# 笑い飛ばす	推定	笑い笑い飛ばすらしい
# 笑い飛ばす	様態	笑い笑い飛ばすそう
# 笑い飛ばす	伝聞	笑い笑い飛ばすそうだ
# 笑い飛ばす	例示	笑い笑い飛ばすようだ
# 笑い飛ばす	勧誘	笑い笑い飛ばそう
# 笑い飛ばす	自分の希望	笑い笑い飛ばすたい
# 笑い飛ばす	他人の希望	笑い笑い飛ばすたがる
# 笑い飛ばす	て	笑い笑い飛ばして
# 笑い飛ばす	です・ます	笑い笑い飛ばします
# 割り込む	可能	割り割り込める
# 割り込む	受け身	割り割り込むられる
# 割り込む	使役	割り割り込むせる
# 割り込む	過去	割り割り込んだ
# 割り込む	否定	割り割り込まない
# 割り込む	推定	割り割り込むらしい
# 割り込む	様態	割り割り込むそう
# 割り込む	伝聞	割り割り込むそうだ
# 割り込む	例示	割り割り込むようだ
# 割り込む	勧誘	割り割り込もう
# 割り込む	自分の希望	割り割り込むたい
# 割り込む	他人の希望	割り割り込むたがる
# 割り込む	て	割り割り込んて
# 割り込む	です・ます	割り割り込みます
# 割り引く	可能	割り引ける
# 割り引く	受け身	割り引くられる
# 割り引く	使役	割り引くせる
# 割り引く	過去	割り引いた
# 割り引く	否定	割り引かない
# 割り引く	推定	割り引くらしい
# 割り引く	様態	割り引くそう
# 割り引く	伝聞	割り引くそうだ
# 割り引く	例示	割り引くようだ
# 割り引く	勧誘	割り引こう
# 割り引く	自分の希望	割り引くたい
# 割り引く	他人の希望	割り引くたがる
# 割り引く	て	割り引いて
# 割り引く	です・ます	割り引きます
# 割る	可能	割れる
# 割る	受け身	割るられる
# 割る	使役	割るせる
# 割る	過去	割った
# 割る	否定	割らない
# 割る	推定	割るらしい
# 割る	様態	割るそう
# 割る	伝聞	割るそうだ
# 割る	例示	割るようだ
# 割る	勧誘	割ろう
# 割る	自分の希望	割るたい
# 割る	他人の希望	割るたがる
# 割る	て	割って
# 割る	です・ます	割ります
